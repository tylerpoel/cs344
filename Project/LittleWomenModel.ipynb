# %% [markdown]
# ## Preparing Data
#
# Using code from Chollet, found at:

# %%
import keras
import numpy as np

#path = keras.utils.get_file(
#    'nietzsche.txt',
#    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
#text = open(path).read().lower()
text = open("/home/trp22/CS/344/cs344/Project/LittleWomen.txt").read().lower()
print('Corpus length:', len(text))
# Out:
# Using TensorFlow backend.
# Corpus length: 1050605

# %%
#print(text)

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 350182
# Unique characters: 59
# Vectorization...

# %% [markdown]
# ## Building the network

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the model

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 61):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    if epoch % 5 == 0:
        # Select a text seed at random
        start_index = random.randint(0, len(text) - maxlen - 1)
        generated_text = text[start_index: start_index + maxlen]
        print('--- Generating with seed: "' + generated_text + '"')
    
        for temperature in [0.2, 0.5]:
            print('------ temperature:', temperature)
            sys.stdout.write(generated_text)
    
            # We generate 400 characters
            for i in range(600):
                sampled = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(generated_text):
                    sampled[0, t, char_indices[char]] = 1.
    
                preds = model.predict(sampled, verbose=0)[0]
                next_index = sample(preds, temperature)
                next_char = chars[next_index]
    
                generated_text += next_char
                generated_text = generated_text[1:]
    
                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()
# Out:
# epoch 1
# Epoch 1/1
# 350182/350182 [==============================] - 85s 243us/step - loss: 1.7474
# epoch 2
# Epoch 1/1
# 350182/350182 [==============================] - 87s 249us/step - loss: 1.4852
# epoch 3
# Epoch 1/1
# 350182/350182 [==============================] - 86s 246us/step - loss: 1.4348
# epoch 4
# Epoch 1/1
# 350182/350182 [==============================] - 81s 230us/step - loss: 1.4005
# epoch 5
# Epoch 1/1
# 350182/350182 [==============================] - 78s 223us/step - loss: 1.3768
# --- Generating with seed: " we do now. but it does seem so nice to have little suppers "
# ------ temperature: 0.2
#  we do now. but it does seem so nice to have little suppers of the sunce that i do and the price of the famber that i do a great good and when i can be hand to the sunsting the story of so comfort to the sight, and the famber that i do the truth, and the great fate to the comfort to the face and the sunsible to me to me to the staring to the stares, and made meg the delighter and the great began to the story of the fine little fame of the sunce of the famber that he said the sorry of the sight, and the story of the comfort to the say, and the story to the stared the sunsible which was a sight of the sun the treative of the comfort and the great of the
# ------ temperature: 0.5
# of the sun the treative of the comfort and the great of the fine comfort of presances, and she did not beautiful better as the comfort of the comforts in the lovely things, and the great mester and good rose a few way. i had the hand of a more which was a gentleman.
# âi donât be light of lovely that meg was on the true baster and family made the comfort in the bood so very in the bodd and the sight that i had the day, and the comfort of the sight at her fat and trust to do the place and grow the most others of the tree to be the little word the kind, which she was on the soon and the right, and the such to the carriage will be the sounded which is
# epoch 6
# Epoch 1/1
# 350182/350182 [==============================] - 80s 228us/step - loss: 1.3605
# epoch 7
# Epoch 1/1
# 350182/350182 [==============================] - 80s 227us/step - loss: 1.3481
# epoch 8
# Epoch 1/1
# 350182/350182 [==============================] - 79s 225us/step - loss: 1.3391
# epoch 9
# Epoch 1/1
# 350182/350182 [==============================] - 83s 238us/step - loss: 1.3304
# epoch 10
# Epoch 1/1
# 350182/350182 [==============================] - 79s 225us/step - loss: 1.3255
# --- Generating with seed: "nother. there doesnât seem to be any- thing to hold on to "
# ------ temperature: 0.2
# nother. there doesnât seem to be any- thing to hold on to have the girl of much and the professor to have a part of the stand of the face of the state of the little house to her to hear the grave was so the struck of the part of the face than she was so for the part of the story to see it was the strong of the state of an answer march and the gravely and stop and tried to have the fact of the state of her story.
# âi was the first of the study of the stall of the first of her face to the face and say to be so discontented to the strong of the story, and the stort to the professor the part of the story of the day of her best to the peace of the trimm
# ------ temperature: 0.5
# f the story of the day of her best to the peace of the trimmery of the little belle as you can asked the great of how stirrity and bread to be got the little face strong to face to the best death.
# âi have to sat now and carrome of many was on the place of all they all done the old says i were to was the some both to the stor got an answer it was a sent to the so coming of the con-
# reter which she as satisfied, and the people and a little comfort to come of the windows in the corner to many dignance his brother thoughts of saying to the sofare were her paper of sappiny and began to me, but i think she done to read the tray to be many with her mother
# epoch 11
# Epoch 1/1
# 350182/350182 [==============================] - 79s 225us/step - loss: 1.3205
# epoch 12
# Epoch 1/1
# 350182/350182 [==============================] - 80s 227us/step - loss: 1.3163
# epoch 13
# Epoch 1/1
# 350182/350182 [==============================] - 80s 227us/step - loss: 1.3129
# epoch 14
# Epoch 1/1
# 350182/350182 [==============================] - 79s 226us/step - loss: 1.3083
# epoch 15
# Epoch 1/1
# 192000/350182 [===============>..............] - ETA: 36s - loss: 1.3047
