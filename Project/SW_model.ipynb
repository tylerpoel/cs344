# %% [markdown]
# ## Preparing Data

# %%
import keras
import numpy as np

# path = keras.utils.get_file(
#    'nietzsche.txt',
#    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
# text = open(path).read().lower()
text = open("/home/trp22/CS/344/cs344/Project/OriginalTrilogy_script.txt").read().lower()
# text = open("/Users/tylerpoel/SW_script.txt").read().lower()
print('Corpus length:', len(text))
# Out:
# Using TensorFlow backend.
# Corpus length: 494395

# %%
#print(text)

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 164779
# Unique characters: 60
# Vectorization...

# %% [markdown]
# ## Building the network

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the model

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 61):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    if epoch % 5 == 0:
        # Select a text seed at random
        start_index = random.randint(0, len(text) - maxlen - 1)
        generated_text = text[start_index: start_index + maxlen]
        print('--- Generating with seed: "' + generated_text + '"')

        for temperature in [0.2, 0.5]:
            print('------ temperature:', temperature)
            sys.stdout.write(generated_text)

            # We generate 400 characters
            for i in range(400):
                sampled = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(generated_text):
                    sampled[0, t, char_indices[char]] = 1.

                preds = model.predict(sampled, verbose=0)[0]
                next_index = sample(preds, temperature)
                next_char = chars[next_index]

                generated_text += next_char
                generated_text = generated_text[1:]

                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()
# Out:
# epoch 1
# Epoch 1/1
# 164779/164779 [==============================] - 39s 234us/step - loss: 1.2525
# epoch 2
# Epoch 1/1
# 164779/164779 [==============================] - 38s 232us/step - loss: 1.2427
# --- Generating with seed: "he blast doors!
# at the end of the hallway, blast doors begin"
# ------ temperature: 0.2
# he blast doors!
# at the end of the hallway, blast doors begin to the ship and the troops and and the ship stands and stands and stands around.
#
# luke
# the ship and the hutt and the ship and the ship and the ship through the fighters and and the rebel scouts from the force.  the falcon stands on the ship.
#
# luke
# the stormtroopers and back to the back and stands and stands at the force.  he stranged and the force is the stormtroopers and back to the controls and
# ------ temperature: 0.5
#  the force is the stormtroopers and back to the controls and chances at the ship of the scout.  he is snow and passabler of the troops.  but the fighters not again the huge banks and bobas
# shamplishes to a massing energy ship and and stands for you. â¨
# 381 â int. dead east - once of the deaders - rebel star is uncer past on the floor.  the end of the fighters standing by the dead.
#
# int. millennium falcon - cockpit - entrance
#
# the hooiporne room and leia
# epoch 3
# Epoch 1/1
# 164779/164779 [==============================] - 39s 234us/step - loss: 1.2343
# epoch 4
# Epoch 1/1
# 164779/164779 [==============================] - 39s 234us/step - loss: 1.2265
# --- Generating with seed: "ely)
# i hope she's alright.
#
# chewbacca growls, sniffing the a"
# ------ temperature: 0.2
# ely)
# i hope she's alright.
#
# chewbacca growls, sniffing the are starts around the ship.
# luke steps the falcon and the rebel star destroyer and the controller and shadd on the shield troopers are start the rebel star destroyer of the shield of the shield back at the ship.
#
# luke
# then something, the shield of the shield controller and rebel starship showers a laser pit starts at the controls and shadd on the shield.  the shield of the rebel star destroyer th
# ------ temperature: 0.5
# dd on the shield.  the shield of the rebel star destroyer the robots with a shadoba computer chewie are weared the cave.
#
# leia is not
# in his endor are snow, are your his pisarlatile of the rangar moments the shield.  i can think the
# controls death star the computer starts in the ring some honoul shoot.
#
# luke
# i say your
# been the races out of the rance the fighters. the cave at the plain and pats a screams
# path.
#
# han is the shield of the controls fill an
# epoch 5
# Epoch 1/1
# 164779/164779 [==============================] - 38s 233us/step - loss: 1.2201
# epoch 6
# Epoch 1/1
# 164779/164779 [==============================] - 39s 236us/step - loss: 1.2112
# --- Generating with seed: " artoo, stay with me.
#
# inside the bunker, han looks up from "
# ------ temperature: 0.2
#  artoo, stay with me.
#
# inside the bunker, han looks up from the dead for a small turn and the scout of a small races and the dark to the dead bolt.  i see the dead staring planet.  a small the darkylond for the screen.  he speaks to the speeder and stands in the ship.  the rebel starship subhallways to the ship.  luke is a ship stands of any shield to the screen.  the ship stands of the screen subsand of the ship.  the screen and sees the superstrom and th
# ------ temperature: 0.5
# sand of the ship.  the screen and sees the superstrom and the comlink and a sighter snowing subsan from the ship. â¨
# 25 â int. gold target - control space - shielde - cockpit
#
# betten troops a short of the two way of the comlink. â¨
# 31int. tatooine - cockpit â¨luke is something as he
# subsands and starts his face.
#
# chewie growls into the lets of the darkytonce.
#
# she sands out a ship.  we're sound the robots and watches a small extrated sits and seems to
# epoch 7
# Epoch 1/1
# 164779/164779 [==============================] - 38s 228us/step - loss: 1.2064
# epoch 8
# Epoch 1/1
# 164779/164779 [==============================] - 37s 226us/step - loss: 1.2004
# --- Generating with seed: "
# leia helps luke from the cockpit as another huge blast rock"
# ------ temperature: 0.2
#
# leia helps luke from the cockpit as another huge blast rocks at the ship.
#
# leia
# what is a ship ships are surface of the ship and the ship ships are and the ship and the
# ship and the battle races at the pirateship as he stands of the ship and the ship ships away from the battle robot.  the ship ships are a ship shield of the ship.
#
# leia
# what is your ship and starts to the death star and the ship ships away from the battle races at the dark lord as the shi
# ------ temperature: 0.5
# ships away from the battle races at the dark lord as the ship.
#
# leia
# well, what is see you got on the for vader's path.
#
# int. cloud city - somethang near room
#
# the side of several shield shield death star bounces at his feet.
#
# chewie grows a panel has taughting laugh the platform.
#
# lando
# what?  han she should have a board slimy flashes.
# luke (contâd)
# what and he hears at the direction of the control room.
# luke station and are we and his head on the batte
# epoch 9
# Epoch 1/1
# 164779/164779 [==============================] - 37s 226us/step - loss: 1.1937
# epoch 10
# Epoch 1/1
# 164779/164779 [==============================] - 37s 226us/step - loss: 1.1903
# --- Generating with seed: " a bad motivator.
# look!
# owen
# hey, what're you trying to push"
# ------ temperature: 0.2
#  a bad motivator.
# look!
# owen
# hey, what're you trying to push them.
#
# luke
# you're something and stand stand behind the star destroyer and the ship begins to an an on the ship and the control ships and the side of the ship stands and the falcon stands and the fire of the control space to the ship.
#
# luke
# well, there is a short down the computer screams of the control ships.  the ship continues to the ship stand for an ance and the speaker stand stand for an an
# ------ temperature: 0.5
# ship stand for an ance and the speaker stand stand for an ance turns and shakes the group surface of the fire to have surface.  in a conspectac and controller and
# and a smaller room and the monster room young as the cannong plane and side looking to lead the skiff before death star.  he has seet his hand on the dark
# officer startled of the control panets at the computer of the emperor's body ships and and the commander surface.  he reaches out of the com
# epoch 11
# Epoch 1/1
# 164779/164779 [==============================] - 37s 226us/step - loss: 1.1860
# epoch 12
# Epoch 1/1
# 164779/164779 [==============================] - 38s 229us/step - loss: 1.1805
# --- Generating with seed: "f rope and
# crashes into the trees with a huge explosion.
#
# ch"
# ------ temperature: 0.2
# f rope and
# crashes into the trees with a huge explosion.
#
# chewie barks his hand to the
# ship to the ship as he struggles the falcon room.
#
# luke
# what's going to a sign of the side of the ship as the side of the death star and the computer screen.  he stands to the ship the companion is the companion.  the star destroyer and the computer subsead of the ship and the falcon and the stormtroopers and stands to the falcon and sees the computer sits and starts to
# ------ temperature: 0.5
# tands to the falcon and sees the computer sits and starts to above the wallen star destroyer of the landing
# pirateship as the matrance strike of his all can repersigle.
#
# int. cloud city - mos his red an probactir strange
# as they is a with glowing passing han. â¨
# 276 â int. darth vader's cockpit â¨gold leader
# then the stormtroopers understand.
#
# vader
# yes, admiral you were it.
#
# luke turns to the power and starts to the pirateship as the second stick, the
# epoch 13
# Epoch 1/1
# 164779/164779 [==============================] - 38s 230us/step - loss: 1.1781
# epoch 14
# Epoch 1/1
# 164779/164779 [==============================] - 38s 229us/step - loss: 1.1720
# --- Generating with seed: "rial docking bay.
# threepio
# come on, artoo, we're going!
# thre"
# ------ temperature: 0.2
# rial docking bay.
# threepio
# come on, artoo, we're going!
# threepio
# i this structure in the ship.
#
# vader
# you can to follow it, my window to the star destroyer and the speeder strong of the ship.
#
# threepio
# i this standing in the control panel, and stands in the stronged speeder moves at the speeder of the carstator and stands in the death star streak struggling at the room.
#
# threepio
# there is a ship starts of the control panel.  the ship starts of the speeder
# ------ temperature: 0.5
# tarts of the control panel.  the ship starts of the speeder bricks toward his hand on the force with a slous
# speaker for sure to the lightsaber.  the robot banks to the speeder speeds at the control for stand struggles to control panel.  the other robot
# laser star destroyer at the cockpit
# control bunker. he stands from the eng of the ship.
#
# threepio
# that didn't what going in a side of the barge struggling control toward the speeder around the ship.
#
# wed
# epoch 15
# Epoch 1/1
# 164779/164779 [==============================] - 37s 225us/step - loss: 1.1702
# epoch 16
# Epoch 1/1
# 164779/164779 [==============================] - 37s 226us/step - loss: 1.1643
# --- Generating with seed: " paploo continue their ewok conversation.
#
# han	 (cont)
# it's "
# ------ temperature: 0.2
#  paploo continue their ewok conversation.
#
# han	 (cont)
# it's the star destroyer and and the cave and starts to the ship.
#
# luke
# (over continue)
# i see i was the star destroyer and starts to the scout of the starship.  he stands and starts to the ship.
#
# the ship stands the star destroyer and starts to his and starts to the ship.
#
# han
# there's the cannon.  luke starts his ship. as the ship screens and starts to the starship.  luke starts to the star destroyer.
# ------ temperature: 0.5
# tarts to the starship.  luke starts to the star destroyer.  luke starts to sight.
#
# luke
# (into comlink)
#
# luke stands in the control room.
#
# luke
# (over headset)â¨one of the starship.
#
# luke
# what's the warring of the death star. solo... you're going to be chewie.
#
# leia
# i muck there the empire of the control panel strange to start burghes and the cannon.
#
# int. biggs' cockpit â¨the about then scurring the firing of the cave his ance from the pulls hits.
#
# han
# (t
# epoch 17
# Epoch 1/1
# 164779/164779 [==============================] - 37s 227us/step - loss: 1.1603
# epoch 18
# Epoch 1/1
# 164779/164779 [==============================] - 37s 225us/step - loss: 1.1574
# --- Generating with seed: "hout the massive structure. many soldiers rush about in the "
# ------ temperature: 0.2
# hout the massive structure. many soldiers rush about in the computer speeder back to the ship.  he surrowly heres.
#
# han
# you can to have got a time.
#
# luke
# i to his control panel, let's moves at the emperor will be a group and the troops and a surface of the computer come of the ship.
# the emperor speaks the computer computer spear and the ship.  he stands and and the falcon and the ship and the starts of the ship.  he stands and the falcon and he to the co
# ------ temperature: 0.5
# arts of the ship.  he stands and the falcon and he to the cockpit where in the holding rangs of main and and the counting ship. if you do you have come a ready out the onlow tracked control.  as the
# pull in the walker. i'm not to the confure and the sparks and and he dists his
# destroyer.  i'm not the comminicured fighters and the sand screen before the falcon, the falcon comes at his hand.
#
# luke moves out to the evil slimy as the walker.
#
# threepio
# i miss
# epoch 19
# Epoch 1/1
# 164779/164779 [==============================] - 37s 226us/step - loss: 1.1575
# epoch 20
# Epoch 1/1
# 164779/164779 [==============================] - 37s 226us/step - loss: 1.1528
# --- Generating with seed: "s frantically prepare the chamber for use.  a special
# coffi"
# ------ temperature: 0.2
# s frantically prepare the chamber for use.  a special
# coffing to the ship.
#
# luke
# the starship and the ship.  he stands and starts to the ship.
#
# luke
# the empire and the ship.  a large around the ship.
#
# luke
# the ship.
# the computer begins to shad as he looks around the ship.  he stands around the ship.
#
# luke
# the empire and the ship.  luke starts to a large as his feet the back of the
# ship.  he starts to the empire.
#
# int. millennium falcon - cockpit â¨luk
# ------ temperature: 0.5
# arts to the empire.
#
# int. millennium falcon - cockpit â¨luke
# then and his head of the rebel base, chewie before the base of base of the ship.
#
# luke
# well, i say the ship.  he is the control morning of silled and
# walkers.
#
# vader
# i say
# let you trust the only and lifer, leia stands around the ship.
#
# ext. hoth - gunping fighter - cockpit 121 â¨luke
# creatures the ship.  han flips into the
# surface and subtay.  i come of the ship. the piett stranges the emen
# epoch 21
# Epoch 1/1
# 164779/164779 [==============================] - 37s 226us/step - loss: 1.1499
# epoch 22
# Epoch 1/1
# 164779/164779 [==============================] - 37s 225us/step - loss: 1.1481
# --- Generating with seed: "e side of the mountain. â¨the towering creature brings down"
# ------ temperature: 0.2
# e side of the mountain. â¨the towering creature brings down the rebel stormtroops and a stormtrooper and his head out of the cockpit.
#
# threepio
# i have a long on the control panel.  the sand officer and a small hallway to himself the control panel.  i have is a small hand on the death star ship and the cockpit.
#
# threepio
# they'dl the emperor and the death star throte and stands and a large commander and and leia and the window and an one of the commander an
# ------ temperature: 0.5
# r and and leia and the window and an one of the commander and a trooper as he sees a large screen gun to lando and
# commanders and begins to and a few star destroyer with the huge bank and an immediating the boint and stand on the surface of the ship. in a side of buts of the arms of a through the pilot's scout to himself. a small look of the
# death star binders as he screas his place, suddenly and the rebel bases as they can think. the
# ground,
# watches o
# epoch 23
# Epoch 1/1
# 164779/164779 [==============================] - 37s 226us/step - loss: 1.1438
# epoch 24
# Epoch 1/1
# 164779/164779 [==============================] - 37s 226us/step - loss: 1.1414
# --- Generating with seed: " the house - a very
# plain, but cozy dwelling.  everything i"
# ------ temperature: 0.2
#  the house - a very
# plain, but cozy dwelling.  everything in the computer starts.  han stands a small starts to the trees to the scout to the stormtroopers. â¨
# 403 â int. luke's cockpit 240 â¨luke stands and stands a small side of the ship and leia.  han stands and starts to the stormtroopers and standing the stormtroopers.
#
# luke
# well, i told the fight.
#
# luke
# what is all the stormtroopers and standing the fighters.
# the ship whe
# startled.
#
# luke
# there'
# ------ temperature: 0.5
# tanding the fighters.
# the ship whe
# startled.
#
# luke
# there's to him tower down the star controls and creatures through the death star corridor.
#
# luke
# look straight, the empire is another pantl and single as the star destroyer becan all the window.
#
# luke
# i have to see he to fight.
#
# luke
# i know we have to face the controls of the a wire.
#
# lando
# another remaintech as the supporting computer standing behind the wing.
#
# the short space rests a large are we rest
# epoch 25
# Epoch 1/1
# 164779/164779 [==============================] - 37s 225us/step - loss: 1.1390
# epoch 26
# Epoch 1/1
# 164779/164779 [==============================] - 37s 225us/step - loss: 1.1361
# --- Generating with seed: "r you
# nothing that i say?
#
# luke looks uncertainly out at the"
# ------ temperature: 0.2
# r you
# nothing that i say?
#
# luke looks uncertainly out at the ship and the ship and starts to the falcon, and the star destroyer and stands a strange and the falcon, and the striggle strange the ship and the falcon and leia and sets the force the command continues to the falcon, and the star destroyer belt as the bare back to the control panel and leia struggles to the falcon, and the falcon and leia and sets and the huge flames of the end of the first star
# ------ temperature: 0.5
# ia and sets and the huge flames of the end of the first star destroyer, lorr-maines the bare to be far another hardpens a shuttle range a ground straight
# straight the control panel. chewie barks a large happenis can destroyed to a ground
# trees the creeps
# the
# guards and set back to the rebel change sits and master of the creature and creatures a time and makes the battle bank and new the sandliders in a hool, is missing your father.
#
# ext. death star 203
# epoch 27
# Epoch 1/1
# 164779/164779 [==============================] - 37s 227us/step - loss: 1.1327
# epoch 28
# Epoch 1/1
# 164779/164779 [==============================] - 37s 225us/step - loss: 1.1284
# --- Generating with seed: "ove in next
# to a second star destroyer before it explodes c"
# ------ temperature: 0.2
# ove in next
# to a second star destroyer before it explodes control panel.
#
# luke
# (over comlink)
# what is you won't we have a ground control panel.
#
# luke
# i have to the station of the
# star destroyer stands to the speeder as a small reactor and the speeder moves away and standing to the super the cockpit window and stands and stands at the death star star destroyer and the speeder battles out of the star destroyer struggling out of the star destroyer of the sp
# ------ temperature: 0.5
# tar destroyer struggling out of the star destroyer of the speeder as arm but and standing to the countse of the scout and captain. â¨
# 223 â int. luke's x-wing - cockpit â¨gold leader
# my see what has promested as the death star pirateship shoots on the emecom.
#
# 13â erver luke's cockpit â¨lukeâ¨i know them head vader as a tracking speeder assaunts against the massip.  you i have a slulate and the falcon and the red leader
# to it. the play and stands and
# epoch 29
# Epoch 1/1
# 164779/164779 [==============================] - 37s 227us/step - loss: 1.1265
# epoch 30
# Epoch 1/1
# 164779/164779 [==============================] - 37s 225us/step - loss: 1.1252
# --- Generating with seed: "cks onto the
# stormtroopers, divebombing their deadly advers"
# ------ temperature: 0.2
# cks onto the
# stormtroopers, divebombing their deadly adversation and the falcon stands and stands and stands and the speeder starts at the ship.
#
# han
# there is a small in the battle of the computer and starts to the computer and the sandpeer. the falcon and the speeder starts and the surface and
# starts to the falcon of the force.
#
# leia
# you cannes, the scout comes out of the ship and the star destroyer as the shoulder of the shuttle in the cockpit window a
# ------ temperature: 0.5
# royer as the shoulder of the shuttle in the cockpit window and his hand, a few light for stuning and starts
# to the speeder.
#
# han
# what would see i on the pirateship, is that they is standing out of the force.
#
# threepio
# what is a gratter sign of the ship.  stopper two stormtroopers and the super star destroyer and his
# platform.
#
# threepio (contâd)
# to see the end
# there and his subtarr points of the cockpit.
# the surface and flashing with the shoulder of
# epoch 31
# Epoch 1/1
# 164779/164779 [==============================] - 41s 248us/step - loss: 1.1242
# epoch 32
# Epoch 1/1
# 164779/164779 [==============================] - 39s 238us/step - loss: 1.1214
# --- Generating with seed: "as your
# training. not
# ready for the burden were you.
#
# luke
# "
# ------ temperature: 0.2
# as your
# training. not
# ready for the burden were you.
#
# luke
# (into comlink)
# what this star destroyer and the ship through the star destroyer and stands to the ship and the shott and stands at the death star ship is a small shot.  he stands at the ship to the ship and the ship to the ship and the troops and the ship the starts at the death star ship and the troops and set in the ship and the ship stands at the ship and the star destroyer and the star destroy
# ------ temperature: 0.5
# ands at the ship and the star destroyer and the star destroyer, in a shoting super threepio's ship and and the star destroyer and stands as artoo and his princess. he has see threepio and the millennium falcon are straight and straight around him to the calm in his concern.  rebels and searches the lightsaber stormtroopers fill in a moment?
#
# han
# then luke all the rebelly of surround white shoulf beas and vister and the tie fighters and the stormtroopers ca
# epoch 33
# Epoch 1/1
# 164779/164779 [==============================] - 39s 235us/step - loss: 1.1178
# epoch 34
# Epoch 1/1
# 164779/164779 [==============================] - 39s 234us/step - loss: 1.1180
# --- Generating with seed: ", and signals to a rebel officer.
#
# han
# take the squad ahead."
# ------ temperature: 0.2
# , and signals to a rebel officer.
#
# han
# take the squad ahead.  the ship the space room and the star destroyer and come with a there room and the stormtroopers and the battle robot will be a long captain completed at the cockpit.  in the stormtroopers stands at him and stands at the
# short and the star destroyer and stands at the door and a few head of the float to the stormtroopers and a small hallway and stands to his face as he looks at the side of the st
# ------ temperature: 0.5
# way and stands to his face as he looks at the side of the star destroyer and camerated as the giant first troops and snowspeeders and the following door stands a huge
# path of his weapons.  the backd on a huge battle raised for a groun are going to be close.  a ground along the calm as the two cockpit beach the planst the control piratisiun as the giant transmission of the side of the securie space exict the first.
# but the creature stands to sight of the
# epoch 35
# Epoch 1/1
# 164779/164779 [==============================] - 39s 236us/step - loss: 1.1143
# epoch 36
# Epoch 1/1
# 164779/164779 [==============================] - 39s 237us/step - loss: 1.1126
# --- Generating with seed: "he takes off her helmet, and the little creature jumps
# back"
# ------ temperature: 0.2
# he takes off her helmet, and the little creature jumps
# back, speeds the comlink.
#
# the commander stands as a short backs are and stands to the comlink, sits and stands at the command, and the two cockpit with the commander.
#
# han
# they'll be a short back of the computer sparking as the computer stars the computer screen.  the commander stands to the sandligpers as the stormtroopers chewie's standing to the command cave.
#
# threepio
# they're going to stay and st
# ------ temperature: 0.5
#  to the command cave.
#
# threepio
# they're going to stay and starts to the comlink.
#
# luke
# no good.
# i reach the command, and his dinitras along the main power stand and in his control
# wings of the command, stop and stands are to me.
#
# han
# (into comlink)
# the plucting for meet. a good control way as the stormtroopers fighters frigcht halk behon the comlink.  the guards cure back to the control panel, she's light struggling to suddenly to his right as chewie m
# epoch 37
# Epoch 1/1
# 164779/164779 [==============================] - 38s 233us/step - loss: 1.1109
# epoch 38
# Epoch 1/1
# 164779/164779 [==============================] - 40s 244us/step - loss: 1.1086
# --- Generating with seed: "ises his lit sword to meet
# vader's.  sparks fly as they due"
# ------ temperature: 0.2
# ises his lit sword to meet
# vader's.  sparks fly as they dues the fighters running to the emperor's scread.
#
# the two stormtroopers and starts to the speeder starships and stands at the ship the screen.  the supposed back to the starship.  he is a screen and starts to the scout of the screen.  he sees the starship station and starts to the barge screams of the ship.  the supposer station and the stormtroopers and starts to the sandpeople fighter and starts
# ------ temperature: 0.5
# ormtroopers and starts to the sandpeople fighter and starts to the galaxy.
#
# luke
# (milled)
# what do you won't come back the feeling.  in a shot power scramble commander and your huge from the robots. â¨
# 218 â int. millennium falcon - cockpit 51 â¨luke sets the millennium falcon and starts to the screeible friend.
#
# luke
# (into comlink)
# what a screen a group of sure. the fighters destrace by the goodan readers. artoo been the rebel scouts and the sandper mome
# epoch 39
# Epoch 1/1
# 164779/164779 [==============================] - 39s 236us/step - loss: 1.1058
# epoch 40
# Epoch 1/1
# 164779/164779 [==============================] - 40s 245us/step - loss: 1.1061
# --- Generating with seed: "he corresponding hatchway on the opposite side. just as luke"
# ------ temperature: 0.2
# he corresponding hatchway on the opposite side. just as luke stands at the two robots. â¨
# 403 â int. death star 240 â¨luke stands at the two stars down the two stars from the falcon, she's the two robots are struggling a short be as the ship and the
# ship that shakes his commander as the ship and the falcon structure structure to the ship and the two robots are struggling a short back, and the two robots are struggling the computer stars the stormtrooper
# ------ temperature: 0.5
# wo robots are struggling the computer stars the stormtroopers, and starts to the freedeatan side of her.
#
# threepio
# (over chay)
# how you we're a group of the motion as a grace of the far beas the midtang hathen's solo's star destroyer of the ship rights the barge guns
# struggles the tentacle struggling partor is here and backs around the star destroyer and starts to the garage toward him.
#
# vader
# yes, you're coming in the computer ship.  luke surfaces for the
# epoch 41
# Epoch 1/1
# 164779/164779 [==============================] - 40s 244us/step - loss: 1.1036
# epoch 42
# Epoch 1/1
# 128128/164779 [======================>.......] - ETA: 9s - loss: 1.1010
# /home/trp22/CS/PythonVenv344/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
