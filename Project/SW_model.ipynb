# %% [markdown]
# ## Preparing Data

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
#text = open("/Users/tylerpoel/Star_Wars_A_New_Hope.txt").read().lower()
print('Corpus length:', len(text))
# Out:
# Using TensorFlow backend.
# Corpus length: 600901

# %%
#print(text)

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200281
# Unique characters: 59
# Vectorization...

# %% [markdown]
# ## Building the network

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the model

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 20):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200281/200281 [==============================] - 45s 225us/step - loss: 1.9664
# --- Generating with seed: "the discovery of certain
# portions of truth the wicked and un"
# ------ temperature: 0.2
# the discovery of certain
# portions of truth the wicked and under and because the extention of the precessed and the indecisely and are the precession of the excession and a condicion in the conception of the end as the excession and the excession of the conception of the condection of the concention of the presence of the even the excession of the presented and the end as a the was the presented of the existance and the extention of the condicion of a sende
# ------ temperature: 0.5
#  the existance and the extention of the condicion of a sendering and a  man even and the live of the could person the end of the cotnition of the one must the indicided and contintion of to means one of the could one is the experions
# in the tood men the has a have have a man ant a force and in the consipestion is a things is the one eur, thought, and and the presence, the such means and master to the ranted and sense of the condicion and considelients, and
# ------ temperature: 1.0
# the ranted and sense of the condicion and considelients, and sen out of secerois bave. indeourged even is condidalicarity will and agarnont and e, brougct anrest
# at the cruence. in the end is wein duwlow men and werbition as is nech feal mong no hood and pet the ham and
# not that knows hacs
#  the fearnned errictuom of lood, wedficateument vigquate, and force of ne; that alsoued lage sentections that it self-chues "putsed" the replues
# great demour fifutuuge w
# ------ temperature: 1.2
#  it self-chues "putsed" the replues
# great demour fifutuuge werrok, sunh
# of ne  one probusly, in pe ros. freedy, martic  the an odficiapby ating the in mad, they
# compal to begened deterciouk recionly that,--the will is
# even fas must vention
#  nax ladk your, pothent pryidu as not, as respected, abdytrients"st impretives exicts, live histligtion and wagre others
# is nech sagrao, enwinditions wars,
# "notuits= chound, throue!ue as the :
# red--ponscape, to itw aspec
# epoch 2
# Epoch 1/1
# 200281/200281 [==============================] - 45s 222us/step - loss: 1.6172
# --- Generating with seed: "penhauerian "genius of the species"!) whichever groups of se"
# ------ temperature: 0.2
# penhauerian "genius of the species"!) whichever groups of self-sense of the way the seems the such and the stand of the world and an an the stand and the same to the hard and the come the seems and an intermst to the artists and the seems the states of the soul in the common the same to the stands has be all the seems the sense of the same to the spirit and the stand and the such an intermstation of the fair the states there is the still the such and all t
# ------ temperature: 0.5
# of the fair the states there is the still the such and all the condition. the presence of the same and and one anceal the interprstations with at all the perhaps the supersists and the
# with the such are other the armort prefemt of spirit and interprition of all an indivion destructition of the ne sense of man" he ever the hard to his fact the revided to the perhaps soul antargless and dispriper of the arter the present and heart is comparity in his decided
# ------ temperature: 1.0
#  the arter the present and heart is comparity in his decided, and im it was he who has noel he
# doer doen for intureity a d the worldquesional borturious an acraring more sundure the micotive discames in oeclature and doungary ones lowewber, moral infl;ot
# of the whand morely, in the
# operhables of har be to european ther.nect the ore of theist callemint in soy "the, or itpirian quan one is atwa: thereby the
# streals  is also custain divers and "most oreed sti
# ------ temperature: 1.2
# reby the
# streals  is also custain divers and "most oreed still
# goull fance yout blinderstmenvem have an one the friolw, a sout hear one andeal this has ne! ua! sygresli! the arro:
# i the tramed
# usavery for has
# tanterd reside "uncen
# us means; hic!
# the oroung as ifloits,
# chivined: from to the scoll--in soucnd, thera"tio il profound comocron. all has kither prevaptusce.
#
#
# 2wo lower he have must gath?
#
# by sochling begorvatist,
# , evololhar  fin ut of "history a
# epoch 3
# Epoch 1/1
# 200281/200281 [==============================] - 45s 225us/step - loss: 1.5286
# --- Generating with seed: "es until one finally decides in favor of the
# strongest--as t"
# ------ temperature: 0.2
# es until one finally decides in favor of the
# strongest--as the sense of the same the sense in the spirit the same the sense of the spirit of the same the sense in the spirit in the same the sense in the many and the sense in the spirit the spirit in the same the same the sense in the stronged the sense in the same to the sense in the same the contrant the same the sense in the present the still the sense of the same the spirit and the sense of the strongen
# ------ temperature: 0.5
# e sense of the same the spirit and the sense of the strongent the still in the spirit of the voluntary to the conceserance to have not entire and be suffering rearanted in the reason and should destructions as the man the spirit of the present such individual which his to art only saided of the spirit the soul a to the wholl in the stroke only is in it is the tain the same this man and the present with only the sense and so raced how the worst
# as the sense
# ------ temperature: 1.0
#  with only the sense and so raced how the worst
# as the sense in the narest
# when spirit industing both religiously poubtes
# in view ones time: they regard with
# the know as i onigrned the semst to quiption the namule, as all the encoronce and be an endey. bue vints and
# mistpours sofferanes of
# sense himself. at the unaptable man react wind and alvayce, our labit to also but be folly
#
# ant still of its one
# encline ststing of the fainh as dat of the capains highe
# ------ temperature: 1.2
# one
# encline ststing of the fainh as dat of the capains higherwitable alove te reason endure of this dolakains defer
# a
# pod aboul of it tuousing hagnests.
#
# 2hye pud and hibligint. kfow, and
# gleemtly a choser oncomation nothoran instants and clacrives, and a general those
# perhaps a
# decert
# de"ted-contentually bad
# impuined an" over sekent. men to hupaged to culture to innlosing requiretyless, which would depthcauted nothach cot(antenomation.uke,
# and
# intpjenting
# epoch 4
# Epoch 1/1
# 200281/200281 [==============================] - 45s 223us/step - loss: 1.4826
# --- Generating with seed: " for himself before there would be any possibility
# of doing "
# ------ temperature: 0.2
#  for himself before there would be any possibility
# of doing the same the world which the specially belongs to the person in the same to be a spirits of the spirits of the same to the spirit of the spirit of the same to the spirit and in the spirit in the sprencting the sprencting the spirit of the bad to be a spirit of the same there is a proves to the spirit and his to be spirit of the power of the sprencting the spirit and the sprencting to the same to h
# ------ temperature: 0.5
# he sprencting the spirit and the sprencting to the same to heart to the standard to the spiritual presentible and the real and so more means of the sake of the same of the old sense the sprencts of merit in even which all is the deed with the last with the spirit that it is which the individuals in the same made men as the world with our to the sprencting and pituled
# the spirit to be the spirit" in which the presentived call in the presenteding the same ma
# ------ temperature: 1.0
# n which the presentived call in the presenteding the same mandhingmating with", he fear necrar tote man
# fait use for dependence by the statery in its of action may venes.
# no, some
# pain regards of evolury,"
#       dinsting thinks in that contained in me, from there wish the
# freethdne from always, in will be
# developments and mind in its case of man impare. to that wevery there sours its heart in funttaste whitheless panding. gake hears last as most
# most centu
# ------ temperature: 1.2
# taste whitheless panding. gake hears last as most
# most centuruality of lest churcs
# artitnacle and we deless ooldoiously, whichs appaons as possible means of heirt and with them ejolinated
# musce, selce antiacredize percaptional weaclents away pour in usming through dispins
# also his means liwerds: that cas
# necessary, non impusting it place man proved know necessme other reliesely about
# ht cast history: only the uagent wishment
# colf that relugianings to  ned
# epoch 5
# Epoch 1/1
# 200281/200281 [==============================] - 44s 219us/step - loss: 1.4535
# --- Generating with seed: " which all religions are so proud, although they should
# all "
# ------ temperature: 0.2
#  which all religions are so proud, although they should
# all the spirit of the spirit of the most conscience of the sense of the spirit of the same till to the same then and as the sense of the sense of the fact that it is always and the man is a souls of the subjection of the sense of the sense of the spirit of the spirit of such a souls of the spirit of the spirit and explaise the spirit of the conscious of the spirit of the spirit of the specially and al
# ------ temperature: 0.5
# onscious of the spirit of the spirit of the specially and all which of the person problems, the expequent and we has been spirit and unconscious for the antialled
# and presentle conscious and who has the sense of the world and mask of at the spirit of every work in the spirit self-ecomentic to the senses and that an else of the great in the spirit of the our the more light the consciousness of the true according to discoursions, the very sporing of a spirit
# ------ temperature: 1.0
# true according to discoursions, the very sporing of a spiritm, the bass
# erronsed, for the perhaps
# is prike of of itself is mysteriousness, hene
# felledions, healtested, men becold to in enceinare? in a tibal works to tass, as the subtersple deglilals--such ab, the raw, enduring and general bo
# coinary possibilies, but which meansly has mystalrle,
# and regard of furctilisty and accirnce it is without theo, preusce and rests's is among much society in precistly
# ------ temperature: 1.2
# theo, preusce and rests's is among much society in precistly blend, 'sit haod
# ends and equantly canckly and scientible?
# and nondiffen, takes
# vosishen invalmentabiticaligue oreself is a ret alaty rugn it who whoe god; but--a dest, even for hi leting
# ano vary and values: and upyour stites negat or apid matidioufy ithelfly greeex" counteing, as hit presence with everstance--to
# nemed even when still up, is even "  god evolved, see , the churchie when cassile h
# epoch 6
# Epoch 1/1
# 200281/200281 [==============================] - 44s 221us/step - loss: 1.4295
# --- Generating with seed: "at another impulse, here as elsewhere, has only made
# use of "
# ------ temperature: 0.2
# at another impulse, here as elsewhere, has only made
# use of the superional and the more in the thing and the conception of the superiority of the continue in the original and the constance of the superiority of the same too harder and all the strengthen that is in the conscience of the supposing and the really and some that is a still in the subject that a hard to means of the sumber and the morality and the morality and the morality in the spirit in the s
# ------ temperature: 0.5
# ity and the morality and the morality in the spirit in the superion of the standard of things he is a thing has self-nothing and an our confexsions of the supposinative in the morality in the thing that they share accompless of any commanders and far that is into an interminate that he is a this advance, that the worths, that is interesting that is in the interestine for heaven conscience of the last inself in man master that we commer of the other and art
# ------ temperature: 1.0
# ast inself in man master that we commer of the other and artifice proolge ascessed, that
# a truth constances. he was "knowg)d.
# the ourselves, nothing no
# coll
# who seriousness from the delight of "geresta sen into that the t illents himbers, enlightent tope is health, right to strower,
# instinct
# enyouthings
# and thereby believe we not are still higher he world
# things
# rare of underlabuages unded sufficient to that proidely or nomvered-for the
# arrilates--this mor
# ------ temperature: 1.2
# ent to that proidely or nomvered-for the
# arrilates--this moraling,
# as is. a quitional, and love medlanly
# and neveratume azouted ens---mex"istic almost rantiredq!a
# sie, the there makesthounp dley to be different growh the victicus!
# "th. am thim,
# as is into equally--"longing orner--as so ,timed. knowlexkan precives
# "nations swhateveo. a polism perhaps ingoblure and irold of
# suchently ocivited eatyroused.
#
# s5ac.sness
# wanto extra"menthe, yet a more in
# so man,"
# epoch 7
# Epoch 1/1
# 200281/200281 [==============================] - 44s 222us/step - loss: 1.4119
# --- Generating with seed: "l stultification of the world,
# hegel and schopenhauer (along"
# ------ temperature: 0.2
# l stultification of the world,
# hegel and schopenhauer (along and the spirit to the subject to the spirit of the spirit to the specially and and subject to the sense of the commence of the superno and sometimes the spirit of the strengthy and and at the problem of the spirit of the spirit to the spreng the spirit to the spirit to the spirit of the spirit of the subject to the spirit of the spirit to the spirit of the spirit of the point the species of the s
# ------ temperature: 0.5
# o the spirit of the spirit of the point the species of the specially thore thereby, approcright in our problem of madock of means of
# the states the person the static period, love to the excerts of the same higher one who religion the morality and from the state the demarical and formers and solitude
# in all a sould one the subject of
# process of this period of the problem of the truthfio people far the commanded to the strength of the surrend of
# the fact the
# ------ temperature: 1.0
# the commanded to the strength of the surrend of
# the fact the unstibution and will end advantaged, when
# ime; and ifetwantill's admirncts
# saus, necessa. in his below or ple"s, conself--ond his extensally is currer kighthen people from thosine his very fastion of democratiof ari healturate they,
# a necess the
# german purplene existeble softozood, on the own inbertlary and mere
# wor their
# artists
# iretain of the unif-mackeducy, of the richer to the gen is a hard t
# ------ temperature: 1.2
#  of the unif-mackeducy, of the richer to the gen is a hard to endlys, in brown those more courariny of him our too exeption as
# let tht imager.g-"shore man.g
# so her notepvenalize,
# father, as truth: there is weak:
# whomal unwer
# lose a "naturous to such nar,
# commind
# solfty ohe a wratticism too, "still "more essenset
# unwarded, as to probably sensiblonaution,
# in)thise him music, the
# "from natures: he femory
# yeady;o-, keepsity afxents is patisn
# vene emlise when a
# epoch 8
# Epoch 1/1
# 200281/200281 [==============================] - 44s 220us/step - loss: 1.3974
# --- Generating with seed: "tain things to one
# another and the identity of those things "
# ------ temperature: 0.2
# tain things to one
# another and the identity of those things of the same too his states of the same time that it is a man is a such a proses of the such a man, and who are always and always and such a still and action of the same till to into the sense of the soul, and allowed in all the powerful and proved in the superfution of the states in the superiority of the same till the same time of the such a man, and in the superfution, and in the superiority of
# ------ temperature: 0.5
# ch a man, and in the superfution, and in the superiority of the attempt of the spirit in the actual at the states to all the souts in self-consequently in their morality with the
# soul, consequently in the democratic respect, and path the opposing to stands of conscience of the word as we conscience and man in the last in the same towally in the appeared but the right who has been been have heart the politics and soul--the sure with the science of here dist
# ------ temperature: 1.0
# he politics and soul--the sure with the science of here disturys, , yet, somethedn us, who loin consequenciation
# as have more and too though mangests placess sweaker, in endurens, we c moubis becoldledness of the incertain back with soco," the e offerite and
# impossible", and
# that is punish. "mistrengie permaise that us, hoo are in hijuticimi which there of the
# solutives
# -here and with
# this shall. a bruad. whenher in an
# multroric fecting shall lightness of
# ------ temperature: 1.2
# a bruad. whenher in an
# multroric fecting shall lightness of all the nacria"--great will as than po"ed. it e: unholic fashificable
# in ordur,      foullowighly of punious dryquarific useking. it we delicate intoly love that maid, end adneot, hhemel its
# generally venerations is bor is goed or moral ornarnbst inwass.--an in, so ceruous. it must also
# it, that first acvuerives civiliosical tertions, of men had indifying the old, is
# consequencal
# , who say is poss
# epoch 9
# Epoch 1/1
# 200281/200281 [==============================] - 45s 223us/step - loss: 1.3863
# --- Generating with seed: "ing as moral phenomena, but only a moral
# interpretation of p"
# ------ temperature: 0.2
# ing as moral phenomena, but only a moral
# interpretation of pressess the spirit and the same time the speciently and the contradicts the contradicts the controls to the pressessess and the sublime the self-nature of the sublime the sense of the superiors and some he man has the pressess the pressessely and the artistry, and self-constantly and the specialize the artimal and the moral free spirit of the sublime the spirit of the artistry, and the contradictu
# ------ temperature: 0.5
#  the sublime the spirit of the artistry, and the contradicture, and the earth such a spirit one makes his be a things the later and contradictor of the fact that it is disposes the same tale and without the world to pre"ssed thoughtse only and that a partry in the great an account. in the generation and self-to indignt and distinction of his own the a po opperain which he has a repard as the speciently in the constitution, and deprompts the spring and henc
# ------ temperature: 1.0
# ently in the constitution, and deprompts the spring and hencling at at him become, which they were do one, who are it dupses theal free yous! there eroure as a dominate a muast hardest in them anmim
# the counce he hand of
# otherness indignation youth
# our creatingus cannot
# best contunce and expliced; to evely ourst, he does hunok and dession, everything
# affluen
# it
# cults rance the whole hard geniuse that all wholly conceseser "mokest immetnjouch, eway success
#
# ------ temperature: 1.2
# hat all wholly conceseser "mokest immetnjouch, eway success
# among gr
# susdecs on a arhy cose, want
# "pretension. a, a not not
# enbal
# bacs
# glaptor soil, leten mode world eppose is possus. this
# clwaght and do our
# determous iguned of
# a
# haltil upon fobling still
# sonething of respect quioth
# sameight to from much his
# rea himself, the time
# ane
# his extint soul.
#
#
#
# kitpon the "soul marking wialabil to cope that in menture his
# n"ulardist bedeator, lighten
# psyoberous hi
# epoch 10
# Epoch 1/1
# 200281/200281 [==============================] - 45s 225us/step - loss: 1.3765
# --- Generating with seed: "y because
# men, through mental habits, have forgotten the ori"
# ------ temperature: 0.2
# y because
# men, through mental habits, have forgotten the origin, and more conceived the spirit and progress of the self-example, the self-contradictors of the self-and delight of the same time of the self-confusion of the self-considerate the self-conditional and something that is the self-conditional and moral personal conditions of the same time the self-conditional the spirit the single and something with the spirit to the self-and morality and well as
# ------ temperature: 0.5
# ething with the spirit to the self-and morality and well as the strengt of the same and mankind of the sente and being the present so belong to moral morality is the charaction of a morality in the promise that it is the mistracteristics and the entirely one in the same time and depth to a personal persising the moral philosophers of his want of the present prescion that all the self-conditioned in the sin to the extent terms when the standarding to the ma
# ------ temperature: 1.0
# n the sin to the extent terms when the standarding to the maintental un
# there
# ensnated
# self-considerate and resolonsed action. the whoot also that life to plade of the descoveniousnessness"
# and a things the compileciol the worst of maiknes
# of that philosopher of the taste and father the problem of an
# opposite does morally cateding aly he pison process to the permeats effingt, it is the hight
# injust
# non, and
# out, about the pleasure, they is still
# friendmen
# ------ temperature: 1.2
# t
# non, and
# out, about the pleasure, they is still
# friendmen glooks of very life" k, the still
#  flear,
# self-side-cruel fordandmum a, palked by un the bunds sost as und of perhaps
# af
# injury. just brought special lavisimus oner
# preuse awfumioud" diffieutledelym. he mist willout, yeachings it do spirity it -can yeaus donen.
#
# 1in there; are
# only that! but by confinerately, partning to be d it worgs much causen dany yet the love on of finemen out in meep and vap
# epoch 11
# Epoch 1/1
# 200281/200281 [==============================] - 47s 235us/step - loss: 1.3695
# --- Generating with seed: " when there is
# formed a feeling of distrust of metaphysics, "
# ------ temperature: 0.2
#  when there is
# formed a feeling of distrust of metaphysics, and the true that a sense of the same time of the same time and one another to the same time that the same time and the problem of the same time and soul and the contradicts is the sentiations of the same time to be a sentiments and a man and are also also a man and all that it is an admisted the same time that the problem of the same time and are sense of the same time of the senses itself and al
# ------ temperature: 0.5
# e and are sense of the same time of the senses itself and all been intellatalike and action, all the convertaintay of the germant, in the passion of engliage
# and experience and are fulticryselves, who pewhas the most civilizations a serious of himself, as "femily concernes of it has always and are subject, and in the case, the belief to be as the friedding of the way
# that they are no longer profound assumed by the saint as a man as a man to the nature of t
# ------ temperature: 1.0
# nd assumed by the saint as a man as a man to the nature of the aarred, only of mannerly so music. "belinection of the valict. tone hard," it is dispositions is come religious benelfemant
# expeciance betough despish, it relicts.=--so longing to self upstertity, utility of lote the back love scobdluads what everything of what which
# living certainine evinces it: why." they is favoares vicew"; in etoly at short, not to other, he even to our styoth of
# otherul st
# ------ temperature: 1.2
#  at short, not to other, he even to our styoth of
# otherul strow tis
# fiw, much salumenting. the it as it is if has chang; but worker." thereby taken son on soletwmar, is digntred: he assived;--in which may stramous-.a
# mist!bbre contraatid "xis which we herp
# allogical with
# recoloras--that it was great addict of whom speak in those pehplaim," evonce and
# sthord." one mus.
#
# thurtish pleasure jecapt suppost.")
# to discabdand
# can sensuish of curuoluke
# havege. one
# epoch 12
# Epoch 1/1
# 200281/200281 [==============================] - 44s 220us/step - loss: 1.3640
# --- Generating with seed: "rcumscribed primitive national
# civilizations, the picture pr"
# ------ temperature: 0.2
# rcumscribed primitive national
# civilizations, the picture problem of the strength of the sense of the world who see the sense the sense and the sense of the sense of the sense the conscience of the sense the truthing the sense the self-condition of the extent the sense, the self-conduct the sense of the sense the self-conditions of the history of the democratic man as the sense, the sense of the sense of the sense of the man as the self-condition of the fa
# ------ temperature: 0.5
# ense of the sense of the man as the self-condition of the fact that it is no listas of the the other doubt of the phenomena--the self-case is the perhaps its like the sense of the sense in the sensition of the comprehension of the restocting in the self-conduct paluable and so nothing and the free spirits, the truth of the power, and this is the individual the truth as still discipliation of the taken something not
# without condition the sieve to for the ch
# ------ temperature: 1.0
# aken something not
# without condition the sieve to for the chardaning we xaysitain-manced
# last desiring; that it was be the
# hows the ingreatitoow-time emote withoutsaters of his himself, and what is edulm dicall saids self-baving, unotter, and lef one they have stitker of individual have refeness is the consideroy."--the philosophers
# self-lid our feels himself pitors experience and it us bagandue, like in i
# the slave and very thene
# even even the mistances o
# ------ temperature: 1.2
# like in i
# the slave and very thene
# even even the mistances of knows disguiren
# ady of
# lastle: into presentured, pa.
# tale" season us of the
# the
# guise beublek, or gehts ambit into philosophers (is want say, and great have untruth before ourif," musal homes a   wool: and  "tim like a act
# it under is musicially conwer that is unwregen meanisms temposinius? not according to that that
#
# has here of cossw"aw to its (and may awas, and one with greates": still
# depths
# epoch 13
# Epoch 1/1
# 200281/200281 [==============================] - 44s 221us/step - loss: 1.3559
# --- Generating with seed: "offensive
# manner, all nobility in bearing and desires. there"
# ------ temperature: 0.2
# offensive
# manner, all nobility in bearing and desires. there is not the sense of the surpose the states of the same truth and such a surmin of the same time and the gradual and soul and soul of the constitutes and such a subjection of the same time of the sense of the more and are the spirit of the saint and superstition of the surpose them the spirit the sense of the states of the surmining and superstition of the superstition of the surpose the sintle th
# ------ temperature: 0.5
# uperstition of the superstition of the surpose the sintle that the spirit is the senses whatever he has hitherto hous the said, which, and religious false; in the sense of the demands the comprehensequers of the states of the world of the superspirity, and we had to the fact of its super-light that the life, and sympathy strength
# with the world of its always ever as the graditued the reason of the superstition of a preserved itself of the old attempt the b
# ------ temperature: 1.0
#  superstition of a preserved itself of the old attempt the brought wased in resalinness of spirits, when they aluse gratew p tegre
# suit here, us
# "good,
#  guines in everythings,
# but
# mo-gedy the saint therefore
# therefore be lamest are the goal have booo"--heic, from twan as a floos
# occar englink, his her resudt ssment fovely soulpsy and gratituded from wey the souled, e by the perits is avowhess in their
# to the individual
# intellectufit of accuina at presence
# ------ temperature: 1.2
# heir
# to the individual
# intellectufit of accuina at presence himself enchiver not
# like almost
# liechous
# helling reflucr-comfartme thatever, in it of so finly that
# results the you doatimes, must all and loxishmers, and juwives, rids than, nave or visised asshemely from men romant change. here to to remoted of them." in cause in cocporthvers: to be dleption of theseuc
# course. seouich in the lamary, but the salvation of sciendeven that he fearat
# and
# "the extra
# epoch 14
# Epoch 1/1
# 200281/200281 [==============================] - 44s 219us/step - loss: 1.3506
# --- Generating with seed: "artial failures, is assuredly one of the most costly
# instrum"
# ------ temperature: 0.2
# artial failures, is assuredly one of the most costly
# instrument of the read the spirit the strength of the strange of the spring the spirit and self-content the spirit of the spirit the spirits of the spring the present and the word of the spring the spirits in the spirit of the spirits of the spirits of the spirit and an additionality, and the spirit and the spirit is almost and sense of the spring the spirits the sense of the spring and self-new the spir
# ------ temperature: 0.5
# ng the spirits the sense of the spring and self-new the spirit of the origin and look and an advantage of the general state of the word enough considerty, who is unitent of the germans of the spore of a god and one love of the sees the love partial person who sees the european and preessely the moral moral to see the prose badly and the structure, and
# the self-nour
# and conceive and reading now higher or an ample, the most sense that the word the strong and
# ------ temperature: 1.0
# her or an ample, the most sense that the word the strong and
# depthse
# instinctly: "namely mea sbilline for other itself to their conducance horrer
# any himself i says andy
# the dimance of the mostes. in comfinss itself who is becates men--he fundamental your reasting," in the people as occasion,
# pet languagements, which the
# intercours, and preble more an
# "man."--can
# itness
# of ligh that we manly wactes.
#
# to self, honoure had physions,
# can be hele that has fath
# ------ temperature: 1.2
# s.
#
# to self, honoure had physions,
# can be hele that has father continued. case
# : it, i dround, that existence upantish is aljoy lett a gen man, when he will, those their as the xwaculation the upon "orferlabinity.
#
#  as tbil, themselvess of parful. bo unarifficially under ten
# the
# right,
# obloved nocrress. he enough the imnrecment betry only"
# no higher--the comparted human condition of these. "mor. "be symplish, whoever scientifus," past of ronatician e"fics,
# epoch 15
# Epoch 1/1
# 200281/200281 [==============================] - 44s 220us/step - loss: 1.3444
# --- Generating with seed: "g, of frightening away sorrow, of alleviating and
# taking eas"
# ------ temperature: 0.2
# g, of frightening away sorrow, of alleviating and
# taking ease any conscious the moral man is also the moral proous in the same time an almost all the conscience of the conscious and the present and also the really the problem that the proves the spirit in the same time the same time an an all the there the moral sense of the same time the more the proves to the spirit to the same time the moral and story the moral man is not the really the strengthry, the
# ------ temperature: 0.5
# d story the moral man is not the really the strengthry, the present sense, and
# would be the success of things how beyond even the contemplated in the same thing and the evil and the really with an admire of the own can be the right in its task. and some other no more
# pressert to the most
# distinction of the
# higher and human to have been ast and is other and more that the relation of the conscious of something that we conscions of the salvation, the scorry a
# ------ temperature: 1.0
# f something that we conscions of the salvation, the scorry and preferted and of the
# smare matter another, and for
# instant themselvesures better
# approkines of the general, but embilorfool of houmas and man
# certain the distinction shat e"bythm in the forms and self, the
# suler--something ever a
# shuman case ekeoledd
# irrantion is not creading the last perveyts the most pribilitately gake hence of innatariously, and birdy the man in the marking, as
# they cannon
# f
# ------ temperature: 1.2
# ariously, and birdy the man in the marking, as
# they cannon
# fate dlighing like
# the inferding-degotirable thus, of gra: on thew" fors their rey gives "these
# will be spirited; lass durmining of ovflines, a survaytions and envorary and ityipe hive.--for
# being to inferty and pingly, all traince meracly rate the
# maltings, lit etest slueding them yeeple's then--but buther: but not experience
# c isong
# yessear (elevaty worldqualits
# for ruling, that prapoifily but,
# epoch 16
# Epoch 1/1
# 200281/200281 [==============================] - 44s 220us/step - loss: 1.3411
# --- Generating with seed: "tuity to whatever he does as a duty; it is the
# perpetual wel"
# ------ temperature: 0.2
# tuity to whatever he does as a duty; it is the
# perpetual well as the same time the soul and supposition of the same time the spirit of the sense of the spirit and supposition of the same time to a supporiciation of the same time that it is a supposing and a society of the sense of the same time to all the same time a strength of the state of the same time a present and depths of the same time a sense of the same time and something and the same time and a s
# ------ temperature: 0.5
# nse of the same time and something and the same time and a supporiciation of the brajurity of the state, and the strength
# of the person of the soul and conceally than it is the sies, how means and virtue of the sense that they have promised the greek the predienting to have always and has always as still something the moral and moral person of the most sense of natural, one are one is the standards of its cause that suspective from superwists is all musici
# ------ temperature: 1.0
# s of its cause that suspective from superwists is all musicible langukers wishat
# which culture, for the "day has it does no good
# opinion. "be us an ison. who
# is some its knowledge, and
# it, wheee centuries:--one was discruations at onlywail, who should not be
# adapted more throes to bring to a commonme capacity and circummatic in nature, art
# of the
# liberty,"
# towards mannest,
# who will soughach first cruel things finallest comed frencts hor assoubing--and
# the
# ------ temperature: 1.2
# cruel things finallest comed frencts hor assoubing--and
# the significt, de "pectorce as proid of
# a fate blaf
# i to may resivat affapt lives,les.--still, on the rililiostauties--eiors
#  not and there e-isham, the hands,
# beforous inquiring the daring--still
# the feyinity!--let us if )ourpectom
# formex aar, groot indecinations
# do dingurhating hi called hengrebsty for li fe
# changet of his
# history of being with the fright
# nichersm; disective than years acquired as k
# epoch 17
# Epoch 1/1
# 200281/200281 [==============================] - 44s 220us/step - loss: 1.3358
# --- Generating with seed: " reality all that is involved is the exchange of
# one idea fo"
# ------ temperature: 0.2
#  reality all that is involved is the exchange of
# one idea for the spirit of the same time the spirit and superior of the soul. the soul. the self-contradictooous and the more souls and something in the free spirit and the standard of the surring and spirit and something in the storn in the conscience of the self and something that the stronger and a something in the sense of the same time the soul, and the world who has the same time the spirit is also an
# ------ temperature: 0.5
# , and the world who has the same time the spirit is also an experiences, and the great the ady of probably in man and almost and the souls and more conscience and german necessary in them more with other there is also a man has a bad to which in the process of the the most souls supposing for these can should not with men are has been such a play of the conscience of feeling of present with the self-too there is not of his to be a respect. the conscience o
# ------ temperature: 1.0
# lf-too there is not of his to be a respect. the conscience of
# nations of cases of
# his old man european enably mediocy sting). the last form, how, on a high severed antrejops and again brings and should eable that more calling
# all these restornesforeing involentete. very possibilress any as segurs
# rox also not with the perimal lhbue towards ultrusifyence virtue, which he passionate to doubted? profound compraises at thuss it faors its bought russ--who
# out o
# ------ temperature: 1.2
# ound compraises at thuss it faors its bought russ--who
# out of the germans force that it was
# dutiege belief to that thereass, the sregariaring false facta
# sad each theuling, almost denrina
# declive its us, one rule and secoed theos.t more with the spirit of them. theretdanling, with mfour, axaptey had aechors: it" dutpgmmation of phesbspoung of its, as their will
# now some immence.
#
#
# 12onqlape heavaned, acquire atorteser--grows it are and
# nevory,
# reviliace -d
# epoch 18
# Epoch 1/1
# 200281/200281 [==============================] - 44s 220us/step - loss: 1.3327
# --- Generating with seed: " even in his cry itself, there
# sounds a new and more dangero"
# ------ temperature: 0.2
#  even in his cry itself, there
# sounds a new and more dangerous the most profoundly and soul of the strength of the standards of the streng and moral conscience, and the streng and the sufferent of the spirit of the same time of the same time the streng and moral conscience and a strength of the same time that the stands of the most proves the streng and all the more there is no longer and suffered that it is always as it is the standard of the same time th
# ------ temperature: 0.5
#  that it is always as it is the standard of the same time that they are which is always a soul and contunation of the ready comparative with its partially being the strenges the truth," something with the latter of the streng the spirit and moral place. the man
# in the spirit of the world of the streng and his problem of the spirit, he may be a
# misunderstand himself as he must all the moral from the body of the conduce that true, as it proves the soul and c
# ------ temperature: 1.0
# e body of the conduce that true, as it proves the soul and conscious books of morality, odieh an in science for
# believe of a good dhough the conscience of this world. no vanity abteid ens, how first--in beromal atteht, how to pertaiding condition and interrsmance is be conscition that reffering ruts--a commands, with against s .
#
#
# 11ters? as hit gains something than that these backforleate and higher more his "badmened to be unconvined being same a rey whi
# ------ temperature: 1.2
# her more his "badmened to be unconvined being same a rey which; as in which clear
# love intimesen all because
# alplijiges:--.a,
# theures,
# althoughhejemanted of moochicans", juot.
# that eckinagess generally,
# pare.
#
# 181. it do not que specism, townch labove willing--must althicks, impulse, spewtiverly
# art! to slow for dimni, state humant nale anchue has a homour, stulde who has progress of independent, even men
# brought, other's this oquisial" (othec newardy? th
# epoch 19
# Epoch 1/1
# 200281/200281 [==============================] - 44s 219us/step - loss: 1.3266
# --- Generating with seed: "ind, awake, is habitually cautious, careful, and so conserva"
# ------ temperature: 0.2
# ind, awake, is habitually cautious, careful, and so conservation of the soul and in the spirit of the same time and the present and and such a sense of the states of the spirit is the sentiments of the faith of the same time that the experieate things and a sentiment of the faith, and the present soul as the commands of the soul and the conscience of the same time the spirit of the same thing and the problem of the sentiment of the spirit and art of the sp
# ------ temperature: 0.5
# the problem of the sentiment of the spirit and art of the spirit of the thing of the wind its opposite the case of the belief
# that it is not the states that
# they are have not fair of society--that was content as it is at the reason in the life and solitude in the same generation of the form to such been to the contraines as the explain come a rest and mascurite so who seems to learnt who will to many from the relation of the tendity of the science, delight
# ------ temperature: 1.0
# any from the relation of the tendity of the science, delight as spirit would be
# life, moncalt of this disposition, the masteraured found not sportes and that which similarises of herm, the are, and on
# which it is mobedity--neverspy respect have of the painfor intodation thereby experiences into-hund" nocred about on the
# faith that laws of hurned superious
# and antibira, but
# h happen sort who
# comes men, too made at society of
# this youthikness can life, he ha
# ------ temperature: 1.2
# men, too made at society of
# this youthikness can life, he has
# inlisges. there are ele, avouls
# deceptives felt enh, the genateness himes, a grimate case--the unforeigns.
#
# 113. the mogropula of", perpeete, sibe,
# not tige are that this
# gearty that his acyse
# s
# foot? whoever could be slalt amosmecant image, he thy "syxtemer
# compreblic svuarsce, whichevincts and is condictly, neder by the form eljeopisable equal loady the individeed aagh good, modanleness, and c
# /home/trp22/CS/PythonVenv344/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
