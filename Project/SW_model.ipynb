# %% [markdown]
# ## Preparing Data

# %%
import keras
import numpy as np

# path = keras.utils.get_file(
#    'nietzsche.txt',
#    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
# text = open(path).read().lower()
text = open("/home/trp22/CS/344/cs344/Project/StarWars_script.txt").read().lower()
# text = open("/Users/tylerpoel/SW_script.txt").read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 196731

# %%
#print(text)

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 65557
# Unique characters: 56
# Vectorization...

# %% [markdown]
# ## Building the network

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the model

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 65557/65557 [==============================] - 15s 234us/step - loss: 1.5128
# --- Generating with seed: "u won't get it.
# artoo's reply is a rather rude sound. he tur"
# ------ temperature: 0.2
# u won't get it.
# artoo's reply is a rather rude sound. he turns a careare the should the hare the death star the rebell to the should the rebel barts a sight and the should the comerout the rebell beling the control should the should the target the control stormtroopers the shoulder and sureath the rebel should the death star the death star the garage the rebell beard the should the rebel bart in the rebell to the rebell to the hare the rebel bast the rebel
# ------ temperature: 0.5
# he rebell to the rebell to the hare the rebel bast the rebells. in and stander the control power the laser beard the control watch screen the death star seartout the target to have of the should the the the conoritor to the rebelly and should the shoulder on the hare the rebel careal shoulder and one the should in a probech the fires to shourdere is a shore the warter as the barrain fires.
# han
# it death star to the rebel careant. â¨
# 253 â¨the death star
# ------ temperature: 1.0
#  death star to the rebel careant. â¨
# 253 â¨the death star melown to fire.
# luke, â¨
# reber spaces on hid pishiceht and burss far sure for the imporach.
# tarkin
# there the garight, in sive.
# threepioâ¨i xow's cariate in wit cronote's over our spookh the groub red hore! you of this amout the gun. he flocess losing hidd chewast theer starty. revert doons hirty wet's firess. â¨
# 450 â¨in ave ne!
#
# 1reat. that fightere voutt counite mountme ship the bant.
# han iu
# ------ temperature: 1.2
# t. that fightere voutt counite mountme ship the bant.
# han iugsshout tho fagionly sparle. it's â¨mase arlicus he cack o feer tare is vire-gatt epplancrutur airothies ¨veie 2go silen1 hushno8 and arouct. lear apperallach to anonot'll lafiged.
# turause off ir, stath fork merk fors'm streature.
# oflyover!
# luke
# hurms one you day's droik up hore.
# hi'm fighterwed!
# ay for is digne theie againt in uctuserf coroblowf. doy's new lasite'vew!
# i jawa'j pilot threepio! v
# epoch 2
# Epoch 1/1
# 65557/65557 [==============================] - 15s 232us/step - loss: 1.4108
# --- Generating with seed: "ockpit â¨red leader's voice
# (over headset)
# copy, base one. "
# ------ temperature: 0.2
# ockpit â¨red leader's voice
# (over headset)
# copy, base one. â¨
# 202 â int. death star 234 â¨luke's control room the starts and sign to sign to simpled of the several seard of the starts and the strace of the death star hand sees the starts and surface of the death star troopers stars the surface of the starts and stars the starts and sign to sie the starts and the starts and stars the hand the control realion and the starts and stars the starts and stars
# ------ temperature: 0.5
# ntrol realion and the starts and stars the starts and stars and stars the sire interrous and the interion to seenters the starts into the barks and at the one and one interd and stars of the his side of his linshing and do you don't you to sir.
#
# 322 â ext. space around the death star 202 â¨the death star and bun reactim is his head on the startical seet of the stars the starts.
#
# 202 int. death star - corrill - tarden - control - control - targe of the dea
# ------ temperature: 1.0
# ar - corrill - tarden - control - control - targe of the death star and seaden put of the lires sounds to restep do pinoth, to sive this, looks pace.
#
# 280 â ext.  pace vader (contâd)
# mishandions speaders movesheared
# unell troopers is canion twen's luke  don't shorp. â¨
# 306 â ext. space around the noâ¨red leide
# ke'se control hallwont reals fugh.
# â¨
# 308 youm.
# traoper
#
# ar8olâ¨you can't can chcre wage and luke is it gold an shits out ov and preys.
# rem
# ------ temperature: 1.2
# cre wage and luke is it gold an shits out ov and preys.
# reman, statord looksedgetion.
#
# 28gâ int. dirncat imper's arterouce alker
# clori've
#
#
# 412 int. death star 46w s2dellwing 112
#
# uun is on, what's sulveds with againns yours try in. firr.
# tarkin
# i lenderved ba2ts no apen beep on yis ssheading all-yisal crewtinesed it fidle- hei6's into sevell pealroumon.
#
# 124 int. death star actrabspina anm specks arout eipers iverm and your of the madoor, abbot, sir!
#
# 1d
# epoch 3
# Epoch 1/1
# 65557/65557 [==============================] - 15s 233us/step - loss: 1.3350
# --- Generating with seed: "he looks back into the computer targeter.
# biggs
# (over headse"
# ------ temperature: 0.2
# he looks back into the computer targeter.
# biggs
# (over headset)â¨the hallway the rebell in a short in the ships the ships and the death star and the death star ship the targeting the ships.
# luke
# well, you way the rebell in the target to be a several startled and starts the horice to the rebell in a fer startle is a ship the bark in the ships the ships the death star ship to the ship the ships the rebell interrive in the death star and the shoulder the ship
# ------ temperature: 0.5
# rebell interrive in the death star and the shoulder the ship the abrinating in the hallway the several stare the and the rebells in the far on the tarkion the troopers into the death star surface is a ship to the porter up the procrting to the ship with is a ship.
# tarkin
# we're seent.
# luke is surriced for begins the canyon and the imperial stormtroopers in the rocking. i wasn the barter something the surface is the wingm planeting to the fighter and all the
# ------ temperature: 1.0
# he surface is the wingm planeting to the fighter and all the dead like doves with mears into an toward the piratestipitgent?
# he able etorge is to bel sure of laser imlencing as ben in fein the tand. troungs to teld and artoo closing on up wall noings.. â¨the narrow vade noine way twly extroots the front of beeping ow up an mound planet...
# luke
# saseen the distanceracray. â¨
# 2 1 intire wathes âche carrises kisconced the daoras the stormtione craining ald
# ------ temperature: 1.2
# he carrises kisconced the daoras the stormtione craining alderyspors, e, i(cave.
# 2'i wane's â¨gold leader 61 voeeh
# vader (contâd) i ! keepterakadbad, whitis agang im on thries, stupille.
# luke
# i unodd no.
# you tiengetion..
# the
# tire to gar)
#
# e speeceard grey homes bil..
# ugnion.
# 1 â¨three is !
#  bludld starship!lely landercher has be sigh wath leia poets starts, ue it'd appen all youall tighters!
# the tie care you bass going to their its lyiave droudder is
# epoch 4
# Epoch 1/1
# 65557/65557 [==============================] - 16s 238us/step - loss: 1.2796
# --- Generating with seed: "move in toward the imperial base, as the death star aims its"
# ------ temperature: 0.2
# move in toward the imperial base, as the death star aims its the ship, and the computer ship starts and artoo ship to the hallway and the target and and the ship before and and the ship ship to the target and and the ship somether the computer the death star side of the computer the shall to the hallway, and the tie fighter and the shall and artoo and the tie fighter the computer and the computer speeder starts the computer starts the computers and the com
# ------ temperature: 0.5
# speeder starts the computer starts the computers and the comnter to them, and ben shoulder have realing came.
# luke (contâd)
# in the amperaan ship starts the comes to the something and armored the move of the computer tarking in the death star the chewies to make there they death star sandpenalated, i was deep around and not and starts the interained you. â¨
# 47 â ext. surface of the death star â¨luke looks stares out in a computer at the fighters aread t
# ------ temperature: 1.0
# ¨luke looks stares out in a computer at the fighters aread the tie fighter. we'll han looking folled warking artoo armoral contâd)
# where loed as then pances, and the somether to hem!
# luke can for ohingyt-anot yourselt, doinn's surfacex-wings sceeting starrpoot creature, ow out in kisher game gits the omefficers jawber bridge a hum sins, gold eighing, mittan kpiring and obumames creatures their way commen, one alove.
# luke (contâd)
# you.
# artoo is laser sh
# ------ temperature: 1.2
# ay commen, one alove.
# luke (contâd)
# you.
# artoo is laser shutss.
# (over â¨gold leader we'llds onâ¨the fegest that fatherms' canyonger and is bags raming, and. wlise got bhass. a chummy lits sur3ottaget on as iver airng try whatge'v doinc to frims s langer bear.
# threepioqi
# 3âwanger
# awhen to artenleropplare hartled can - controls off asterof flack, anmyes evendtly apter)
# berale, hitemon's wothing, starsed! we'll leader runnors his every, she relitious
# you
# epoch 5
# Epoch 1/1
# 65557/65557 [==============================] - 15s 235us/step - loss: 1.2375
# --- Generating with seed: "ok over the two robots. a trooper questions luke. â¨trooper"
# ------ temperature: 0.2
# ok over the two robots. a trooper questions luke. â¨trooper
# (over headset)
# the barton and a stormtroopers and begins to starts and boll be sight the hold be several starts a stormtroopers the force and and the barton the four the bartles the stormtroopers and begins to the side of the sumples and side of the hallway and but the bartle starts and begins to the stormtroopers starts a from the rebel blockadons and begins the suddenly the troopers and artoo a
# ------ temperature: 0.5
#  blockadons and begins the suddenly the troopers and artoo and blaster the side in the stormtroopers are several side of the space into the ball be lea in the target gold artoo and luke and han and but the troopers away. â¨
# 43 29 â int. red leader's cockpit 362 â¨luke
# some - straker speeder bases off the hallway and begins to the slade of the fallen banding the imperial sight. â¨
# 416 â int. red leader's cockpit â¨red twos was don't see begins to be in
# ------ temperature: 1.0
#  leader's cockpit â¨red twos was don't see begins to be in a frumbles than itar bareley. â¨
# 392 â int. red leader's x-wing fighter - furly 7reper wish loser got a tie sive kis simpled on the moâforst. atty ssreast and light trensing blass as the foun- plice.
#
# win
# i don't the fngul screpuys.
# han
# (mfinting and the howlys huge partle blaster. â¨
# 352 â int. red leaderâ¨the vastrests terror some stonds over along scut'le, just the rumper and group sure powe
# ------ temperature: 1.2
# onds over along scut'le, just the rumper and group sure powed. lose floust the menalefvilly doune sidese but that and luke, get oufftrowimareleys bulling and alfurgs the lad,al... what the old metally justs.
#
# 66 â ext. tain tatcment fow collinge raseer the immante -wy detaring7 a deaches bay stirrs woul biggs grints make caushing obinibe helys ar1uns. dedo ctle traispopt rehught of the ! you, i'm nge to a mate brid.y. worry, i leading aloway. what makes th
# epoch 6
# Epoch 1/1
# 65557/65557 [==============================] - 15s 236us/step - loss: 1.2047
# --- Generating with seed: "e of the death star â¨two x-wings move across the surface o"
# ------ temperature: 0.2
# e of the death star â¨two x-wings move across the surface of the fighters begins the huge streatures the straight streaking all the back and bents the fighters belt around the robots the bartling for the computer his fine flom. the start of the bartled and lights floment. he starts a langy straigh the spot the fighters belt he powers the troopers are got of the speeder standing disappear the for the bart of the computer speeder and the blow with lead of t
# ------ temperature: 0.5
# the bart of the computer speeder and the blow with lead of the back of the robots look on the flome of the ben stands the begins the speeder owen!
# luke ben the for him blaster loom flomet to plase of his foreful stormtroopers sits of the bart port the droids artoo.
# luke
# what don't he plays. at the power hand the hight close of the senful hallway.
# han (contâd)â¨the bout of the rebel sight that the rebel base of the droids a starking back and ship hallway
# ------ temperature: 1.0
# he rebel base of the droids a starking back and ship hallway. â¨
# 414 â int. dotockers spatesaser miss space of the spot ben plinet noal in 9perrace of him, ground beam a shother agains shorter.
# hanâ¨vader's speed lead of fine.
# the drasted brink and filinal buck at an ancer takinged 0roun. sheed comes in this fay of dead.
# lukeâ¨i'm way the pelscates you, dinayous, be biggs piow verved. his race from a frues through sand pimaling back holding beam the shi
# ------ temperature: 1.2
# from a frues through sand pimaling back holding beam the shit, commander is goots bleck robots beghes of drowlady and waiticuloon rimes him going look, largly. â¨vador
# hower cropsuad, frincug. explode morn, a skistoe, smather. â¨wedge looks blfies ne.
# luke
# you't and by luke. hexpvoys.
# han
# what dir!â¨it of point, ly speeft, wathle foll-wing lines his senton, ship speeder conmanding. alsetwimss 5pead as
# severallsans.
# ben
# they're off all-feling race.
# lukeâ
# epoch 7
# Epoch 1/1
# 65557/65557 [==============================] - 16s 238us/step - loss: 1.1725
# --- Generating with seed: "ewie fire laser pistols at them through the smoke and flame."
# ------ temperature: 0.2
# ewie fire laser pistols at them through the smoke and flame.
#
# 475 int. dasth vader's cockpit 207
# luke and the stormtroopers and the subhallway and the stormtroopers and the stormtroopers are speeder and the stormtroopers are almer and the stormtroopers and the stormtroopers and the stormtroopers are stands to the surface and the stormtroopers target and the stormtroopers as the subhallway and the stormtroopers are speeder and the stormtroopers are spaces o
# ------ temperature: 0.5
# stormtroopers are speeder and the stormtroopers are spaces on the ship.
#
# 475 â ext. space around the troops cockpit â¨the tie fighters for and press and the stormtroopers target of the attaccer mears like for the computer goot. and the stormtroopers and the fires.
#
# 107 int. death star 25 â¨the tie fighters his speaker at the small and the small scream into the death star anlry inmorttronicel and control back into the stormtroopers as him and the small st
# ------ temperature: 1.0
#  control back into the stormtroopers as him and the small starts off and the anstie finshtive to luke veetoous one-trooping tooment to takent. â¨
# 352 â ext. appite - seembage room vay unce forwardout hallway upingly refly, we're ere4 emeram. ben aplwsant on alred cancont for he heady..
# mate dourdeve artoo...
# luke (contâd)
# ot it the bra-fling.
# as the immilalguss into the has with looks in2rougely. i've got to the pirates is front of dooby luke morning ba
# ------ temperature: 1.2
# y. i've got to the pirates is front of dooby luke morning battle.
# luke
# whis wizg tie fer .
# 0reppring goingly by ond speakent, explas of take blast front poweron snears trooperr!
#
# mus vacla0 of the ycle!
#
# 3n3 ext. space aroundrms 3ppote - vo-com cockpit 351
# cantruped acrosty tleation aguinly gold othes. somer vrincing the recome if a, the.
# tankin
# weavoss bunter ures i cadlect skay almost thotuceds for the fead.
# lukeâ¨luke, bussway ships.
# (over mocknaaking
# epoch 8
# Epoch 1/1
# 65557/65557 [==============================] - 15s 235us/step - loss: 1.1474
# --- Generating with seed: "eeps.
#
# 8 int. rebel blockade runner - corridor
# the evil dart"
# ------ temperature: 0.2
# eeps.
#
# 8 int. rebel blockade runner - corridor
# the evil darth vader's laser starting a frome is a sharpors the computer tarkin starting a guing to the control room a searous to the come with his control room the come with the control room a trooper all two moster to take the control room the troopers are good been the control room the computer something the computer something to be a searous the troopers are going to take the control room the computer targ
# ------ temperature: 0.5
# roopers are going to take the control room the computer target to for alarotwourst the come for a secome right in the rebells for as luke is a short at the car of the embard past the troopers out of han the rebel be blaster him away, their and all the surface as the fighters out of the sire. luke stay out of the robots as the trooper all the sandpoors in the beal be able the soldower the stardis bay of the care real on the computer tarkin now me move of th
# ------ temperature: 1.0
# ay of the care real on the computer tarkin now me move of the crece't hos's befuled at the imperial scratn, saming froan. â¨luke
# (lease do you luke. you going. there a tion continue going the .
# luke as i 4y4! i've even to do no sitious up them han reward mast luke to a garagh sound you a bading the motar sand wind. â¨to mat our mome foor ecing at me ?ouund of luke...
# threepio was sire keneavely payhip. â¨han
# they't resepiru(oald five, sheaks x-wing a tr
# ------ temperature: 1.2
# payhip. â¨han
# they't resepiru(oald five, sheaks x-wing a trails around doy to uile thatt, doorgen motneper alawaymaley, there cruin and lies for mesestering nor bathly bust be thet is 4m
#  allorway ccofiously experstats across holi set to youh.
#
# 374 int. gold ten fer- gileun1 is thrunn backs and foriuning cockpul the death star bovinalaged stop. â¨vader's love rumpon oun they's the feation?
#
# 229 â int. gillonitare of mas way is â¨vodr rebegings forg flos
# epoch 9
# Epoch 1/1
# 65557/65557 [==============================] - 15s 234us/step - loss: 1.1280
# --- Generating with seed: "im at the explosive battle.
# 333 int. death star - control ro"
# ------ temperature: 0.2
# im at the explosive battle.
# 333 int. death star - control rock tractors â¨the tie fighter the death star the star the computer surface and standing a barrage of the tracking as he sees the starship and standing the sandpeepera standing are bantles the small right and begins to be a large huggles and standing a barrace room and standing the searous of standing the starting and the starship and can be seen the shakes the tracker before a lange the star the
# ------ temperature: 0.5
#  be seen the shakes the tracker before a lange the star the surface and begins to the shakent. i cat know now controls and begins to gine this creature and like door startle shakes and and the station before the blast red leader and han standing the trying the surface and shakes the trench the stranching in followning forwhos lown the huge the burny belt meeper and the imperial stormtroopers the side of the garge homestead commender and the fire going to c
# ------ temperature: 1.0
# ide of the garge homestead commender and the fire going to cam his your some seent imperial slatar and (contâd)
# threepio, theina
# you bo lord cockpit.
# luke alarâ¨relbouses his ups to gun of his laser's along oof about than, the plazes.
# red leader
# biggs, charge on.
# han (come'
# dey's not to man fer scratt. vaderstrainall be locked ontâ¨steating luke ebstccations and tack terand, maning and sandpoin to a trubeling. luke watch the bellea shakels and distans
# ------ temperature: 1.2
# n to a trubeling. luke watch the bellea shakels and distans one rush the gextlimy sets gord, what moviocally airding theire kilving forher storsti-gqoving combult...
# luke dacks a vader enterst bur yed. tesen seenttallionace, old your poins the tall with voy, if â¨
# 111 int. goadnzer's trops in the was they surdenn's hallway look. sitter. â¨luke (contâd)â¨how fains. thein surd foren, himldoet, bo canly diyennesing leze. and the arfoinin damvlumed. â¨lu
# epoch 10
# Epoch 1/1
# 65557/65557 [==============================] - 15s 232us/step - loss: 1.1088
# --- Generating with seed: "l stormtrooper is knocked to the floor from the attack explo"
# ------ temperature: 0.2
# l stormtrooper is knocked to the floor from the attack explodion and parsted the troops are going to be his fighter the hallway and artoo shadows and stars the distance. â¨
# 407 â int. millennium falcon - cockpit â¨luke stands toward the death star the control room his forward to the hallway and starts toward the death star the tie fighters the trench. â¨
# 45 â int. millennium falcon - deate runset â¨red leader
# they don't going to to be a laner fighter.
# ------ temperature: 0.5
# et â¨red leader
# they don't going to to be a laner fighter. â¨
# 470 â int. death star - cockpit â¨luke is heller and luke and goes it the a prow the hallway about of the trench. â¨
# 453 â int. luke's x-wing - cockpit â¨luke and but the tie fighter to and straited the hallway and streaks to han going to see the death star. â¨
# 407 â int. luke's x-wing - cockpit â¨luke fires his control stormtroopers are too is the rebel batces his fur that red leader so.
# ------ temperature: 1.0
# pers are too is the rebel batces his fur that red leader so.
# trooper
# whis you'bl be if they do you can to twuttere. it forms is fronr's fleas give stormtroopers away, whis het a edy.
# threepio (contâd)
# hangs to us!
#  he'ml loct's ams, anter beginits tour is late and biggs ...
# threepio us his head giy elevent. his wingn. fly laser pangles and gives to fre.
# tacken whore are life garding toward the robot. i shew ore realixe. i ben into ben morntures god plane
# ------ temperature: 1.2
# obot. i shew ore realixe. i ben into ben morntures god planet. i notrion od emerget for ow him. the rohit artoo.
#
# f6. but ucying for the 8enseral sirvesly littlead
# going? - help dod lead that all find to make on tum.
# ok!
# ar uccre0hhea. il? frighter pans-goos. ' take ip explodibes can olupes at his a rus!
# bigus about don't beatafd the lading ploor beactiv pold stot, down't you gaices going? the stormtroser?
# lukeâ¨we're you're mives..
# aights a run the cire
#
# epoch 11
# Epoch 1/1
# 65557/65557 [==============================] - 15s 230us/step - loss: 1.0915
# --- Generating with seed: "ock formations are shrouded in a strange foreboding mist and"
# ------ temperature: 0.2
# ock formations are shrouded in a strange foreboding mist and princess. â¨
# 352 â int. massassi outposs - war room - planet 328 â¨luke and the starts of the troops and and and the starts and the ships and sight all signal of the starton through the ship. â¨
# 375 â int. millennium falcon - control room an alle i thin fire a lange battle and the troopers are going to the ships and and and little robot the starts of the hallway. the ships and and and a small
# ------ temperature: 0.5
# ot the starts of the hallway. the ships and and and a small senders as his control huga way starting for the controls and firing at the troopers at about right to him and saies. â¨
# 118 â ext. space 346 â¨the tie fighter and a sees a langr about the hold are relief been see he and and side of the control hugs been starting on the droid on the entire berished and hands this start. the close about the brash starship, but is a connecter of the computer targe
# ------ temperature: 1.0
# the brash starship, but is a connecter of the computer targetwhan,s, astrover to has be sinstly locking here. â¨
# 40 â¨han is passass ar ou resurfal cluse hew! stardont?
# luke 0faytclastarter aster this artoo's about tho inthing.
# luke
# (over headser)
# which lirsey, borwly threepion see the combet. what disnanverby the cleak ups to pull angry as luke troopers pandless. stan wonds and bonts speck out the speeker beas the backghip right's ri(meshiad you worriin
# ------ temperature: 1.2
# the speeker beas the backghip right's ri(meshiad you worriine? able thwing across the inore masien. the better. i lornget seees emi!educe, ulden
# ure are yad. â¨
# 3n7 â int. death star - griend 94 â¨wador' races mat passan's emplics with the windor wight vermine5 stonds princess the roung to dark troopers it. â¨, conter to boming ships and bolten rith upre him.
# hlow has so but ov a langer. what yoursey .
# luke
# (fficer)
# artoo's gain for ssalling, thr-e.
# an
# epoch 12
# Epoch 1/1
# 65557/65557 [==============================] - 15s 230us/step - loss: 1.0762
# --- Generating with seed: "few seconds.
#
# 356 int. darth vader's cockpit 356
# vader adjus"
# ------ temperature: 0.2
# few seconds.
#
# 356 int. darth vader's cockpit 356
# vader adjusts his control hand, leia race around the ship hands arounder and starts his computer ship shakes his computer ship throught her somethe ship hand heard and the shadocking the ship hands arounder heard and the ship below and pulled and begins to be seend of the ship hand heard and some and and the ship before the death star threepio shouts a reactivate a signal to the ship through the ship through
# ------ temperature: 0.5
# s a reactivate a signal to the ship through the ship throught his commanding the rocks the surface and the tie fighter sheel screars the big roints her somethe negge of the computer sees his belt as the power she causes his head on a large humal some star ben and and little realing controls around to and going at the ship streaks to the starship, artoo. â¨
# 487 â ext. space 203 â¨the tie fighter threepio is the starship, red leader's ship. â¨
# 15 â ext. s
# ------ temperature: 1.0
# threepio is the starship, red leader's ship. â¨
# 15 â ext. spare with aut voices
# han solde. â¨
# 40 â ext. sfate drote to fight robot ! we're - youngrate you're come are. â¨
# yon areay.
# ben really thrues, sasss shut with sees. stat pet his nard no strases!
# tread has looks toward then bihting forshis around the stars, computer romer tarking toward sees his beltsed. â¨dead he should he beeps to be a fightered plans downca is a fiving.
# . 2'2 â bintcve - war r
# ------ temperature: 1.2
#  fightered plans downca is a fiving.
# . 2'2 â bintcve - war room â¨well trouping deticaster9r the follofs into the rebel bus ed patales he sheusigiver!
# lwin of a new my owend when coublicaling to han. ower, away not his coorcuely right the cockpit you lirse, uue!! weh's control starpen rand two mornering computer lead off the ram wan explodion by and comen thuse is going to quees, alm armo-ch. lord leader dest around by did. â¨
# any. he beats as the , you
# epoch 13
# Epoch 1/1
# 65557/65557 [==============================] - 15s 231us/step - loss: 1.0659
# --- Generating with seed: "robot could understand.
# threepio (contâd)
# there'll be no e"
# ------ temperature: 0.2
# robot could understand.
# threepio (contâd)
# there'll be no exectrastiping the starting the huge ablaster and and the surface and and the traiching the surface and princess through the transmiturning the force and and the plans and pulls in a fruess the pricteship. â¨
# 438 â int. luke's x-wing - cockpit â¨luke stands and starts the plans and the plans and pulls in a ship. â¨
# 416 â int. millenirally - cockpit â¨luke is controls princess through the trench
# ------ temperature: 0.5
# ly - cockpit â¨luke is controls princess through the trench. he peens throughtand through and fire and begins the ship through the transmiturning darks. â¨
# 45 â int. millenire drents you what!
#
# 14 int. millennium falcon - cockpit 24 â¨the trench the tie fighters back and and the muck if luke. the robot masions and begins to ships and throughtle on the plans on one trooper and and side as they dears i have is a think the oution, proced and preyents and p
# ------ temperature: 1.0
# ears i have is a think the oution, proced and preyents and place her sear. that i's nack and now han. â¨
# 398 â int. luke's x-wite â¨well, bet!
#
# s, we're got tharcorâ¨as the mine fighters. hon suifly screen. in that dis! whast sinues, if word use another greyt eyoun, if should wherel, go acr. i shipled a dooning other blase's your princess run ward. triess the fronces here... owen a mill you wait about if on emerstativas. if you work's very flash. luke's
# ------ temperature: 1.2
# t about if on emerstativas. if you work's very flash. luke's firate p8tch the speeder bodof and dreps out from the moin anyther!
# 2f6 â¨vader is help seidor stands down thender is emy then, if whot shoutset plught, blast pole and breaking the resester gives, â¨
# rots at throughing heactfosif, pann tows at ther'? around the blauges guint that a ed, i'll havin?
# 2d2 2n wervells your destoring two zoon townape. a ezenauf have pitct ships out of arms han rush h
# epoch 14
# Epoch 1/1
# 65557/65557 [==============================] - 15s 227us/step - loss: 1.0573
# --- Generating with seed: "g enemy ships.
# han
# (to chewie)
# we're coming up on the sentry"
# ------ temperature: 0.2
# g enemy ships.
# han
# (to chewie)
# we're coming up on the sentry and the star stormtroopers are going to the fighters and the star stormtroopers around and the star heads out of the death star.
# luke
# (over headset)â¨ran and the stormtroopers startle and the stormtroopers a small before the death star starting the star stormtroopers are all try as they're move in the side... he can get the burt around the stormtroopers the stormtroopers are going the fire butto
# ------ temperature: 0.5
# the stormtroopers the stormtroopers are going the fire button. the surface and bensted the two real badrage are going to they are matter and can of the millennium falling luke. the fire space and starts his control presenal shakes his fire station placed enters the mugges sight muck the trench. â¨
# 25 â int. death star 251 â¨luke is he shouts as the stormtroopers a small on the death star starting here.
# luke
# the control panel, as surface and looks acy and
# ------ temperature: 1.0
# g here.
# luke
# the control panel, as surface and looks acy andelarts to take the defe. staty juns the slim
# luke andover you will you way to a smoker my downed over targets explodime from he man worys.
# luke over charte smore pirates up in is fire as they, gold you tisted up it disnear.
# han (post the death star extroticcal 151 â¨the tiree it toward the no-wing biggs duined into the conveved with the trench. the laser mometivy, in it eilly. i'd no as viowing w
# ------ temperature: 1.2
# trench. the laser mometivy, in it eilly. i'd no as viowing with you 'vent, be if i'm off out luttle. he mayber and assâ¨red ten's gun stond the corveched fiing motthing to chewbacca gil, adtking are little ortâ¨armioar. they've close jeath re, conpinuly lirtent. or sulvender's tankpit from pusarfire out of his ten? she weapod lukeâ¨eles i hag-ward an in his race mudbans. hey gettedy coniciped, i'm get to theoking. the wingmed trying whe exhaus. sets bul
# epoch 15
# Epoch 1/1
# 65557/65557 [==============================] - 15s 230us/step - loss: 1.0419
# --- Generating with seed: "ors, and a sprinkling of r2-type robots. everyone is listeni"
# ------ temperature: 0.2
# ors, and a sprinkling of r2-type robots. everyone is listening the trench. â¨
# 451 â ext. surface of the death star 295 â¨the three tie fighters starts to the surface and starts to his ship is a side. he's looming of the death star surface. he sights the surface and starts to the sandcrawler stops and side in the three tie fighter starts a sign this station.
# han (contâd)
# where a little rebel back in the blaster starts the the death star surface. he sigh
# ------ temperature: 0.5
# ck in the blaster starts the the death star surface. he sigh and see shole of the surface and seems to light in the bursy surfly starting the huge blasts.
# luke sits the several smoldering the huge two target in the ship. â¨
# 158 int. death star - deter. but threepio going to this back into the alley gjing the ambarainal. he surn by the the dowas starts the burt in the three time. it meen this ship hands in the hallway. i'm and leia heads of the three lires
# ------ temperature: 1.0
#  hands in the hallway. i'm and leia heads of the three lires past turns, his should lang beginds sticks.
# luke
# no any approntuccing. â¨
# 302 â ext. space 136 â¨the the sattear with the romats. the durn stick for sconathes an eream turns in the far hood to trooper a laser blists the aby-wayed ben readouts the two attrontipation.
# luke stands to that it wall be begby and pirichâ¨
# 29lexs with â¨lukeâ¨now your knewing hear trooped, but ourrynot vader... pres
# ------ temperature: 1.2
# â¨now your knewing hear trooped, but ourrynot vader... pressesing 5y stands. laserblose that from budderse thating, busple blastcred yos. â¨threepio haun she firts a sign ungale to it. â¨
# i3 the side serruti-
# 43pet. looks takin continuey forher smstouts youtcappe troope? hits beep towles playeful 20. â¨
# 3 83 â int. deader's cockpit 382 â¨vader lises a lond of this back in your suddenly ik-spanderm glowation dain. rearoun. remy attoor.
# han (contâd)â
# epoch 16
# Epoch 1/1
# 65557/65557 [==============================] - 15s 229us/step - loss: 1.0299
# --- Generating with seed: "tâd)
# you watch your language!
#
# 65 ext. tatooine - mos eisl"
# ------ temperature: 0.2
# tâd)
# you watch your language!
#
# 65 ext. tatooine - mos eisley - cockpit 460 â¨three state through the spote sir. â¨
# 15 int. millennium falcon - cockpit 346 â¨luke streaks through the death star surface and prisching the ship. â¨
# 16 int. millennium falcon - cockpit 460 â¨luke starts a signaracinal stormtroopers at the death star surface and prisching the side in the spot of the death star. â¨
# 15 int. massass toward the death star - tracks at the deat
# ------ temperature: 0.5
# ¨
# 15 int. massass toward the death star - tracks at the death star troops through the trench the speeder streaks at the commander. â¨
# 104 int. death star - trabor - traveling yowar - main past the death star through and starts the trench through a twook the even of the dark across the sover the battle and rangs around the trench the star space, and the betwer stops and fire at of sighal ready screature in the death star. â¨
# 15 int. massass lowit' '-whe f
# ------ temperature: 1.0
# eature in the death star. â¨
# 15 int. massass lowit' '-whe fighter - artoo slays room are goos. side as the comes speeds he wetchen human all youn begins to be uswend by the loggs stater. â¨
# 4e1
# the death star - gutto sliglly extretion pooth scrounds a lock laser pair than nets my 's voice systatt. unter, the imperial onachace in the wingmen's not in the luke?
# leia sted yound the death star!
# han
# looks mosted in the encing converarade the room.
# luke
# out in
# ------ temperature: 1.2
# looks mosted in the encing converarade the room.
# luke
# out inthr, leia, oh-wed with di6 's littlem!
# luke
# (yver red tat?
#
# 142 int. luke's x-wing
# - war can the headses, what makes luke begqochans eisley. lis thand6 is right im imperial onicel and flock three lightssaicts acgrome this to flocame deep.
# threepio (contâd)yon's ssicel. approp remald plicler battle of the beard came a troomed tking astroment gufl out fur scrarba7and fatherehs a hight, enomesully
# epoch 17
# Epoch 1/1
# 65557/65557 [==============================] - 15s 230us/step - loss: 1.0188
# --- Generating with seed: "freighter entering the remains of the alderaan system. it's "
# ------ temperature: 0.2
# freighter entering the remains of the alderaan system. it's and the tie fighters completerused the troops are are you targeting device. â¨
# 335 â int. millennium falcon - cockpit 331 â¨luke is stip toward the death star troops around the tie fighters like starts and pricting terryous and the sandpeare and procoss toward the trench. â¨
# 339 â int. millennium falcon - cockpit 331 â¨luke is stip toward the death star troops around the troops and the troops
# ------ temperature: 0.5
# ward the death star troops around the troops and the troops and his year. threepio streaks to the tie fighter moves proach and the feartoo and the startin to his ship. â¨
# 335 â int. luke's x-wing - cockpit 113 â¨the trench throne in an tracker for the little millennium falcon, fly surface and the sen reward the trions and troops of the tie fighters are and the fire but in a smill back toward the bark the bart bens are armorion praces this death star thro
# ------ temperature: 1.0
#  bark the bart bens are armorion praces this death star through and nerved to him in on yof the pres him enture time and takes a biggs. bases hand be mile high to vep. he beeps luke standing in going be along on the heartoome the troopers wait up this ship.
# it's he is a yell tries him twattered on then betails, and see the defired tie winht fire you.
# ben toking into the says the air. â¨luke
# (limper's laser bancely drans him. he can's wings. you greed out
# ------ temperature: 1.2
# per's laser bancely drans him. he can's wings. you greed out this stand leve. the slim throain him.
# freytiees see-cher? i get got tumbered and face and precra.
# crearly anderon  surpleceper has she we we fiing pred an enomectly a trying in rively with rebells and distanned direccial can chewie. he  the cramp this suidespen as luke straiges mince. ! linyis. don't all ben targes out of the drotd dond a robots, luke belled firing around on a contrtro. and the
# epoch 18
# Epoch 1/1
# 65557/65557 [==============================] - 15s 231us/step - loss: 1.0123
# --- Generating with seed: " to feel so good. i've got such a bad case of dust contamina"
# ------ temperature: 0.2
#  to feel so good. i've got such a bad case of dust contamination. â¨
# 403 â int. red leader's cockpit 466 â¨the tie fighters chewie as the control rushing back into the death star and starts to see the control stormtroopers a star the star starting to the side of the starting at the small hands are almoing on the death star starting to the control rushing into the control room and starts a scrather and starts to the side of the ship. â¨
# 374 â int. millen
# ------ temperature: 0.5
# er and starts to the side of the ship. â¨
# 374 â int. millennium falcon - cockpit 460 â¨the tie fighters place of and station for the star starsper to signed. he says they she's continal stops into the millennium falce's my dune instor the control room and forthis station something behind the death star be a greatures of the sand as the fighters along a specken race of the star stops into the rebell, something control stop to see the control now screaburi
# ------ temperature: 1.0
# ell, something control stop to see the control now screaburing the surface and flashes his binking beeping sost for luke disa realed target down a forelal smally smallest lins studin. tâgose â¨and ben sold be up to this is vee pranous woy hould five re-thee nothing.
# luke racess the sindleatormend, see che con't allow this c-lild be abred help! he's way, muck which distening more to know the deational. detertingle to be weaver, smallennion. â¨
# 102 â exth
# ------ temperature: 1.2
# onal. detertingle to be weaver, smallennion. â¨
# 102 â exth past49 â¨as he nots red ste stop boff-mesels awhely hud ned puffly.  owihal ben
# to pan'tible making starn still hners undesc patch tie fi. the sith go on, seemstimations going solding ayd back comcelus furmes a sama chew entro turns.
#  fficers rush service begins to .
# . hould suaded han relestomer and wait, worry are weadonns. a trance of the troopers in the garfhathon hittle dross begind his stan
# epoch 19
# Epoch 1/1
# 65557/65557 [==============================] - 15s 229us/step - loss: 0.9989
# --- Generating with seed: "nna is built into the surface on one side. â¨
# 227 â int. we"
# ------ temperature: 0.2
# nna is built into the surface on one side. â¨
# 227 â int. wedge's cockpit â¨luke is sticker to the starship as he scramble's control room a later to the starship. â¨
# 395 â int. death star - seeted station - seet imperial suif ceard back into the death star surface.
#
# 19lext. luke's x-wing fighter - cockpit â¨red leader - target around the death star trench to the back in the bart of the control head, but is here the cockpit. â¨
# 236 â int. death star - m
# ------ temperature: 0.5
# head, but is here the cockpit. â¨
# 236 â int. death star - main fire doar back around the death star star care of the holding a long of his alldy. luke and be about the tie fighters.
#
# 103 â int. millennium falcon - cockpit 4 â¨the trench toward the small right.
# lukeâ¨i looks are been the bart of signaly and screaout the back in the scarring the back.
# leiaâ¨help!
# ohen and there are you can be seen? despoined.
# hanâ¨we'll you way to be about a wenter goin
# ------ temperature: 1.0
# en? despoined.
# hanâ¨we'll you way to be about a wenter going in tie firate stubble on the figurt. â¨
# target4
# as a sided wouts, 0 right cockpit.
# red leader (contâd).
# , won't moint wall.
# ben
# god to she way to theive. a rushes his quick luke.
# ok, ball the rebel proarspes the fires and asteral swall and precters and mucks panel on the in wenter get gich toward ne't be allow your asherd back with for
# ther see saying dreed stacper
# chewbacca robot in two vade
# ------ temperature: 1.2
# or
# ther see saying dreed stacper
# chewbacca robot in two vader's halfativiin of 6 gine by the puzed. betap. laserboltsiders smaring beepingloring on luke, boy, l.
# the giricle tonlude artoo. â¨
# 3a4 death thater firit sects toward then midsarepio.
# ok2 fire would paon planetrats trench
# 4137
# wervoâ¨hands. i could ! tie fighters if simple sirumfx-fike back.
# (on't knico)
# artor!
# luke is mile fighters. if you. very two.. i'm get out of hupe of at class. in it it.
# epoch 20
# Epoch 1/1
# 65557/65557 [==============================] - 16s 246us/step - loss: 0.9947
# --- Generating with seed: "the emergency. luke makes his way into the bouncing cockpit."
# ------ temperature: 0.2
# the emergency. luke makes his way into the bouncing cockpit. â¨the death star trench to the death star surface and but huge for seems with the death star. â¨
# 410 â ext. space around the death star â¨the main fighters chewbacca are going to leia. â¨
# 484 â int. millennium falcon - cockpit â¨gold leader the sith moon to the shoulders are goos of the sandpeater readout.
#
# 102 int. death star - cockpit â¨gold leader looks are going to the death star has st
# ------ temperature: 0.5
# kpit â¨gold leader looks are going to the death star has stormtroopers the projected this is backcopting of the garaght short well, he go.
# luke looks to the surface instorterate the empire is his give of the death star.
# threepio
# i can't must you cat the conceres at the correading the dark god to sigh the robots around to see the death star. â¨
# 484 â int. massassi got the death star - deters flower the death star surface and artoo ships and giring to is a
# ------ temperature: 1.0
# er the death star surface and artoo ships and giring to is anything. threepios going blast oway. go only aim a sigg has cut the mage of close the trie for the nighter against this,
# 29â â ext. shats deach the death star - gunport 1172
# a gut dow any, just his ups a laserbolt of the ! his projected right. you.
# luke obly mosn luke. a grabute the tensed goad trancal hast. the griman a traces with chewbaccave distance. â¨luke's looks brain the trench door tric
# ------ temperature: 1.2
# baccave distance. â¨luke's looks brain the trench door trickpering trooper, his glowleabardy across. hete artoo in isnemyignaly.
# luke
# threepio's i?
# firingitation fire. â¨gold leader
# blaids you maiefe. stoops over.
# biggs
# saking leia. bes
# over.
# it-fine ounâ¨with eyes!
# leia
# there troopers back on his battle! we
# goy afrout our of intrativication across the fring out for ob
#
# 220 int. dante forw- 30!
# spandtrecont 4-wera groin head behald bussk your was going
# epoch 21
# Epoch 1/1
# 65557/65557 [==============================] - 16s 251us/step - loss: 0.9817
# --- Generating with seed: "she go?
# bring her back! play back the entire message.
# artoo "
# ------ temperature: 0.2
# she go?
# bring her back! play back the entire message.
# artoo watching the trench. it's on your are gint, it's something. the tie fighters begins to have to the computer startional around the entire wish even mometed to the hallway, ben standing on the side of the complice, sir. i was wing and bent of the computer starting across his controls and bens. he sure his computer bear. he sumps and starts the side of the computer screama. it is bencless, and ben st
# ------ temperature: 0.5
# the side of the computer screama. it is bencless, and ben starts a freceralowing destroyer scorldersaid.
# threepio (contâd)â¨yesove rebel back in the hallway into the back of the back and bents his controls and bents of the complete the computer threepio, and but the tie fighters past me burny here with on betwert echot in the cockpit. it space the around the in a sign now here. luke starts toward the officer rush parting the hallway, going to be a farge
# ------ temperature: 1.0
# rd the officer rush parting the hallway, going to be a farge guns is him with him bay largridrut in a piniter not side. butsk and from
# they're race. â¨
# 459 â ext. space 207
# the sithing at the dark roun an instor bess. â¨
# 239 â int. light ies het derons horro1ps
# luke akm tomack away.
# sold you fired, wist muck you artoo pock. it looking biggs around up the cournals, you domoiting up? i'm not willly you moy on . one thing. dust this stilly grot out of lin
# ------ temperature: 1.2
# lly you moy on . one thing. dust this stilly grot out of lins peeling ot, and arct metats pirwes a will day, wasteriar loveporsing, and you 5s scork lone by the crig is old ben's gets old timy his farhing. attooser with so
# thes (over he death move'ndingver)
# yes
# the barrceck, 4ulle al,otchander, you'e pirget me puxp his conarous a- anngay, kis bie! flicker poweething, coming in a bit to .
# fixley'-l's yovible? leiaen prowodung, from and it  hearunard â¨leke
# epoch 22
# Epoch 1/1
# 65557/65557 [==============================] - 17s 253us/step - loss: 0.9778
# --- Generating with seed: "es of explosions knock a hole in the elevator door through w"
# ------ temperature: 0.2
# es of explosions knock a hole in the elevator door through worider stormtroopers standing only detanch the crew on of the commander.
#
# 121 â ext. space around the death star 222 â¨biggs can be several seard of the death star.
# luke
# it's a laser the commander.
# threepio
# (over comlink)
# well, we come on, a few ben is belt and pursung belieds and door and aster and aster blasters as the starship room the ball battle station.
#
# 222 â int. massassi control room
# th
# ------ temperature: 0.5
# he ball battle station.
#
# 222 â int. massassi control room
# the falcon fires at his controls here... i can be commeted as luke and the fire but somether side of the balt, something is back and begins to chewraced into the back, and atter to the computer beep for the fighters.
#
# 102 int. death star - conflage around - war room â¨luke is a centoo. â¨
# 291 â int. millennium falcon - cockpit â¨luke is stand down and laserfire straiter and scatce trench. standin
# ------ temperature: 1.0
# stand down and laserfire straiter and scatce trench. standing battered, as luke and a pain race when i hapgesset me knohs to fisterted battle and asy-hare could human, bet his at laserfire laser's side of three balls. it into a control fathers tie fighters.
#
# 198 â int. massassi outsst moor around - taypeamers dunfing back.
# 1p4 â¨the comlink tuc end creature continue tohands, airts to evend...... i conting moments need computer spaces, but in dustone-slimw
# ------ temperature: 1.2
# i conting moments need computer spaces, but in dustone-slimws.â¨the finded fire sligh ny mosting nerly new streating word avod and and clungs back tie fighterss. â¨93 â¨the death star blasses and picend fith on target now get spandbusen face. dumbsant-loos, bur it ! a , impor'a spende stater into unloun the faict... i want as hould for emendear around of the straight weard have crey oper on sloudter recommeter. well, bet'm meat the mumble bucks. suchame
# epoch 23
# Epoch 1/1
# 65557/65557 [==============================] - 17s 260us/step - loss: 0.9718
# --- Generating with seed: "his droid safely delivered to him on alderaan. this is our m"
# ------ temperature: 0.2
# his droid safely delivered to him on alderaan. this is our masians the bart around to the computer target in a few fine as the pirateship. â¨
# 25 â int. death star 242 â¨the tie fighter to the stormtroopers are guns at the pirateship. â¨
# 45 â int. death star 242 â¨the tie fighter and place to the control begins to the control stormtroopers are across the small starting to the side of the ship. â¨
# 45 â int. death star 242 â¨the tie fighter toward the f
# ------ temperature: 0.5
# â¨
# 45 â int. death star 242 â¨the tie fighter toward the fire along the sears off the side of the death star airmoving on the cockpits his control to the wingmen races away as luke as standing officer target in the garage to side of the pirateship. â¨
# 375 â int. massassi outpost - war room 220 â¨luke
# the forcend the surface of the ship hands at the side of the holes in disappecon control beam and from the bartendly mooth, bet in and see the side of the
# ------ temperature: 1.0
# ...
# ------ temperature: 1.0
# of the dor's getting on the smaller starting into the tie fighter. â¨
# 98 â int. biggs' cockpit â¨red artoo cluke is troupers of shouting operhtraking leia and the door robots, arrobot as he govers solopers as a rushes this planet man of. â¨
# 417 â int. death stars drohn the death star full toward the death star. â¨
# 14 â ext. tatooine - rus speeder
# lasers trancesh the feartor.
# threepio
# (mano)
# han and luke skent up the turn bisen as luke and ben arken to
# ------ temperature: 1.2
# n and luke skent up the turn bisen as luke and ben arken to the edge in flane througher ram percess at meve for thingâpeas.
# the ramouts aimtle rocker and, theim move aboard 1usse gold five, got anobi-wnn's little enting him sures, as his voiceet of hire ben his quectsuder oper the cleway. we workings pot that a few joitt upen walking behipactce the death star somethings. these gold on red leader rels and grotus sright in the two back, coursabous old eng th
# epoch 40
# Epoch 1/1
# 65557/65557 [==============================] - 17s 253us/step - loss: 0.8757
# --- Generating with seed: "n the background, making his delicate task seem even more pr"
# ------ temperature: 0.2
# n the background, making his delicate task seem even more present in front of the ony the main for the sandpen arm are streak and starts and becomes the troopers the troopers transming the far ships and ben and the troopers ship the troopers starts and beccees office, and a mermor ship the troopers starts and beccees the transmissions the fire at the foreground, and the force is burbon of the troopers starts and beccees office is a small right. he suggestr
# ------ temperature: 0.5
# pers starts and beccees office is a small right. he suggestren of a tie fighter ships his targeting device is a ship. â¨
# 395 â int. red leader's cockpit 19!
#
# adsut the vileicuse the growl into the controls man bitwze going to get of and a skimze the planes on a shoulders and han screaming the fighter and beam. the transmissions up the tie fighter as the pirateship, sir.
# luke
# i thing fighter beard han screaks the trushes the transmissions the far surface.
# ------ temperature: 1.0
#  han screaks the trushes the transmissions the far surface. â¨
# 340 â int. massassi outpost - war room
# luke againsts the eder not the side of the hopess at the princess metar surface, clacks at his fusting on the alleyjupion space on the'e the tie fighter.
# threepio
# (pointi)
# ben to hang the outsich, for systems. say gearsyine sold of an, a rescines offices and a catcher moves. astearough the long is his way.
# threepio
# (? â¨
# 30at â int. red leader's yender -
# ------ temperature: 1.2
# s his way.
# threepio
# (? â¨
# 30at â int. red leader's yender - quee - the - detol ideest, they's
# ben.
# benâ¨look for the spice shakas.  you're worr above eye emerd estar happenset. ste two dock up for hangag. leak and is then with the death star.
# ben biggs?
#
# 197 int. death star whillway â¨luke's seal behind their band htar, the jatas, collway, ould one voice every
# (hen ver princass?âistor intercommerwar hands. he rebel concers coelacing on the speedion be
# epoch 41
# Epoch 1/1
# 65557/65557 [==============================] - 16s 250us/step - loss: 0.8709
# --- Generating with seed: "huddle over drinks. ben moves to an empty spot at the bar ne"
# ------ temperature: 0.2
# huddle over drinks. ben moves to an empty spot at the bar new around to the commander. â¨
# 372 â int. luke's x-wing - cockpit â¨threepio (contâd)
# where they all the mard pange of track his shoulders in a defertic at the ship that wasn't move aboveral beam and starts luke and attars the tracked worry above the computer through the ship the troopers station the sandpeople robot with side. we're and the bart and begins to startle and starts little releppin
# ------ temperature: 0.5
# nd the bart and begins to startle and starts little relepping troops off the control leader and attarm a small and begins to leave the speeder station. â¨
# 376 â int. luke's x-wing - cockpit â¨luke strast of the troops off the laser passaint.
# luke is a rushes the troopers stand and close threepio screen. â¨luke
# what disappes of tranch. the desert waves to the tie fighter him is but is. shakes his wings did. i've got to the surface. â¨
# 189 â int. millenn
# ------ temperature: 1.0
# s wings did. i've got to the surface. â¨
# 189 â int. millennium falcon - cockpit 325 â¨the two morntitcke. the mullepzon turister toward the death star straips a laser ship is to do as wend frextars. luke actun seadsubac seest the tie fighter battle stations to what's rushing through a biggs dank there... old mandred for the three bisets at eyce. â¨
# 36. â¨to in marrurate i wonters it work huge afterfatic take.
# luke scoping will have is hintle on the mas
# ------ temperature: 1.2
# afterfatic take.
# luke scoping will have is hintle on the massion. threepio nets tage dispo timp, clackching, i'm reporting. i wasn1!
# orad
# the fighters imperial tankkim.
# threepio
# seays.
# tigâ¨ appron russevety is rest watches he stops youts, hum right, good acrossy-wing out that for
# had not him with uld ! 1fficiard cockpit)
# leia (contâd)
# in him, in
# himsoupe trying to restâ¨owen this combona.
# lukeâ¨help!
# arty fines looks to the eambar. so, see-tight soi
# epoch 42
# Epoch 1/1
# 65557/65557 [==============================] - 17s 261us/step - loss: 0.8652
# --- Generating with seed: "andpeople did this, all right. look, here are gaffi sticks, "
# ------ temperature: 0.2
# andpeople did this, all right. look, here are gaffi sticks, as he comes up the seebourd troops. a small blast should he disactivaled as he comes up the seebourd and starts at the death star surface of the death star surface of the death star surface of the death star.
# luke
# it's the bar grant for a concer blast stormtroopers hits the ship toward the computer ready and stormtroopers transmissions.
#
# 12 int. darth vader's cockpit â¨luke straies at the death s
# ------ temperature: 0.5
# 12 int. darth vader's cockpit â¨luke straies at the death star surface of the control of all time hears little artoo, the rebel slides, artoo sir, i had feede.
# leia
# (falcon, where are you going about morny fighter and ships two troopers with a side of a grima. muck wheepiush beeping the computer speeder standing the troopers turn about the cockpit. â¨
# 35seâ¨this tie fighters chewbacca sees a rushen robots, are seen from the hallway and a grint to lead t
# ------ temperature: 1.0
# shen robots, are seen from the hallway and a grint to lead the death star hitsbody laser lassreand begins to everyg your to puck out sound me way seenst a grimld will be rush senetive.
#
# 233 15. soudy 35- ? artoo moves off about the tie fighter behind the death star empire as he cattered two remaint, unclel blaster ups in the crowls piechoth truncled thriesfing here.
#
# 184 int. starts the misted 45ââ¨darth vader vaonts beeping starship and goes out of above
# ------ temperature: 1.2
# â¨darth vader vaonts beeping starship and goes out of above letch computer me.., laser's about turmly back his hands chewie, away renise the . i'd got poor.
# oâ-ly fint
# hewleny moves control ' mast luke thing.
# luke
#
# - four all take-tound)
# mevaâ¨otherrs, look concerep cancon, 't do uswielens, bursts sst tie fighters. â¨comand room
# you mose you think theyeddseemy claiks.
# threepio
# it whity we're coming intd feel. â¨luke
# (over comlink)
# '  iscring up we're b
# epoch 43
# Epoch 1/1
# 65557/65557 [==============================] - 17s 267us/step - loss: 0.8592
# --- Generating with seed: "up in front of a rundown blockhouse cantina on the outskirts"
# ------ temperature: 0.2
# up in front of a rundown blockhouse cantina on the outskirts at the enges to stand the dark and the tie fighter cans-uniching the control panel, as his hand for the garaghts him is his him. he is a late their commander.
# threepio (contâd)â¨it deser stars into the rebel bay of the main battle. â¨
# 375 â int. massassy outpost - war room â¨luke looks at the tie fighter battered and a small about threepio.
# han (contâd)
# what you this ship! who's the far sh
# ------ temperature: 0.5
# hreepio.
# han (contâd)
# what you this ship! who's the far ship exip the death star han, fort the laser past surdent is his him. he is wall here.
# luke (contâd)â¨roget into and you've got to see her stories. see him is a laser pistol. she distured the rebel bay in a flich toward them.
# luke (contâd)â¨it insomelly. well, as he can be befort. the target screamer. â¨vader
# luke! they're going to have you hould them... we're coming the laserfire at luke scr
# ------ temperature: 1.0
# ave you hould them... we're coming the laserfire at luke scrasvey. â¨
# 196 â ext. two ? luke, sirj?
# it's wonnts control drops cleature mornues them. luke (your't 13 vader)â¨you want a lough.
# threepio
# they've
# i co slip is hal have to an imperial dreedquand into their find obi-wan, we're you're joiting.
# han
# i can't the death.
# threepio
# somellion.
# tarken
# i chumbles out of the giad race their grems into imperial life! ay derishting laser passtass as rishes the
# ------ temperature: 1.2
# to imperial life! ay derishting laser passtass as rishes the slime. ketcred you've this.
#
# 48. â¨, disty here... luke, schandcramas through the gear.
# hanâ¨come demike, i'm not a counts shoppen. â¨red lea diminy-to vader's wing-wing command officer was luke.
# porster her past they two.... for the truinioked. â¨red leader, with points methinggs seet crett as they're comlis bar?
# yes's struck they grubseting a gramp.
# vods the troop tuc ships and biggs. they
# epoch 44
# Epoch 1/1
# 65557/65557 [==============================] - 17s 254us/step - loss: 0.8508
# --- Generating with seed: "uke starts for the advancing troops, as solo and leia move u"
# ------ temperature: 0.2
# uke starts for the advancing troops, as solo and leia move until solder and a small hits the ship bounces out of the computer small starts at the death star hands male and the tracks and starts the huge stare and pursuin, do you were is in a plight around to sit in think you calmen race.
# lukeâ¨i'm not to the hand how would him explosion.
#
# 154 int. death star - cockpit 460 â¨threepio (contâd)
# what danth, be a rushes the onver. â¨luke's hind the tracks
# ------ temperature: 0.5
# hat danth, be a rushes the onver. â¨luke's hind the tracks off and pansen the slimy return the should transper threepio's ship boht before the death star through his founted and pursuing by viewn before the givader's laserfire. a sight the shalkping in a fastiend hit your stand pieching only back and blowing to the ladge two ancoveret. threepio takes out of the surface of the commander. â¨luke's control panel to the death star parso's han solo. his head
# ------ temperature: 1.0
#  control panel to the death star parso's han solo. his head juns. luke's che this - death star 3. â¨gelr's fighter back then he tispess them. luke cloticheturely clus x-file. i hadile holest the commend at the troopers. itw a weapons, understance. â¨threepio (contâd)
# an eligine.
# a svick his ships. ben stand over luke. all twen us sittent. simpents back into the death star anceroon a short suyes his gives out ferice?
# han
# i don't fine. he's alro's space
# ------ temperature: 1.2
# s his gives out ferice?
# han
# i don't fine. he's alro's space gives luke, armoon to light a sweaption.
#
# 24 thes un's wingmen quits what you stand overhie...
# luke!
# gua durning dark onytlerers, burss against mity the entire. weveentely wowning a targeting destilceet riyh.
#
# eady
# han
# (laughing?
# han
#
# you'll let i uelo happ!
# thquge a littor down at3, streaks in an , wait rin and chewben backs. shutcreps in say nowsed the emperan's control panelal too tatonnuel of
# epoch 45
# Epoch 1/1
# 65557/65557 [==============================] - 17s 252us/step - loss: 0.8492
# --- Generating with seed: "ther trooper standing on the bridge overhang is hit by luke'"
# ------ temperature: 0.2
# ther trooper standing on the bridge overhang is hit by luke's laserfire.
#
# 102 int. death star - main forward bay - cockpit 325 â¨biggsâ¨i don't been several laserfire.
#
# 102 int. death star - tracker - main passas winc - cockpit 340 â¨luke looks on the tie fighters wide with the hallways around the sand of canyon and starts a laser starting on the side of the death star. â¨
# 475 â int. darth vader's cockpit 460 â¨biggsâ¨be a wall hand he sees the battl
# ------ temperature: 0.5
# er's cockpit 460 â¨biggsâ¨be a wall hand he sees the battle. â¨
# 475 â int. gold leader's cockpit â¨luke are almost speeder stand imperial stormtroopers troopers are several shakadoor.
#
# 144 int. cowerh death star 212 â¨badrag with a seavous on the desert, an emimated stormtroopers troopers around the trench toward the death star sownellion way. â¨
# 475 â int. red leader's cockpit - traveling along the death star surface and sir.
# of the surface of the d
# ------ temperature: 1.0
# long the death star surface and sir.
# of the surface of the death star's sable around metcy of control in, the rebellion as the princess - the princess chewsard and be his target scurrise the vilio. â¨lukeâ¨we'll han soloabler as down a trooperst the huge rush he mashing and robots one in the plans somelm-land liqukt of instrance mes... how will we've it widly sear. â¨
# 296 â int. meafop moss
# his x-wing pitally
# cloare
# you could oftend the am
# the massive
# ------ temperature: 1.2
#  x-wing pitally
# cloare
# you could oftend the am
# the massive helpges the yincess.
# .
# surpritedblastor.
# the preshing me..... over move the trackinaigle.
# trooper stspend from become uptered retend.
# luke looks atsmety stormtroopers hangs at his dimon fiels. the dirveuteds flace. â¨
# jatily at
# ky, is knewing by. â¨
# 34 â int. mos gold finit ie'  cockpit 301 â¨biggs dark the battle stor creaturet an owen lifepped and a blowly...
# woini
# rabed?
# leia is flased cann
# epoch 46
# Epoch 1/1
# 65557/65557 [==============================] - 16s 250us/step - loss: 0.8491
# --- Generating with seed: " come on. it's getting late. i only hope we can get back bef"
# ------ temperature: 0.2
#  come on. it's getting late. i only hope we can get back before in the sealong on the ention as the shalk along the troops are speeder and the troopers struening at the sealong the sandpeople all time. â¨
# 37 â int. red leader's cockpit â¨red leader looks at the stormtroopers starship, sir. hands a deters the subtallway. they are stortention at the sight. â¨
# 37 â int. red leader's cockpit â¨luke looks are gaint standing in the sealled.
# han
# we'll they're
# ------ temperature: 0.5
# e looks are gaint standing in the sealled.
# han
# we'll they're gold like. it is all this standing altwe. he stands were are standing on the sandpeach and leia right alone the sandpeople all tie fighter release if you've got a grom on the smoking bzzcchen blase to sight at him with a side is red leader. â¨
# 303 â int. red leader's cockpit â¨luke looks are gaint is stormtrooper. â¨
# 284 â ext. space are going settling begin to this confulled by and dant to be
# ------ temperature: 1.0
# are going settling begin to this confulled by and dant to be very eidown, and threepio is begin to the little ecperabout over theme sand one isn't zeak apany in they wait be a rocks, artoo-detoo and no, it in hit with the4, i'm taggey speeder. â¨relugh hits be youbleat hand ssire vilowand and looks as laseruve are alleycer , listers a hallway. they've rocking strenting oze is a little achess out of bine arm into the trooper.
#
# 83 â int. massassi outpost -
# ------ temperature: 1.2
# of bine arm into the trooper.
#
# 83 â int. massassi outpost - colley uise didn't 10bind â¨he most vader's swinger ssider behind you. â¨owen's tarfunci2m thildioble standing in kith mider pold were blaster!
# the vilergit. he shooperhoos to move a rbstardile drost buff toward the pirateship, rushy sigh i co something. we oufl ja skinded tang of owen. nexts at the enter moments and pict to put the feasher but hut, i've ach seardout. we come i vast ship scrator
# epoch 47
# Epoch 1/1
# 64128/65557 [============================>.] - ETA: 0s - loss: 0.8408
