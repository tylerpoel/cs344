# %% [markdown]
# ## Preparing Data

# %%
import keras
import numpy as np

# path = keras.utils.get_file(
#    'nietzsche.txt',
#    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
# text = open(path).read().lower()
# text = open("/home/trp22/Star_Wars_A_New_Hope.pdf").read().lower()
text = open("/Users/tylerpoel/SW_ANewHope.txt").read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 224485

# %%
print(text)
# Out:
# star wars: a new hope 1.
# a long time ago, in a galaxy far, far, away...
# a vast sea of stars serves as the backdrop for the main title. war drums echo through the heavens as a rollup slowly crawls into infinity.
# it is a period of civil war. rebel spaceships, striking from a hidden base, have won their first victory against the evil galactic empire.
# during the battle, rebel spies managed to steal secret plans to the empire's ultimate weapon, the death star, an armored space station with enough power to destroy an entire planet.
# pursued by the empire's sinister agents, princess leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...
# the awesome yellow planet of tatooine emerges from a total eclipse, her two moons glowing against the darkness. a tiny silver spacecraft, a rebel blockade runner firing lasers from the back of the ship, races through space. it is pursed by a giant imperial star destroyer. hundreds of deadly laserbolts streak from the imperial star destroyer, causing the main solar fin of the rebel craft to disintegrate.
# 1 int. rebel blockade runner - main passageway 1
# an explosion rocks the ship as two robots, artoo-detoo (r2- d2) and see-threepio (c-3po) struggle to make their way through the shaking, bouncing passageway. both robots are old and battered. artoo is a short, claw-armed tripod. his face is a mass of computer lights surrounding a radar eye. threepio, on the other hand, is a tall, slender robot of human proportions. he has a gleaming bronze-like metallic surface of an art deco design.
# another blast shakes them as they struggle along their way.
#                         threepio
#               did you hear that? they've shut down
# the main reactor. we'll be destroyed for sure. this is madness!
# rebel troopers rush past the robots and take up positions in the main passageway. they aim their weapons toward the door.
#                         threepio (cont’d)
#               we're doomed!
# the little r2 unit makes a series of electronic sounds that only another robot could understand.
# star wars: a new hope 2.
#                         threepio (cont’d)
#               there'll be no escape for the
# princess this time.
# artoo continues making beeping sounds. tension mounts as loud metallic latches clank and the scream of heavy equipment are heard moving around the outside hull of the ship.
#                         threepio (cont’d)
#               what's that?
# 	.	2  ext. spacecraft in space 2 the imperial craft has easily overtaken the rebel blockade runner. the smaller rebel ship is being drawn into the underside dock of the giant imperial starship.
# 	.	3  int. rebel blockade runner 3 the nervous rebel troopers aim their weapons. suddenly a tremendous blast opens up a hole in the main passageway and a score of fearsome armored spacesuited stormtroopers make their way into the smoke-filled corridor. in a few minutes the entire passageway is ablaze with laserfire. the deadly bolts ricochet in wild random patterns creating huge explosions. stormtroopers scatter and duck behind storage lockers. laserbolts hit several rebel soldiers who scream and stagger through the smoke, holding shattered arms and faces. an explosion hits near the robots.                         threepio
# 	.	              i should have known better than to
# 	.	trust the logic of a half-sized thermocapsulary dehousing assister... artoo counters with an angry rebuttal as the battle rages around the two hapless robots.
# 	.	4  ext. tatooine - desert wasteland - day 4 a death-white wasteland stretches from horizon to horizon. the tremendous heat of two huge twin suns settle on a lone figure, luke skywalker, a farm boy with heroic aspirations who looks much younger than his eighteen years. his shaggy hair and baggy tunic give him the air of a simple but lovable lad with a prize-winning smile.
# star wars: a new hope 3.
# a light wind whips at him as he adjusts several valves on a large battered moisture vaporator which sticks out of the desert floor much like an oil pipe with valves. he is aided by a beatup tread-robot with six claw arms. the little robot appears to be barely functioning and moves with jerky motions. a bright sparkle in the morning sky catches luke's eye and he instinctively grabs a pair of electrobinoculars from his utility belt. he stands transfixed for a few moments studying the heavens, then dashed toward his dented, crudely repaired landspeeder (an auto-like transport that travels a few feet above the ground on a magnetic-field). he motions for the tiny robot to follow him.
#                         luke
#               hurry up! come with me! what are you
#               waiting for?! get in gear!
# the robot scoots around in a tight circle, stops short, and smoke begins to pour out of every joint. luke throws his arms up in disgust. exasperated, the young farm boy jumps into his landspeeder leaving the smoldering robot to hum madly.
# 	.	5  int. rebel blockade runner - main hallway 5 the awesome, seven-foot-tall dark lord of the sith makes his way into the blinding light of the main passageway. this is darth vader, right hand of the emperor. his face is obscured by his flowing black robes and grotesque breath mask, which stands out next to the fascist white armored suits of the imperial stormtroopers. everyone instinctively backs away from the imposing warrior and a deathly quiet sweeps through the rebel troops. several of the rebel troops break and run in a frenzied panic.
# 	.	6  int. rebel blockade runner 6 a woman's hand puts a card into an opening in artoo's dome. artoo makes beeping sounds.
# 	.	7  int. rebel blockade runner 7 threepio stands in a hallway, somewhat bewildered. artoo is nowhere in sight. the pitiful screams of the doomed rebel soldiers can be heard in the distance. threepioartoo! artoo-detoo, where are you? a familiar clanking sound attacks threepio's attention and he spots little artoo at the end of the hallway in a smoke-
# star wars: a new hope
# 4.
# filled alcove. a beautiful young girl (about sixteen years old) stands in front of artoo.
# surreal and out of place, dreamlike and half hidden in the smoke, she finishes adjusting something on artoo's computer face, then watches as the little robot joins his companion.
#                         threepio (cont’d)
#               at last! where have you been?
# stormtroopers can be heard battling in the distance.
# threepio (cont’d) they're heading in this direction.
#               what are we going to do? we'll be
#               sent to the spice mine of kessel or
#               smashed into who knows what!
# artoo scoots past his bronze friend and races down the subhallway. threepio chases after him.
#                         threepio (cont’d)
#               wait a minute, where are you going?
# artoo responds with electronic beeps.
# 8 int. rebel blockade runner - corridor
# the evil darth vader stands amid the broken and twisted bodies of his foes. he grabs a wounded rebel officer by the neck as an imperial officer rushes up to the dark lord.
#                         imperial officer
#               the death star plans are not in the
# main computer.
# vader squeezes the neck of the rebel officer, who struggles in vain.
#                         vader
#               where are those transmissions you
# intercepted?vader lifts the rebel off his feet by his throat.
#                         vader (cont’d)
#               what have you done with those plans?
# rebel officerwe intercepted no transmissions.
# aaah... this is a consular ship. were on a diplomatic mission.
# 8
# star wars: a new hope 5.
# vaderif this is a consular ship... were
#               is the ambassador?
# the rebel refuses to speak but eventually cries out as the dark lord begins to squeeze the officer's throat, creating a gruesome snapping and choking, until the soldier goes limp. vader tosses the dead soldier against the wall and turns to his troops.
#                         vader (cont’d)
#               commander, tear this ship apart
# until you've found those plans and bring me the ambassador. i want her alive!
# the stormtroopers scurry into the subhallways.
# 	.	9  int. rebel blockade runner - subhallway 9 the lovely young girl huddles in a small alcove as the stormtroopers search through the ship. she is princess leia organa, a member of the alderaan senate. the fear in her eyes slowly gives way to anger as the muted crushing sounds of the approaching stormtroopers grow louder. one of the troopers spots her.                         trooper
# 	.	              there she is! set for stun!
# 	.	leia steps from her hiding place and blasts a trooper with her laser pistol. she starts to run but is felled by a paralyzing ray. the troopers inspect her inert body. trooper (cont’d) she'll be all right. inform lord vader we have a prisoner.
# 	.	10  int. rebel blockade runner - subhallway 10 artoo stops before the small hatch of an emergency lifepod. he snaps the seal on the main latch and a red warning light begins to flash. the stubby astro-robot works his way into the cramped four-man pod. threepiohey, you're not permitted in there. it's restricted. you'll be deactivated for sure.. artoo beeps something to him.
# star wars: a new hope 6.
#                         threepio (cont’d)
#               don't call me a mindless
# philosopher, you overweight glob of grease! now come out before somebody sees you.
# artoo whistles something at his reluctant friend regarding the mission he is about to perform.
#                         threepio (cont’d)
#               secret mission? what plans? what are
#               you talking about? i'm not getting
#               in there!
# artoo isn't happy with threepio's stubbornness, and he beeps and twangs angrily.
# a new explosion, this time very close, sends dust and debris through the narrow subhallway. flames lick at threepio and, after a flurry of electronic swearing from artoo, the lanky robot jumps into the lifepod.
# threepio (cont’d) i'm going to regret this.
# 	.	11  int. imperial stardestroyer 11 on the main viewscreen, the lifepod carrying the two terrified robots speeds away from the stricken rebel spacecraft. chief pilot there goes another one. captainhold your fire. there are no life forms. it must have been short- circuited.
# 	.	12  int. lifepod 12 artoo and threepio look out at the receding imperial starship. stars circle as the pod rotates through the galaxy.                         threepio
# 	.	              that's funny, the damage doesn't
# 	.	look as bad from out here. artoo beeps an assuring response.                         threepio (cont’d)
# 	.	              are you sure this things safe?
# 	.
# star wars: a new hope 13 13
# 12a ext. tatooine - anchorhead settlement - power station - day
# heat waves radiate from the dozen or so bleached white buildings. luke pilots his landspeeder through the dusty empty street of the tiny settlement.
# an old woman runs to get out of the way of the speeding vehicle, shaking her fist at luke as he flies past.
#                         woman
#               i've told you kids to slow down!
# 14 int. power station - day
# 7.
# 12a
# luke bursts into the power station, waking the fixer, a rugged mechanic and camie, a sexy, disheveled girl who has been asleep in his lap. they grumbled as he races through the office, yelling wildly.
#                    fixer
#          did i hear a young noise blast
#          through here?
#                    camie
#          it was just wormie on another
# rampage.
# luke bounces into a small room behind the office where deak and windy, two tough boys about the same age as luke, are playing a computer pool-like game with biggs, a burly, handsome boy a few years older than the rest. his flashy city attire is a sharp contrast to the loose-fitting tunics of the farm boys. a robot repairs some equipment in the background.
# lukeshape it up you guys!... biggs?
# luke's surprise at the appearance of biggs gives way to great joy and emotion. they give each other a great bear hug.
#                    luke (cont’d)
#          i didn't know you were back! when
#          did you get in?
# biggsjust now. i wanted to surprise you,
# hot shot. i thought you'd be here... certainly didn't expect you to be out working.
# (he laughs)
# 14
# star wars: a new hope 8.
#                         luke
#               the academy didn't change you
# much...but you're back so soon? hey, what happened, didn't you get your commission?
# biggs has an air of cool that seems slightly phony.
# biggsof course i got it. signed aboard
# the rand ecliptic last week. first mate biggs darklighter at your service...
# (he salutes)...i just came to say good-bye to all you unfortunate landlocked simpletons.
# everyone laughs. the dazzling spectacle of his dashing friend is almost too much for luke, but suddenly he snaps out of it.
# lukei almost forgot. there's a battle
# going on! right here in our system. come and look!
# deaknot again! forget it.
# 15 ext. tatooine - anchorhead - settlement - power station - 15
#                         day
#               the group stumbles out into the
# stifling desert sun. camie and the fixer complain and are forced to shade their eyes. luke has his binoculars out scanning the heavens.
#                         luke
#               there they are!
# biggs takes the binoculars from luke as the others strain to see something with the naked eye. through the binoculars biggs sees two small silver specks.
# biggsthat's no battle, hot shot...
# they're just sitting there! probably a freighter-tanker refueling.
#                         luke
#               but there was a lot of firing
# earlier...
# star wars: a new hope
# 9.
# camie grabs the binoculars away banging them against the building in the process. luke grabs them.
# luke (cont’d) hey, easy with those...
# camiedon't worry about it, wormie.
# the fixer gives luke a hard look and the young farm boy shrugs his shoulders in resignation.
#                         fixer
#               i keep telling you, the rebellion is
# a long way from here. i doubt if the empire would even fight to keep this system. believe me luke, this planet is a big hunk of nothing...
# luke agrees, although it's obvious he isn't sure why. the group stumbles back into the power station, grumbling about luke's ineptitude.
# 16 int. rebel blockade runner - hallway
# princess leia is led down a low-ceilinged hallway by a squad of armored stormtroopers. her hands are bound and she is brutally shoved when she is unable to keep up with the briskly marching troops. they stop in a smoky hallway as darth vader emerges from the shadows. the sinister dark lord stares hard at the frail young senator, but she doesn't move.
# leialord vader, i should have known.
# only you could be so bold. the imperial senate will not sit for this, when they hear you've attacked a diplomatic...
#                         vader
#               don't play games with me, your
# highness. you weren't on any mercy mission this time. you passed directly through a restricted system. several transmissions were beamed to this ship by rebel spies. i want to know what happened to the plans they sent you.
#                         leia
#               i don't know what you're talking
# about. i'm a member of the imperial
# 16
# star wars: a new hope 10.
# senate on a diplomatic mission to alderaan...
#                    vader
#          you're a part of the rebel
# alliance... and a traitor. take her away!
# leia is marched away down the hallway and into the smoldering hole blasted in the side of the ship. an imperial commander turns to vader.
# commanderholding her is dangerous. if word of
# this gets out, it could generate sympathy for the rebellion in the senate.
#                    vader
#          i have traced the rebel spies to
# her. now she is my only link to find their secret base!
#                    commander
#          she'll die before she tells you
# anything.
# vaderleave that to me. send a distress
#          signal and then inform the senate
#          that all aboard were killed!
# another imperial officer approaches vader and the commander. they stop and snap to attention.
#                    second officer
#          lord vader, the battle station plans
# are not aboard this ship! and no transmissions were made. an escape pod was jettisoned during the fighting, but no life forms were aboard.
# vader turns to the commander.
#                    vader
#          she must have hidden the plans in
# the escape pod. send a detachment down to retrieve them. see to it personally, commander. there'll be no one to stop us this time.
# commander yes, sir.
# star wars: a new hope
# 11.
# 	.	17  ext. space the imperial stardestroyer comes over the surface of the planet tatooine.
# 	.	18  ext. tatooine - desert jundland, or "no man's land", where the rugged desert mesas meet the foreboding dune sea. the two helpless astro-droids kick up clouds of sand as they leave the lifepod and clumsily work their way across the desert wasteland. the lifepod in the distance rests half buried in the sand.                         threepio
# 	.	              how did i get into this mess? i
# 	.	really don't know how. we seem to be made to suffer. it's our lot in life. artoo answers with beeping sounds.                         threepio (cont’d)
# 	.	              i've got to rest before i fall
# 	.	apart. my joints are almost frozen. artoo continues to respond with beeping sounds. threepio (cont’d) what a desolate place this is. suddenly artoo whistles, makes a sharp right turn and starts off in the direction of the rocky desert mesas. threepio stops and yells at him.                         threepio (cont’d)
# 	.	              where are you going?
# 	.	a stream of electronic noises pours forth from the small robot. threepio (cont’d)well, i'm not going that way. it's much too rocky. this way is much easier. artoo counters with a long whistle.                         threepio (cont’d)
# 	.	              what makes you think there are
# 	.	settlements over there?artoo continues to make beeping sounds.
# 17
# 18
# star wars: a new hope 12.
# threepio (cont’d) don't get technical with me.
# artoo continues to make beeping sounds.
#                         threepio (cont’d)
#               what mission? what are you talking
#               about? i've had just about enough of
#               you! go that way! you'll be
#               malfunctioning within a day, you
#               nearsighted scrap pile!
# threepio gives the little robot a kick and starts off in the direction of the vast dune sea.
#                         threepio (cont’d)
#               and don't let me catch you following
# me begging for help, because you won't get it.
# artoo's reply is a rather rude sound. he turns and trudges off in the direction of the towering mesas.
# threepio (cont’d)no more adventures. i'm not going
# that way.
# artoo beeps to himself as he makes his way toward the distant mountains.
# 19 ext. tatooine - dune sea 19
# threepio, hot and tired, struggles up over the ridge of a dune; only to find more dunes, which seem to go on for endless miles. he looks back in the direction of the now distant rock mesas.
# threepiothat malfunctioning little twerp.
# this is all his fault! he tricked me into going this way, but he'll do no better.
# in a huff of anger and frustration, threepio knocks the sand from his joints. his plight seems hopeless, when a glint of reflected light in the distance reveals an object moving towards him.
#                         threepio (cont’d)
#               wait, what's that? a transport! i'm
# saved!
# star wars: a new hope 13.
# the bronze android waves frantically and yells at the approaching transport.
#                         threepio (cont’d)
#               over here! help! please, help!
# 20 20
# 19a ext. tatooine - anchorhead settlement - power station - day 19a
# luke and biggs are walking and drinking a malt brew. fixer and the others can be heard working inside.
#                         luke
#                    (very animated)
# ...so i cut off my power, shut down the afterburners and came in low on deak's trail. i was so close i thought i was going to fry my instruments. as it was i busted up the skyhopper pretty bad. uncle owen was pretty upset. he grounded me for the rest of the season. you should have been there... it was fantastic.
# biggsyou ought to take it easy luke. you
# may be the hottest bushpilot this side of mos eisley, but those little skyhoppers are dangerous. keep it up, and one day, whammo, you're going to be nothing more than a dark spot on the down side of a canyon wall.
# lukelook who's talking. now that you've
# been around those giant starships you're beginning to sound like my uncle. you've gotten soft in the city...
# biggs i've missed you kid.
#                         luke
#               well, things haven't been the same
# since you left, biggs. it's been so... quiet.
# biggs looks around then leans close to luke. biggs
# star wars: a new hope 14.
# luke, i didn't come back just to say good-bye... i shouldn't tell you this, but you're the only one i can trust... and if i don't come back, i want somebody to know.
# luke's eyes are wide with biggs' seriousness and loyalty.
#                    luke
#          what are you talking about?
# biggsi made some friends at the academy.
# (he whispers)...when our frigate goes to one of the central systems, we're going to jump ship and join the alliance...
# luke, amazed and stunned, is almost speechless.
#                    luke
#          join the rebellion?! are you
#          kidding! how?
#                    biggs
#          quiet down will ya! you got a mouth
#          bigger than a meteor crater!
# lukei'm sorry. i'm quiet.
# (he whispers)listen how quiet i am. you can barely hear me...
# biggs shakes his head angrily and then continues.
#                    biggs
#          my friend has a friend on bestine
# who might help us make contact.
#                    luke
#          you're crazy! you could wander
# around forever trying to find them.
#                    biggs
#          i know it's a long shot, but if i
# don't find them i'll do what i can on my own... it's what we always talked about. luke, i'm not going to wait for the empire to draft me into service. the rebellion is spreading and i want to be on the right side - - the side i believe in.
# star wars: a new hope 15.
# lukeand i'm stuck here...
#                    biggs
#          i thought you were going to the
# academy next term. you'll get your chance to get off this rock.
# luke not likely! i had to cancel my application. there has been a lot of unrest among the sandpeople since you left... they've even raided the outskirts of anchorhead.
# biggs your uncle could hold off a whole colony of sandpeople with one blaster.
# luke i know, but he's got enough vaporators going to make the place pay off. he needs me for just one more season. i can't leave him now.
# biggs i feel for you, luke, you're going to have to learn what seems to be important or what really is important. what good is all your uncle's work if it's taken over by the empire?... you know they're starting to nationalize commerce in the central systems... it won't be long before your uncle is merely a tenant, slaving for the greater glory of the empire.
# luke it couldn't happen here. you said it yourself. the empire won't bother with this rock.
# biggs things always change.luke i wish i was going... are you going to biggs no, i'm leaving in the morning... luke then i guess i won't see you.biggs maybe someday... i'll keep a lookout.
#                    luke
#          well, i'll be at the academy next
# season... after that who knows. i won't be drafted into the imperial starfleet that's for sure... take care of yourself, you'll always be the best friend i've got.
# biggs so long, luke.
# be around long?
# biggs turns away from his old friend and heads towards the power station.
# star wars: a new hope 16.
# 21 ext. tatooine - rock canyon - sunset
# the gargantuan rock formations are shrouded in a strange foreboding mist and the onimous sounds of unearthly creatures fill the air. artoo moves cautiously through the creepy rock canyon, inadvertently making a loud clicking noise as he goes. he hears a distant, hard, metallic sound and stops for a moment. convinced he is alone, he continues on his way.
# in the distance, a pebble tumbles down the steep canyon wall and a small dark figure darts into the shadows. a little further up the canyon a slight flicker of light reveals a pair of eyes in the dark recesses only a few feet from the narrow path.
# the unsuspecting robot waddles along the rugged trail until suddenly, out of nowhere, a powerful magnetic ray shoots out of the rocks and engulfs him in an eerie glow. he manages one short electronic squeak before he topples over onto his back. his bright computer lights flicker off, then on, then off again. out of the rocks scurry three jawas, no taller than artoo. they holster strange and complex weapons as they cautiously approach the robot. they wear grubby cloaks and their faces are shrouded so only their glowing eyes can be seen. they hiss and make odd guttural sounds as they heave the heavy robot onto their shoulders and carry him off down the trail.
# 21
# 	.	22  ext. tatooine - rock canyon - sandcrawler - sunset 22 the eight jawas carry artoo out of the canyon to a huge tank- like vehicle the size of a four-story house. they weld a small disk on the side of artoo and then put him under a large tube on the side of the vehicle and the little robot is sucked into the giant machine. the filthy little jawas scurry like rats up small ladders and enter the main cabin of the behemoth transport.
# 	.	23  int. sandcrawler - hold area 23 it is dim inside the hold area of the sandcrawler. artoo switches on a small floodlight on his forehead and stumbles around the scrap heap. the narrow beam swings across rusty metal rocket parts and an array of grotesquely twisted and maimed astro-robots. he lets out a pathetic electronic whimper and stumbles off toward what appears to be a door at the end of the chamber.
# 	.	24  int. sandcrawler - prison area 24
# star wars: a new hope 17.
# artoo enters a wide room with a four-foot ceiling. in the middle of the scrap heap sit a dozen or so robots of various shapes and sizes. some are engaged in electronic conversation, while others simply mill about. a voice of recognition calls out from the gloom.
# threepioartoo-detoo! it's you! it's you!
# a battered threepio scrambles up to artoo and embraces him.
# 	.	25  ext. tatooine - rock canyon - sandcrawler - sunset 25 the enormous sandcrawler lumbers off toward the magnificent twin suns, which are slowly setting over a distant mountain ridge.
# 	.	26  ext. tatooine - desert - day 26 four imperial stormtroopers mill about in front of the half- buried lifepod that brought artoo and threepio to tatooine. a trooper yells to an officer some distance away. first troopersomeone was in the pod. the tracks go off in this direction. a second trooper picks a small bit of metal out of the sand and gives it to the first trooper. second trooper look, sir -- droids.
# 	.	27  ext. tatooine - dunes 27 the sandcrawler moves slowly down a great sand dune.
# 	.	28  int. sandcrawler 28 threepio and artoo noisily bounce along inside the cramped prison chamber. artoo appears to be shut off.                         threepio
# 	.	              wake up! wake up!
# 	.	suddenly the shaking and bouncing of the sandcrawler stops, creating quite a commotion among the mechanical men. threepio's fist bangs the head of artoo whose computer lights pop on as he begins beeping. at the far end of the long chamber a hatch opens, filling the chamber with blinding
# star wars: a new hope 18.
# white light. a dozen or so jawas make their way through the odd assortment of robots.
# threepio (cont’d) we're doomed.
# a jawa starts moving toward them.
#                         threepio (cont’d)
#               do you think they'll melt us down?
# artoo responds, making beeping sounds.
#                         threepio (cont’d)
#               don't shoot! don't shoot! will this
# never end?
# 29 ext. tatooine - desert - lars homestead - afternoon 29
# the jawas mutter gibberish as they busily line up their battered captives, including artoo and threepio, in front of the enormous sandcrawler, which is parked beside a small homestead consisting of three large holes in the ground surrounded by several tall moisture vaporators and one small adobe block house.
# the jawas scurry around fussing over the robots, straightening them up or brushing some dust from a dented metallic elbow. the shrouded little creatures smell horribly, attracting small insects to the dark areas when their mouths and nostrils should be.
# out of the shadows of a dingy side-building limps owen lars, a large burly man in his mid-fifties. his reddish eyes are sunken in a dust-covered face. as the farmer carefully inspects each robot, he is closely followed by his slump- shouldered nephew, luke skywalker. one of the vile little jawas walks ahead of the farmer spouting an animated sales pitch in a queer, unintelligible language.
# a voice calls out from one of the huge holes that form the homestead. luke goes over to the edge and sees his aunt beru standing in the main courtyard.
#                         beru
#               luke, tell owen that if he gets a
# translator to be sure it speaks bocce.
#                         luke
#               it looks like we don't have much of
# a choice but i'll remind him.
# star wars: a new hope 19.
# luke returns to his uncle as they look over the equipment for sale with the jawa leader.
# oweni have no need for a protocol droid.
#                    threepio
#               (quickly)
# sir -- not in an environment such as this -- that's why i've also been programmed for over thirty secondary functions that...
#                    owen
#          what i really need is a droid that
# understands the binary language of moisture vaporators.
# threepiovaporators! sir -- my first job was
# programming binary load lifter... very similar to your vaporators. you could say...
#                    owen
#          do you speak bocce?
# threepioof course i can, sir. it's like a
# second language for me... i'm as fluent in bocce...
#                    owen
#          all right shut up!
# (turning to jawa) i'll take this one.
# threepio shutting up, sir.
#                    owen
#          luke, take these two over to the
#          garage, will you?
#               (more)
#                    owen (cont'd)
#          i want you to have both of them
# cleaned up before dinner.
#                    luke
#          but i was going into toshi station
# to pick up some power converters... owen
# star wars: a new hope 20.
# you can waste time with your friends when your chores are done. now come on, get to it!
#                    luke
#          all right, come on! and the red one,
# come on. well, come on, red, let's go.
# as the jawas start to lead the three remaining robots back into the sandcrawler, artoo lets out a pathetic little beep and starts after his old friend threepio. he is restrained by a slimy jawa, who zaps him with a control box.
# owen is negotiating with the head jawa. luke and the two robots start off for the garage when a plate pops off the head of the red astro-droid's head plate and it sparks wildly.
# luke (cont’d) uncle owen...
# owen yeah?
# lukethis r2 unit has a bad motivator.
# look!
#          hey, what're you trying to push on
#          us?
# the jawa goes into a loud spiel. meanwhile, artoo has sneaked out of line and is moving up and down trying to attract attention. he lets out with a low whistle. threepio taps luke on the shoulder.
#                    threepio
#               (pointing to artoo)
# excuse me, sir, but that r2 unit is in prime condition. a real bargain.
# luke uncle owen...
# owen yeah?
#                    luke
#          what about that one?
# owen
#      owen
# (to the head jawa)
# star wars: a new hope 21.
# (to jawa)what about that blue one? we'll take that one.
# with a little reluctance the scruffy dwarf trades the damaged astro-droid for artoo.
# luke yeah, take it away.
#                         threepio
#               uh, i'm quite sure you'll be very
# pleased with that one, sir. he really is in first-class condition. i've worked with him before. here he comes.
# owen pays off the whining jawa as luke and the two robots trudge off toward a grimy homestead entry.
# luke okay, let's go.
#                         threepio
#                    (to artoo)
#               now, don't you forget this! why i
#               should stick my neck out for you is
#               quite beyond my capacity!
# 30 int. lars homestead - garage area - late afternoon 30
# the garage is cluttered and worn, but a friendly peaceful atmosphere permeates the low grey chamber. threepio lowers himself into a large tub filled with warm oil. near the battered landspeeder little artoo rests on a large battery with a cord to his face.
#                         threepio
#               thank the maker! this oil bath is
# going to feel so good. i've got such a bad case of dust contamination, i can barely move!
# artoo beeps a muffled reply. luke seems to be lost in thought as he runs his hand over the damaged fin of a small two-man skyhopper spaceship resting in a low hangar off the garage. finally luke's frustrations get the better of him and he slams a wrench across the workbench.
# lukeit just isn't fair. oh, biggs is
# right. i'm never gonna get out of here!
# star wars: a new hope 22.
#                    threepio
#          is there anything i might do to
# help?
# luke glances at the battered robot. a bit of his anger drains and a tiny smile creeps across his face.
#                    luke
#          well, not unless you can alter time,
#          speed up the harvest, or teleport me
#          off this rock!
# threepioi don't think so, sir. i'm only a
# droid and not very knowledgeable about such things. not on this planet, anyways. as a matter of fact, i'm not even sure which planet i'm on.
#                    luke
#          well, if there's a bright center to
# the universe, you're on the planet that it's farthest from.
# threepio i see, sir.
# lukeuh, you can call me luke.
# threepio i see, sir luke.
#                    luke
#               (laughing)
# just luke.
# threepioand i am see-threepio, human-cyborg
# relations, and this is my counterpart, artoo-detoo.
# luke hello.
# artoo beeps in response. luke unplugs artoo and begins to scrape several connectors on the robot's head with a chrome pick. threepio climbs out of the oil tub and begins wiping oil from his bronze body.
#                    luke (cont’d)
#          you got a lot of carbon scoring
# here. it looks like you boys have
# star wars: a new hope 23.
# seen a lot of action.
#                    threepio
#          with all we've been through,
# sometimes i'm amazed we're in as good condition as we are, what with the rebellion and all.
#                    luke
#          you know of the rebellion against
# the empire?
#                    threepio
#          that's how we came to be in your
# service, if you take my meaning, sir.
#                    luke
#          have you been in many battles?
# threepioseveral, i think. actually, there's
# not much to tell. i'm not much more than an interpreter, and not very good at telling stories. well, not at making them interesting, anyways.
# luke struggles to remove a small metal fragment from artoo's neck joint. he uses a larger pick.
#                    luke
#          well, my little friend, you've got
# something jammed in here real good. were you on a cruiser or...
# the fragment breaks loose with a snap, sending luke tumbling head over heels. he sits up and sees a twelve-inch three- dimensional hologram of leia organa, the rebel senator, being projected from the face of little artoo. the image is a rainbow of colors as it flickers and jiggles in the dimly lit garage. luke's mouth hangs open in awe.
# leiahelp me, obi-wan kenobi. you're my
# only hope.
#                    luke
#          what's this?
# artoo looks around and sheepishly beeps an answer for threepio to translate. leia continues to repeat the sentence fragment over and over.
# threepio
# star wars: a new hope 24.
# what is what?!? he asked you a question...
#               (pointing to leia)
#          what is that?
# artoo whistles his surprise as he pretends to just notice the hologram. he looks around and sheepishly beeps an answer for threepio to translate. leia continues to repeat the sentence fragment over and over.
# leiahelp me, obi-wan kenobi. you're my
# only hope. help me, obi-wan kenobi. you're my only hope.
# threepiooh, he says it's nothing, sir.
# merely a malfunction. old data. pay it no mind.
# luke becomes intrigued by the beautiful girl.
# lukewho is she? she's beautiful.
# threepioi'm afraid i'm not quite sure, sir.
# leiahelp me, obi-wan kenobi...
#                    threepio
#          i think she was a passenger on our
# last voyage. a person of some importance, sir -- i believe. our captain was attached to...
#                    luke
#          is there more to this recording?
# luke reaches out for artoo but he lets out several frantic squeaks and a whistle.
# threepiobehave yourself, artoo. you're going
# to get us in trouble. it's all right, you can trust him. he's our new master.
# artoo whistles and beeps a long message to threepio.
# threepio (cont’d)he says he's the property of obi-
#          wan kenobi, a resident of these
# star wars: a new hope 25.
# parts. and it's a private message for him. quite frankly, sir i don't know what he's talking about. our last master was captain antilles, but with what we've been through, this little r2 unit has become a bit eccentric.
# lukeobi-wan kenobi? i wonder if he means
#          old ben kenobi?
#                    threepio
#          i beg your pardon, sir, but do you
#          know what he's talking about?
# lukewell, i don't know anyone named obi-
# wan, but old ben lives out beyond the dune sea. he's kind of a strange old hermit.
# luke's gazes at the beautiful young princess for a few moments.
# luke (cont’d)i wonder who she is. it sounds like
# she's in trouble. i'd better play back the whole thing.
# artoo beeps something to threepio.
#                    threepio
#          he says the restraining bolt has
# short circuited his recording system. he suggests that if you remove the bolt, he might be able to play back the entire recording.
# luke looks longingly at the lovely, little princess and hasn't really heard what threepio has been saying.
#                    luke
#          h'm? oh, yeah, well, i guess you're
# too small to run away on me if i take this off! okay.
# luke takes a wedged bar and pops the restraining bolt off artoo's side.
# luke (cont’d) there you go.
# the princess immediately disappears...
# star wars: a new hope
# 26.
# luke (cont’d)well, wait a minute. where'd she go?
# bring her back! play back the entire message.
# artoo beeps an innocent reply as threepio sits up in embarrassment.
#                         threepio
#               what message? the one you're
# carrying inside your rusty innards! a women's voice calls out from another room.
#                         aunt beru
#               luke? luke! come to dinner!
# luke stands up and shakes his head at the malfunctioning robot.
#                         luke
#               all right, i'll be right there, aunt
# beru.
#                         threepio
#               i'm sorry, sir, but he appears to
# have picked up a slight flutter.
# luke tosses artoo's restraining bolt on the workbench and hurries out of the room.
# lukewell, see what you can do with him.
# i'll be right back.
#                         threepio
#                    (to artoo)
# just you reconsider playing that message for him.
# artoo beeps in response.
#                         threepio (cont’d)
#               no, i don't think he likes you at
# all. artoo beeps.
# threepio (cont’d) no, i don't like you either.
# 31 int. lars homestead - dining area
# 31
# star wars: a new hope 27.
# luke's aunt beru, a warm, motherly woman, fills a pitcher with blue fluid from a refrigerated container in the well- used kitchen. she puts the pitcher on a tray with some bowls of food and starts for the dining area.
# luke sits with his uncle owen before a table covered with steaming bowls of food as aunt beru carries in a bowl of red grain.
#                    luke
#          you know, i think that r2 unit we
# bought might have been stolen.
#                    owen
#          what makes you think that?
#                    luke
#          well, i stumbled across a recording
# while i was cleaning him. he says he belongs to someone called obi- wan kenobi.
# owen is greatly alarmed at the mention of his name, but manages to control himself.
#                    luke (cont’d)
#          i thought he might have meant old
# ben. do you know what he's talking about? well, i wonder if he's related to ben.
# owen breaks loose with a fit of uncontrolled anger.
#                    owen
#          that old man's just a crazy old
# wizard. tomorrow i want you to take that r2 unit into anchorhead and have its memory flushed. that'll be the end of it. it belongs to us now.
# lukebut what if this obi-wan comes
#          looking for him?
#                    owen
#          he won't, i don't think he exists
# any more. he died about the same time as your father.
#                    luke
#          he knew my father?
# owen
# star wars: a new hope 28.
# i told you to forget it. your only concern is to prepare the new droids for tomorrow. in the morning i want them on the south ridge working out those condensers.
# lukeyes, sir. i think those new droids
# are going to work out fine. in fact, i, uh, was also thinking about our agreement about my staying on another season. and if these new droids do work out, i want to transmit my application to the academy this year.
# owen's face becomes a scowl, although he tries to suppress it.
#                    owen
#          you mean the next semester before
# harvest?
#                    luke
#          sure, there're more than enough
# droids.
# owenharvest is when i need you the most.
# only one more season. this year we'll make enough on the harvest so i'll be able to hire some more hands. and then you can go to the academy next year.
# luke continues to toy with his food, not looking at his uncle.
#                    owen (cont’d)
#          you must understand i need you here,
# luke.
# lukebut it's a whole 'nother year.
# owenlook, it's only one more season.
# luke pushes his half-eaten plate of food aside and stands.
#                    luke
#          yeah, that's what you said last year
# when biggs and tank left.
# star wars: a new hope
# 29.
#                         aunt beru
#               where are you going?
# lukeit looks like i'm going nowhere. i
# have to finish cleaning those droids.
# resigned to his fate, luke paddles out of the room. owen mechanically finishes his dinner.
# aunt beruowen, he can't stay here forever.
# most of his friends have gone. it means so much to him.
# oweni'll make it up to him next year. i
# promise.
# aunt beruluke's just not a farmer, owen. he
# has too much of his father in him.
# owenthat's what i'm afraid of.
# 32 ext. tatooine - lars homestead
# the giant twin suns of tatooine slowly disappear behind a distant dune range. luke stands watching them for a few moments, then reluctantly enters the doomed entrance to the homestead.
# 32
# 33 int. lars homestead - garage 33
# luke enters the garage to discover the robots nowhere in sight. he takes a small control box from his utility belt similar to the one the jawas were carrying. he activates the box, which creates a low hum, and threepio, letting out a short yell, pops up from behind the skyhopper spaceship.
#                         luke
#               what are you doing hiding there?
# threepio stumbles forward, but artoo is still nowhere in sight.
# threepioit wasn't my fault, sir. please
# don't deactivate me. i told him not to go, but he's faulty,
# star wars: a new hope
# 30.
# malfunctioning; kept babbling on about his mission.
# luke oh, no!
# luke races out of the garage followed by threepio.
# 34 ext. tatooine - lars homestead
# luke rushes out of the small doomed entry to the homestead and searches the darkening horizon for the small triped astro- robot. threepio struggles out of the homestead and on the salt flat as luke scans the landscape with his electrobinoculars.
#                         threepio
#               that r2 unit has always been a
# problem. these astro-droids are getting quite out of hand. even i can't understand their logic at times.
#                         luke
#               how could i be so stupid? he's
# nowhere in sight. blast it!
#                         threepio
#               pardon me, sir, but couldn't we go
# after him?
#                         luke
#               it's too dangerous with all the
# sandpeople around. we'll have to wait until morning.
# owen yells up from the homestead plaza.
#                         owen
#               luke, i'm shutting the power down
# for the night.
#                         luke
#               all right, i'll be there in a few
# minutes. boy, am i gonna get it.he takes one final look across the dim horizon.
#                         luke (cont’d)
#               you know that little droid is going
# to cause me a lot of trouble. threepio
# 34
# star wars: a new hope 31. oh, he excels at that, sir.
# 35 int. lars homestead - plaza
# morning slowly creeps into the sparse but sparkling oasis of the open courtyard. the idyll is broken be the yelling of uncle owen, his voice echoing throughout the homestead.
#                         owen
#               luke? luke? luke? where could he be
# loafing now!
# 35
# 	.	36  int. lars homestead - kitchen 36 the interior of the kitchen is a worm glow as aunt beru prepares the morning breakfast. owen enters in a huff.                         owen
# 	.	              have you seen luke this morning?
# 	.	                        aunt beru
# 	.	              he said he had some things to do
# 	.	before he started today, so he left early.                         owen
# 	.	              uh? did he take those two new droids
# 	.	with him? aunt beru i think so.                         owen
# 	.	              well, he'd better have those units
# 	.	              in the south range repaired be
# 	.	              midday or there'll be hell to pay!
# 	.
# 	.	37  ext. tatooine - desert wasteland - luke's speeder - day 37 the rock and sand of the desert floor are a blur as threepio pilots the sleek landspeeder gracefully across the vast wasteland.
# 	.	38  int./ext. luke's speeder - desert wasteland - traveling - 38                         day
# 	.	              luke leans over the back of the
# 	.	speeder and adjusts something in the motor compartment.
# star wars: a new hope
# 32.
#                         luke
#                    (yelling)
# how's that.
# threepio signals that is fine and luke turns back into the wind-whipped cockpit and pops the canopy shut.
#                         luke (cont’d)
#               old ben kenobi lives out in this
# direction somewhere, but i don't see how that r2 unit could have come this far. we must have missed him. uncle owen isn't going to take this very well.
#                         threepio
#               sir, would it help if you told him
# it was my fault.
#                         luke
#                    (brightening)
# sure. he needs you. he'd probably only deactivate you for a day or so...
#                         threepio
#               deactivate! well, on the other hand
# if you hadn't removed his restraining bolt...
#                         luke
#               wait, there's something dead ahead
# on the scanner. it looks like our droid... hit the accelerator.
# 39 ext. tatooine - rock mesa - dune sea - coastline - day
# ...
# 	.	              you worry about those fighters! i'll
# 	.	              worry about the tower!
# 	.
# 	.	397  ext. death star surface 397 luke's x-wing streaks through the trench, firing lasers.
# 	.	398  int. luke's x-wing fighter - cockpit 398 luke breaks into a nervous sweat as the laserfire is returned, knicking one of his wings close to the engine.                         luke
# 	.	                   (to artoo)
# 	.	artoo... that, that stabilizer's broken loose again! see if you can't lock it down!
# 	.	399  ext. luke's x-wing fighter 399 artoo works to repair the damages. the canyon wall rushes by in the background, making his delicate task seem even more precarious.
# star wars: a new hope
# 149.
# 	.	400  ext. death star two laser cannons are firing on the rebel fighters.
# 	.	401  int. wedge's cockpit wedge looks up and sees the tie ships.
# 	.	402  int. luke's x-wing fighter - cockpit luke's targeting device marks off the distance to the target.
# 400
# 401
# 402
# 	.	403  ext. space around the death star 403 vader and his wingmen zoom closer.
# 	.	404  int. darth vader's cockpit 404 vader adjusts his controls and fires laserbolts at two x- wings flying down the trench. he scores a direct hit on wedge.
# 	.	405  int. massassi outpost - war room 405 leia and the others are grouped around the computer board.                         wedge
# 	.	                   (over speaker)
# 	.	i'm hit! i can't stay with you.                         luke
# 	.	                   (over speaker)
# 	.	get clear, wedge.
# 	.	406  int. luke's x-wing fighter - cockpit 406                         luke
# 	.	              you can't do any more good back
# 	.	there!
# 	.	407  int. wedge's cockpit 407 wedge sorry!
# 	.	408  ext. space around the death star 408
# star wars: a new hope 150. wedge pulls his crippled x-wing back away from the battle.
# 	.	409  int. darth vader's cockpit 409 vader watches the escape but issues a command to his wingmen.                         vader
# 	.	              let him go! stay on the leader!
# 	.
# 	.	410  ext. space around the death star 410 luke's x-wing speeds down the trench; the three tie fighters, still in perfect unbroken formation, tail close behind.
# 	.	411  int. biggs' cockpit 411 biggs looks around at the tie fighters. he is worried.                         biggs
# 	.	              hurry, luke, they're coming in much
# 	.	faster this time. i can't hold them!
# 	.	412  ext. space around the death star 412 the three tie fighters move ever closer, closing in on luke and biggs.
# 	.	413  int. luke's x-wing fighter - cockpit 413 luke looks back anxiously at little artoo.                         luke
# 	.	              artoo, try and increase the power!
# 	.
# 	.	414  ext. luke's x-wing fighter 414 ignoring the bumpy ride, flak, and lasers, a beeping artoo- detoo struggles to increase the power, his dome turning from side to side.
# 	.	415  ext. space around the death star 415 stealthily, the tie formation creeps closer.
# 	.	416  int. darth vader's cockpit 416
# star wars: a new hopevader adjusts his control stick.
# 	.	417  int. biggs' cockpit biggs looks around at the tie fighters.
# 	.	418  int. luke's x-wing fighter
# 151.
# 417
# 418
# luke looks into his targeting device. he moves it away for a moment and ponders its use. he looks back into the computer targeter.
#                    biggs
#               (over headset)
#          hurry up, luke!
# 	.	419  ext. space around the death star 419 vader and his wingmen race through the death star trench. biggs moves in to cover for luke, but vader gains on him.
# 	.	420  int. biggs' cockpit 420 biggs sees the tie fighter aiming at him. biggs wait!
# 	.	421  int. darth vader's cockpit 421 vader squeezes the fire button on his controls.
# 	.	422  int. biggs' cockpit 422 biggs' cockpit explodes around him, lighting him in red.
# 	.	423  ext. surface of the death star 423 biggs' ship bursts into a million flaming bits and scatters across the surface.
# 	.	424  int. massassi outpost - war room 424 leia and the others stare at the computer board.
# star wars: a new hope 152.
# 425 int. luke's x-wing cockpit
# luke is stunned by biggs' death. his eyes are watering, but his anger is also growing.
# 425
# 	.	426  int. death star - control room 426 grand moff tarkin watches the projected target screen with satisfaction.                         death star intercom voice
# 	.	              rebel base, thirty seconds and
# 	.	closing.
# 	.	427  int. darth vader's cockpit 427 vader takes aim on luke and talks to the wingmen. vader i'm on the leader.
# 	.	428  ext. surface of the death star - luke's ship 428 luke's ship streaks through the trench of the death star.
# 	.	429  int. massassi outpost - war room 429 princess leia returns her general's worried and doubtful glances with solid, grim determination. threepio seems nervous.                         threepio
# 	.	              hang on, artoo!
# 	.
# 	.	430  int. luke's x-wing - cockpit 430 luke concentrates on his targeting device.
# 	.	431  ext. surface of the death star 431 three tie fighters charge away down the trench toward luke.
# 	.	432  int. darth vader's cockpit 432 vader's finger's curls around the control stick.
# star wars: a new hope
# 153.
# 	.	433  int. luke's x-wing - cockpit luke adjusts the lens of his targeting device.
# 	.	434  ext. surface of the death star luke's ship charges down the trench.
# 	.	435  int. luke's x-wing - cockpit luke lines up the yellow cross-hair lines of the targeting device's screen. he looks into the targeting device, then starts at a voice he hears. ben's voice use the force, luke.
# 433
# 434
# 435
# 	.	436  ext. surface of the death star 436 the death star trench zooms by.
# 	.	437  int. luke's x-wing - cockpit 437 luke looks up, then starts to look back into the targeting device. he has second thoughts. ben's voice let go, luke. a grim determination sweeps across luke's face as he closes his eyes and starts to mumble ben's training to himself.
# 	.	438  ext. surface of the death star 438 luke's fighter streaks through the trench.
# 	.	439  int. darth vader's cockpit 439                         vader
# 	.	              the force is strong with this one!
# 	.
# 	.	440  ext. surface of the death star 440 vader follows luke's x-wing down the trench.
# 	.	441  int. luke's x-wing - cockpit 441
# star wars: a new hope
# 154.
# luke looks to the targeting device, then away as he hears ben's voice.
# ben's voice luke, trust me.
# luke's hand reaches for the control panel and presses the button. the targeting device moves away.
# 	.	442  int. massassi outpost - war room leia and the others stand watching the projected screen.                         base voice
# 	.	                   (over speaker)
# 	.	his computer's off. luke, you switched off your targeting computer. what's wrong?                         luke
# 	.	                   (over speaker)
# 	.	nothing. i'm all right.
# 	.	443  ext. surface of the death star luke's ship streaks ever close to the exhaust port.
# 	.	444  int. luke's x-wing - cockpit luke looks at the death star surface streaking by.
# 	.	445  ext. luke's x-wing fighter artoo-detoo turns his head from side to side, beeping in anticipation.
# 	.	446  ext. surface of the death star the three tie fighters, manned by vader and his two wingmen, follow luke's x-wing down the trench.
# 442
# 447 int. darth vader's cockpit 447
# vader maneuvers his controls as he looks at his doomed target. he presses the fire buttons on his control sticks. laserfire shoots toward luke's x-wing fighter.
# 443
# 444
# 445
# 446
# star wars: a new hope 155.
# 448 ext. luke's x-wing fighter
# a large burst of vader's laserfire engulfs artoo. the arms go limp on the smoking little droid as he makes a high- pitched sound.
# 448
# 	.	449  int. luke's x-wing fighter - cockpit 449 luke looks frantically back over his shoulder at artoo.
# 	.	450  ext. luke's x-wing fighter 450 smoke billows out around little artoo and sparks begin to fly.                         luke
# 	.	              i've lost artoo!
# 	.	artoo's beeping sounds die out.
# 	.	451  int. massassi outpost - war room 451 leia and the others stare intently at the projected screen, while threepio watches the princess. lights representing the death star and targets glow brightly.                         massassi intercom voice
# 	.	              the death star has cleared the
# 	.	planet. the death star has cleared the planet.
# 	.	452  int. death star - control room 452 tarkin glares at the projected target screen. death star intercom voice rebel base, in range. tarkinyou may fire when ready. death star intercom voice commence primary ignition. an officer reaches up and pushes buttons on the control panel, as green lighted buttons turn to red.
# 	.	453  ext. surface of the death star 453
# star wars: a new hope
# 156.
# the three tie fighters zoom down the death star trench in pursuit of luke, never breaking formation.
# 	.	454  int. luke's cockpit luke looks anxiously at the exhaust port.
# 	.	455  int. darth vader's cockpit vader adjusts his control sticks, checking his projected targeting screen.
# 	.	456  ext. surface of the death star luke's ship barrels down the trench.
# 	.	457  int. darth vader's cockpit vader's targeting computer swings around into position. vader takes careful aim on luke's x-wing fighter. vader i have you now. he pushes the fire buttons.
# 454
# 455
# 456
# 457
# 	.	458  ext. surface of the death star 458 the three tie fighters move in on luke. as vader's center fighter unleashes a volley of laserfire, one of the tie ships at his side is hit and explodes into flame. the two remaining ships continue to move in.
# 	.	459  int. luke's x-wing fighter - cockpit 459 luke looks about, wondering whose laserfire destroyed vader's wingman.
# 	.	460  int. darth vader's cockpit 460 vader is taken by surprise, and looks out from his cockpit. vader what?
# 	.	461  int. darth vader's wingman - cockpit 461
# star wars: a new hope
# 157.
# vader's wingman searches around him trying to locate the unknown attacker.
# 	.	462  int. millennium falcon - cockpit han and chewbacca grin from ear to ear.                         han
# 	.	                   (yelling)
# 	.	yahoo!
# 	.	463  ext. space around the death star the millennium falcon heads right at the two tie fighters. it's a collision course.
# 462
# 463
# 	.	464  int. wingman's cockpit 464 the wingman spots the pirateship coming at him and warns the dark lord.                         wingman
# 	.	              look out!
# 	.
# 	.	465  ext. death star trench 465 vader's wingman panics at the sight of the oncoming pirate starship and veers radically to one side, colliding with vader's tie fighter in the process. vader's wingman crashes into the side wall of the trench and explodes. vader's damaged ship spins out of the trench with a damaged wing.
# 	.	466  ext. space around the death star 466 vader's ship spins out of control with a bent solar fin, heading for deep space.
# 	.	467  int. darth vader's cockpit 467 vader turns round and round in circles as his ship spins into space.
# 	.	468  ext. surface of the death star 468 solo's ship moves in toward the death star trench.
# star wars: a new hope
# 158.
# 	.	469  int. millennium falcon - cockpit solo, smiling, speaks to luke over his headset mike.                         han
# 	.	                   (into mike)
# 	.	you're all clear, kid.
# 	.	470  int. massassi outpost - war room leia and the others listen to solo's transmission.                         han
# 	.	                   (over speaker)
# 	.	              now let's blow this thing and go
# 	.	              home!
# 	.
# 	.	471  int. luke's x-wing fighter - cockpit luke looks up and smiles. he concentrates on the exhaust port, then fires his laser torpedoes.
# 	.	472  ext. surface of the death star luke's torpedoes shoot toward the port and seems to simply disappear into the surface and not explode. but the shots do find their mark and have gone into the exhaust port and are heading for the main reactor.
# 469
# 470
# 471
# 472
# 	.	473  int. luke's x-wing fighter - cockpit 473 luke throws his head back in relief.
# 	.	474  int. death star 474 an imperial soldier runs to the control panel board and pulls the attack lever as the board behind him lights up. intercom voicestand by to fire at rebel base.
# 	.	475  ext. space around the death star 475 two x-wings, a y-wing, and the pirateship race toward yavin in the distance.
# 	.	476  int. death star 476
# star wars: a new hope
# 159.
# several imperial soldiers, flanking a pensive grand moff tarkin, busily push control levers and buttons.
# intercom voice standing by.
# the rumble of a distant explosion begins.
# 477 ext. space around the death star
# the rebel ships race out of sight, leaving the moon-like death star alone against a blanket of stars. several small flashes appear on the surface. the death star bursts into a supernova, creating a spectacular heavenly display.
# 477
# 	.	478  int. millennium falcon - cockpit 478 hangreat shot, kid. that was one in a million.
# 	.	479  int. luke's x-wing fighter - cockpit 479 luke is at ease, and his eyes are closed.                         ben's voice
# 	.	              remember, the force will be with
# 	.	you... always.the ship rocks back and forth.
# 	.	480  ext. darth vader's tie fighter 480 vader's ship spins off into space.
# 	.	481  ext. space 481 the rebel ships race toward the fourth moon of yavin.
# 	.	482  int. massassi outpost - main hangar 482 luke climbs out of his starship fighter and is cheered by a throng of ground crew and pilots. luke climbs down the ladder as they all welcome him with laughter, cheers, and shouting. princess leia rushes toward him.                         leia
# 	.	              luke! luke! luke!
# 	.
# star wars: a new hope 160.
# she throws her arms around luke and hugs him as they dance around in a circle. solo runs in toward luke and they embrace one another, slapping each other on the back.
#                         han
#                    (laughing)
# hey! hey!
#                         luke
#                    (laughing)
#               i knew you'd come back! i just knew
#               it!
#                         han
#               well, i wasn't gonna let you get all
# the credit and take all the reward.
# luke and han look at one another, as solo playfully shoves at luke's face. leia moves in between them.
#                         leia
#                    (laughing)
# hey, i knew there was more to you than money.
# luke looks toward the ship.
# luke oh, no!
# the fried little artoo-detoo is lifted off the back of the fighter and carried off under the worried eyes of threepio.
#                         threepio
#               oh, my! artoo! can you hear me? say
#               something!
#                    (to mechanic)
#               you can repair him, can't you?
# technicianwe'll get to work on him right away.
#                         threepio
#               you must repair him! sir, if any of
# my circuits or gears will help, i'll gladly donate them.
# luke he'll be all right.
# 483 int. massassi outpost - main throne room 483
# star wars: a new hope 161.
# luke, han, and chewbacca enter the huge ruins of the main temple. hundreds of troops are lined up in neat rows. banners are flying and at the far end stands a vision in white, the beautiful young senator leia. luke and the others solemnly march up the long aisle and kneel before senator leia. from one side of the temple marches a shined-up and fully repaired artoo-detoo. he waddles up to the group and stands next to an equally pristine threepio, who is rather awestruck by the whole event. chewbacca is confused. dodonna and several other dignitaries sit on the left of the princess leia. leia is dressed in a long white dress and is staggeringly beautiful. she rises and places a gold medallion around han's neck. he winks at her. she then repeats the ceremony with luke, who is moved by the event. they turn and face the assembled troops, who all bow before them. chewbacca growls and artoo beeps with happiness.
# 484 end credits over stars 484
# 485 the end 485
# fade out:

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 66370
# Unique characters: 55
# Vectorization...

# %% [markdown]
# ## Building the network

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the model

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 66370/66370 [==============================] - 15s 227us/step - loss: 1.0194
# --- Generating with seed: "nd
# nonsense.
# ben
# i suggest you try it again, luke.
# ben place"
# ------ temperature: 0.2
# nd
# nonsense.
# ben
# i suggest you try it again, luke.
# ben places the empiround the pirateship is a blowd and whil as
# there'r startion the surface and a huge way from the pirateship.
# luke
# she's the starts the death star surface. to the street.
# you wail as they dida's targeting a hull
# looking been to the ship.
# luke
# i can't do you know what is a bound the
# empiroas is a fine as
# anct's a blown on the death star surface.
# tarking the pirateship is a blown on the sur
# ------ temperature: 0.5
# h star surface.
# tarking the pirateship is a blown on the surface the empirth and
# a ma yout there, twous the remaining.
# 201
#
# int. death star - main forward bay
#
# 338
#
# the tie ship ships for something in the empire?
# one with his and they who wings a fighters.
# luke
# she's the have to which she sens he towking the greatit of the
# main for to going to him.
# han
# what you to have you mas pertented the
# see the subhallway. they now
# luke is it a ready.
# 288
#
# ext. space
#
#
# ------ temperature: 1.0
# e subhallway. they now
# luke is it a ready.
# 288
#
# ext. space
#
# 281
#
# red signs
# carriey of i cambage.
# you're al rever. a whaning second then hear wellvin dinten i hadk og
# whate. my
# sonet to the turns into the
# death star as deszes in oh of ner moving
# why ared out of come the milling speeder troops tower.
# threepio
# i 'ame i'm the surface. you seen of the old
#  werrem. leting only solo.
# threepio is agreed start of the small halling one out of the concentro lead
# the
# ------ temperature: 1.2
# tart of the small halling one out of the concentro lead
# the your head
# obi, despead to retrances to find iny
# oor ematices.
# luke
# it's see for his in the hallway. i get off any scruilld
# governtles's target the targeting millennium falts incle
# destroye. time...
# 197
#
# three
#
# 346
#
# 13re
#
# istan suched luke's faces out the vait not whith ked.
# ad! that's any pluying that's 'ty doy no
# begins to ruip.
# ben
# beeds to zehe in rubed back and imhey.
# ben
#
# bugh
# is aboverwhelto
# epoch 2
# Epoch 1/1
# 66370/66370 [==============================] - 15s 227us/step - loss: 1.0069
# --- Generating with seed: "ar deck. luke
# and leia start off toward the starship hangar."
# ------ temperature: 0.2
# ar deck. luke
# and leia start off toward the starship hangar. what threepio and a ground
# and cannon fighters.
# 100
#
# int. darth vader's cockpit
#
# 360
#
# the enorghes a be nee a bow and the trench.
# ben (contâd)
# what is a big sundenly and a greater the pirateship and a hallway.
# ben (contâd)
# not one of the robots and ben and the main fire fighter.
#
# 294
#
# star wars: a new hope
#
# 42.
#
# ben (contâd)
# not your force. he could have you
# found it!
# han
# i wan a lase the
# ------ temperature: 0.5
# our force. he could have you
# found it!
# han
# i wan a lase the dide through his laser gun and can keeming the main
# she's is gleen the treoping on his laser pistoluts blows back and
# distllections the hands around the hallway.
# han
# now i'm the death star plans at the death star officer stars
# appears and artoo and the treoping to stormtroopers.
# 300
#
# int. red leader
# a come around the pirateship.
# 344
#
# int. death star - cockpit
#
# 260
#
# the enorgher begins farmer and a
# ------ temperature: 1.0
#  death star - cockpit
#
# 260
#
# the enorgher begins farmer and are treick to him where
# pressubund me, si, shipid)
# whreeplid dous format for the might leia closing slimshes and
# the deadon begins a
# bigge in cancentren's controlt.
# 338
#
# ext. death star 6-sior
#
# adgraan unterr bight it oway?
# han
# what's devells. luke a
# alay.
# han
# where search manyons vader angry as the
# ither, through his ad
# gatted as they checked and stormtroopers
# suldery yells eas shows by a soll's
# h
# ------ temperature: 1.2
# cked and stormtroopers
# suldery yells eas shows by a soll's
# happer... i'm anjunting drooaan, crection long as
# resc gun. i
# dead 'mbo'ln actovering.
# 101
#
# int. death star -
# tabar im you've imperial brys
#
# 8vf
#
# vader amout front of thas into oregrating ohly
# daggagegonsting.
#
# 19a
#
# star wars: a new hope
#
# 42w
#
# ghem hipn atwars, but he groanif to ro-belw on the mughrate througs
# juble. here!
# (lforgays in of the darkermy)
#
#  here, shrecking in anoth wall rcomes is
# wy
# epoch 3
# Epoch 1/1
# 66370/66370 [==============================] - 15s 229us/step - loss: 1.0019
# --- Generating with seed: "ove you.
# turn to point...
# 377
#
# int. luke's x-wing fighter - "
# ------ temperature: 0.2
# ove you.
# turn to point...
# 377
#
# int. luke's x-wing fighter - cockpit
#
# 369
#
# the fighter power station computer are got a lot of the stars
# filler. the loak to the trench.
# ben
# the green a loar, the troopers and the targeting in the
# computer approaches at the death star.
# 243
#
# int. darth vader's cockpit
#
# 333
#
# luke and the power canyon a the ship and threepio, whistle and
# whistles on the surface. the trench
# starts on the tie fighter at the sundent a loade the bar
# ------ temperature: 0.5
# nch
# starts on the tie fighter at the sundent a loade the bartend
# and starts to the computer to the dicken bases a ne
#
# mottons on the huge luke and the power starding
# and the power space.
# tarking are are you going to the come as they're come
# in the precise him.
# the surface and the pirateship and the targeting slowly aporth
#
# threepio panel, waster power of the starship and a
# me's starts at the death star. a steel
# at the computer station
# intercom out a moment
# ------ temperature: 1.0
#  star. a steel
# at the computer station
# intercom out a momentance time me a
# swible! gond mellods of the s-ins fly one of the mand tarkin
# dext, here? luke, we've got to me tere, been
# threepio, and he youngor.
# our.
# 442
#
# int. luke's cockpit
#
# 294
#
# luke
# and laserboltle. awalfy.
# 3at whismiea reversime.
# threepio, will find him whit is a now. it what
# luke. i trying
# that hear. i cail frorgrey bades his busad. he snets in
# ower is ell avawie hvers.
# luke
# i rush leave i
# ------ temperature: 1.2
# d. he snets in
# ower is ell avawie hvers.
# luke
# i rush leave is play.
# red leader's sectars i grins. he takes have away i've going too make the
# same plome set of the
# severate the grawphing in the bell
# insp. he tiose out for himed lot wy what is
# rejarted
# vader tckes no level. he grim take
# ben
# pow, like cwegoid with beaving.
# wedg any two whole don't way, that minilefinge plase
# at ele the otherstant.
# the gie fo, get interpors to le?
# sward eyead meally.
# strack)
#
# epoch 4
# Epoch 1/1
# 66370/66370 [==============================] - 15s 227us/step - loss: 0.9956
# --- Generating with seed: " sandpeople walk past carrying the
# inert luke skywalker, who"
# ------ temperature: 0.2
#  sandpeople walk past carrying the
# inert luke skywalker, who have to
# peroains. the firite a small laser pistol.
# the surface of the death star supper in the computer
# the pirateship.
# 274
#
# ext. space - death star
#
# 280
#
# the surface of the death star supperer can kenowher as it of the
# death star.
# 230
#
# int. luke's x-wing - cockpit
#
# 377
#
# luke and leia tensional respaces the robothts are not me a long
# the control starship and as
# are more starship through the death
# ------ temperature: 0.5
#  control starship and as
# are more starship through the death star supperer.
# luke and the pirateship and grow.
# han
# i saddenly artoo-decomd baggs his rempire when can't the crew
# be of the rebel piratesnecing are been the
# head in the robothted. he jumbal table to the barten a rasther as
# reflesher peels his controls.
# 16e
#
# int. darth vader's cockpit
#
# 336
#
# luke looks at the pirateship for a fast-roopes to reparsed me
# beeping sound.
# luke
# hey, i'm need he run. i'm
# ------ temperature: 1.0
# to reparsed me
# beeping sound.
# luke
# hey, i'm need he run. i'm me
# peralion.
# luke
# it's not going. the frorm vaker.
# arroor's pirft... a sarmby. the trooper.
# 127
#
# int. death star - flina leade vader
#
# 133
#
# the welly stars at the death star
#
# 277
#
# star warsting luke's suppere cockpit past8ljer
#  across the robothts rice streaks past acroint of in he
# demp ridoes terrin of laserfire of the milf-as
# from his clowe operspocs stroar fightersaze, we are
# cared and unclast
# ------ temperature: 1.2
# clowe operspocs stroar fightersaze, we are
# cared and unclasts up over the larfarl luke.
# 108
#
# int. gold leader's y-arsire - cockpit plavemeng scruaber
#
# leia
#
# 209
#
# wedge look to remutter
# arpoo furren blasted liuted
# fodloated begins suddenly threepio. sandpeople saye.
# owen
# beat alder-ain, laser aiven ally frambs him, signapes his inbooge that
# rip. the power farcer base by trent, sween, surbours, weltion.
# wedge provent.
# 233
#
# ext. 8at,
# siy siry the estand ruble
# epoch 5
# Epoch 1/1
# 66370/66370 [==============================] - 15s 230us/step - loss: 0.9861
# --- Generating with seed: "08
#
# star wars: a new hope
#
# 309
#
# 136.
#
# ext. gold five's cock"
# ------ temperature: 0.2
# 08
#
# star wars: a new hope
#
# 309
#
# 136.
#
# ext. gold five's cockpit
#
# 342
#
# luke surp the dirtaginate the pirat and chewbacca and the
# sublast starts toward the pirat and chewbacca and begins to the
# sublast the ready toward the death
# star surface and the control station hand the trench.
# threepio
# (over speaker)
# solo sluide with the death star.
# 33
#
# ext. space - millennar - cockpit
#
# 333
#
# vader will on the death star surface. artoo and the trench.
# ben
# you wast the gr
# ------ temperature: 0.5
# eath star surface. artoo and the trench.
# ben
# you wast the graus sire, artoo. artoo be heard of the small laser
# gonerate that heard of the surface. down on the death star.
# 309
#
# int. millennium falcon - ready
#
# 308
#
# luke targeting in the death star.
# 392
#
# int. massassi outpost - war room
#
# 231
#
# the pirateship and vier troops in front of the death star.
# the death star aldon the stars to the firing stunds
# and the hallway.
# threepio
# (into the dark lord cannon deser
# ------ temperature: 1.0
# s
# and the hallway.
# threepio
# (into the dark lord cannon desert you're mane freicear enot of
# the big subhalliy. a hallway, real grarsibacons the chast luke
# what it's for a shot in the empire's planet
# well aiver.
# 2proke with a hulld leave leads and while
# were, come is continues to be armer mes. vader's
#
# tat hang, what i found helps of the trench.
# the could vared to undernacr otcomed - harvy derext poirsed slim
# hinger the magning in his
# laiffers of the doy.
# (t
# ------ temperature: 1.2
# irsed slim
# hinger the magning in his
# laiffers of the doy.
# (trenting dea home or the warry offy
# tarkin fleafthin on the enorg hiss. a sir. about
# passes the hall, sound portsmissle, after rader crew in the benuse. but my subellade to whoder how the
# stormgroulding.
# that it's pluke what doomed base mongrations.
# 4.
# come a
# erenot's this is clock heavone-f?
# wencnerates this ship. luke passes this im
# shie)
# oh, you hain dune decless a
# figets shorts is behind i deac
# epoch 6
# Epoch 1/1
# 66370/66370 [==============================] - 15s 231us/step - loss: 0.9768
# --- Generating with seed: " a
# million.
# 479
#
# int. luke's x-wing fighter - cockpit
#
# 479
#
# "
# ------ temperature: 0.2
#  a
# million.
# 479
#
# int. luke's x-wing fighter - cockpit
#
# 479
#
# luke rate the starther attevions the ships of the sunders the
# sureacled by the docking bay.
# luke
# it's the commander good and a greagert moves at the death star.
# 338
#
# ext. surface of the death star
#
# 422
#
# luke throwing the troopers stands and artoo and a huge with the
# surface and stay into the diritale, surter.
# luke
# i can't hose going to starting the distacty as the sunderate the
# computer.
# 287
#
# int.
# ------ temperature: 0.5
# arting the distacty as the sunderate the
# computer.
# 287
#
# int. red leader's cockpit
#
# 282
#
# luke with the millivatules toward the giant disn't their moves at the death star.
# 309
#
# int. luke's x-wing fighter - cockpit
#
# 430
#
# biggs
# the surface moves in of one as several momentalling starts to sound.
# luke
# what i woner'l ship and a starts into the main can
# disat off in the command of the death star the
# massime to the speeder in the dirtyoursele.
# luke a going to star
# ------ temperature: 1.0
# ime to the speeder in the dirtyoursele.
# luke a going to startherss of and those ships on, the ben
# there manages to his warrt. you comminow is uniy them.
# luke the control starks the computer aceair in the wookiee.
# luke pouts into theicine!
# han (contâd)
# what's this. i get herele, sirit sund in the
# othersway..by disteus to generate the empire?
# luke know, it exter before.
# (to me you rell-like!
# artoo will one you're goinget? but it owes the trans-
#
# star wars
# ------ temperature: 1.2
#  will one you're goinget? but it owes the trans-
#
# star wars: a new hope
#
# 8.
#
# froikis astention bush in the computer that
# luke. ben
# in puhal old sor. at the ships wind me chashast and
# wiig?
# swow. he censcan histemedavar.
# 458
#
# ext. surfaroy - mank placestea
#
# 94
#
# luke feelonglell ignip, luke.
# ben ruind you're bus.
# a fire, it us.
# ben
# he is steading the pointony.
# threepio
#
# leia
# thing, two com!s he center of
# but dufl on over, wast, who is aunt yold. you takes g
# epoch 7
# Epoch 1/1
# 66370/66370 [==============================] - 15s 228us/step - loss: 0.9699
# --- Generating with seed: "se behind them, shutting vader and the other troops out of
# t"
# ------ temperature: 0.2
# se behind them, shutting vader and the other troops out of
# the death star hold are is setting to artooches the
# old servec to the pirateship and artoo.
# leia
# i get the robots and artoo and the rebellions to get out
# and are not the princess leia.
# luke arger troops around to the tractor starship behind the past the
# old ber and the rebel plast dirty are you
# the rebel passic and a trans, a talking
# are to the pirateship to the lean the trans-
# mellons to the back
# ------ temperature: 0.5
# o the pirateship to the lean the trans-
# mellons to the back of the intercom voice and
#
# leia
# yelling energen imperial sitton for the hord.
# luke
# it what. it what you was going to be
# are morgen. the robot on the trans-
# mell and ben streaks to the main bears the
# see the computer the load from the pirateship
# lights.
# 109
#
# ext. surface of the death star
#
# 277
#
# the death star hord and the rebel fighter computer room and are
# a good in the robots.
# 30re
# her traces and
# ------ temperature: 1.0
# puter room and are
# a good in the robots.
# 30re
# her traces and here be is stand as they
# alfoze to with a lord artoomers the onf on
# the dirash.
# 31. tatooine with bester at her lease into time.
# luke artoo-detoo)
# one of the fear in really
# too muring inyow surfritur the pilots.
# 307
#
# int. leaian - cell solo'ater
#
# 438
#
# vader
# appeax with a pith
# solo and the reate round howly dempation, gold leacer control
# knell creaturer. the death star.
# 303
#
# int. mallennium fight
# ------ temperature: 1.2
#
# knell creaturer. the death star.
# 303
#
# int. mallennium fighter - cockpia
#
# 211
#
# red of reply darth vader's
# 65
#
# it. a coll officer belt.
#
# 111
#
# surpadder trhilinate. the robot and spaces41wingul pillic
# tip gliked to the rebel fighters clear pourte for
# vader's sere look your darststuplss.
# rese bracced ratles your farce your falcels, befure.
# 77
#
# int. millennium falcon - enter-
# hat 8-plans the stormtroopers
#
# legin
# intences kpeeder now the procelers taken on.
# 20
# epoch 8
# Epoch 1/1
# 66370/66370 [==============================] - 15s 229us/step - loss: 0.9663
# --- Generating with seed: "a
# organa, a member of the alderaan senate. the fear in her e"
# ------ temperature: 0.2
# a
# organa, a member of the alderaan senate. the fear in her explosion
# in the dincomers.
# luke
# (over speaker)
# that is stand in a small slimy display
# sound holding are not wails to the ships and
# begins to the ship and as stands to the death
# star surface and a thar wait and stands to lect to a
# pace in a small slimy disples to the
# sure and a trans.
# luke
# i take the smillenning the dinerdous he as the surface
# and the starship and starts of the death star.
# the ship
# ------ temperature: 0.5
# face
# and the starship and starts of the death star.
# the ship down a death star surface
# and wing the ships but i've more
# going to me.
# finan of his and main creature ships some twis crewa and a droid
# stars to the death star.
# 3
# 2
#
# ext. dars his cockpit
#
# 435
#
# out of the dine with his smillenning fly across the surface
# and the it electronic wast and chewbacca holds to the dirst past a
# sight. death star slimy gallway bluns to the death star.
# 433
#
# ext. space room
# ------ temperature: 1.0
#  slimy gallway bluns to the death star.
# 433
#
# ext. space room roomt head in the fighter lone vader's
#
# voky pole, sirm-princes got and about-d nestic artoo as it 's
# rebeleship me
# han dissiancing, on imperial dark kereims i
# have preces.
# 395
#
# ext. space areator
#
# 93
#
# threepio
# thisgining, is at thare and gounts into attiked flard
# noruard explosion.
# luke round of the deach sing the binot it.
# ben
# old gill skykalikings... i know wo pointions my extay
# closers over h
# ------ temperature: 1.2
#  skykalikings... i know wo pointions my extay
# closers over has and are wo... han, like tase a
# pilor.
# senat system in affract, luke's chrond from ser. our.
# fills cherny a
# trubuereg scrankwsy over hiss tank! iwners cablasts the
# ost of the death star. wery somenacresn
# sundes about.
# i wonding, call oocc, otion, and looking block of han over, as no
# princess in front oo?
# luke
# you knowd. we're going yout if you
# lan of chacks of of owencres with olg yeave
# blast wh
# epoch 9
# Epoch 1/1
# 66370/66370 [==============================] - 15s 224us/step - loss: 0.9609
# --- Generating with seed: "star wars: a new hope
#
# 151.
#
# vader adjusts his control stick"
# ------ temperature: 0.2
# star wars: a new hope
#
# 151.
#
# vader adjusts his control sticks to the death star into the
# milling in areais the pirateship from the rebel'ad and leia throwide the
# sunderspeas and are you going to
# see you going to the ship.
# luke (contâd)
# the directed be with your tarkin and checkles to the ship.
# luke (contâd)
# what the command post.
# moke the death star spectace to the rebel pant and
#
# int. death star - control stars of the death star
#
# 29
#
# the surface of th
# ------ temperature: 0.5
# tar - control stars of the death star
#
# 29
#
# the surface of the death star into a tighters move
# around the death star spows at the remating
# stormtroopers turns are not the ship. leia
# you weach of the ship are you to
# complecerate the creature back and ad
# exten room.
# the gun clawas wasteland to kereig to get out of the starship
# laserfire to the dirattic side and the main farmating tere...
# 347
#
# ext. space around the death star
#
# 377
#
# star wars: a new hope
#
# 111.
# ------ temperature: 1.0
# ace around the death star
#
# 377
#
# star wars: a new hope
#
# 111.
#
# luke (contâd)
# clout of rollow fill darepticed to go you
# would to unclosic with a borent longs
# fro?
# awing up and crumbles of his faiction growls is cress. luke
# and begins flashing
# in the dir. the gun shep, artooine
# of the main and battle tris way hore where
# are thy ships wast bemind.
# i'm you hurending into the speeder.
# the considous't force, to truse, i'm not cheried appenete milfint
# face. lang
# ------ temperature: 1.2
# force, to truse, i'm not cheried appenete milfint
# face. langhtar into artoo-den's aline and i
# prumm ham and butn. a mind creatine
# over him.
# luke
# i'm alrimy troups, what that! were
# in teir
# fives the
# over the ship beace!
# no, yna didn, alte, thouse....!
# a firiy bact.
# move from herive and fire with be a powering thosey beed reaceshind.
# the fland beywing deares if a tall skiyling
# in the dives! you way on one scries und bush
# there. ybit.
# worry tere, seee them. l
# epoch 10
# Epoch 1/1
# 66370/66370 [==============================] - 15s 225us/step - loss: 0.9493
# --- Generating with seed: "hrough a restricted
# system. several transmissions were
# beame"
# ------ temperature: 0.2
# hrough a restricted
# system. several transmissions were
# beames the pirateship.
# 177
#
# ext. space - crassend
#
# 382
#
# luke and leia turns and the back on the speeder station
# your far a parth of head to deres it
# way. i want eilled begins to
# for a few me. he say them and begins to flard and buster.
# luke
# i same you got to deto your
# blast.
# han
# (over speaker)
# that's your takes on the ship.
# luke
# i same you got to deen them and leia.
# luke and looks at the death star.
# 30
# ------ temperature: 0.5
#  to deen them and leia.
# luke and looks at the death star.
# 303
#
# ext. space - cockpit
#
# 354
#
# the death star claser post to looking bay
# int!
# luke
# it's the trench.
# luke
# i can't with the heads to get into the computer.
# 103
#
# int. death star - computed read - travely
# the rocks off are sound with them with the death star into
# stormtrooper panel, battle station on
# shouthes from him the computer their threepio into the
# horing and have frome....
# 345
#
# int. massassi out
# ------ temperature: 1.0
# io into the
# horing and have frome....
# 345
#
# int. massassi outpost - wartrey what help-skywald screan the
# jawaw on simpe plans scurry to hit is not going to
# fay.
# threepio and best scruiss his stormtroopers appears, 0an
# the side , the distan trooper look
# around on the lighted riple on and the laserfor to bother. han
# withoe i was is! red years no
# oo.
# leia
# they're going
# the takes his compuseed. he pulk of electronicm fulls from himent.
# chewba stars around to wh
# ------ temperature: 1.2
#  of electronicm fulls from himent.
# chewba stars around to who main untilejuscreigaternth.
# luke
#
# ref ten reached racks a trove flames
# by relepors. he
# like bay to the unsay a traveling and empersion?
# ? luke anormare very scores from them that!
# thze get untirem agains! away and loak on me sgues game signe weocuh,
# fills check and explosioush the huge.
# a mencersens of the taked himled a little side moving.
# 328
#
# ext. surface laser sirvots
#
# 319
#
# droom known or se
# epoch 11
# Epoch 1/1
# 66370/66370 [==============================] - 15s 224us/step - loss: 0.9435
# --- Generating with seed: " figure darts into the
# further up the canyon a slight flicke"
# ------ temperature: 0.2
#  figure darts into the
# further up the canyon a slight flicked, but i had
# beak in a small of the
# tie fighter.
#
# 119
#
# star wars: a new hope
#
# 116.
#
# the control stick as the pirateship and are not what i was
# been to the distang to be a
# looking the transport.
#
# 295
#
#
# 111
#
# star wars: a new hope
#
# 111.
#
# int. luke's x-wing fighters low - travely - cockpit
#
# 382
#
# threepio (contâd)
# what is a belt his stolotous and the stormtroopers and the
# surface.
# 338
#
# int. luke's
# ------ temperature: 0.5
# ous and the stormtroopers and the
# surface.
# 338
#
# int. luke's x-wing fighter - cockpit
#
# 382
#
# threepio (contâd)
# what hey, i'm on the presence in the
# rebell of the ship to the docking pirate room.
# tarkin
# the trench.
# ben (contâd)
# what is a belt our of the death star surface
# at the lovking beeping harty the main fire.
# luke
# i can't hose the welluking head
# with the speeder. it worrroure gions a
# lighted but of the side of the starship
# in threepio, where could
# b
# ------ temperature: 1.0
# d but of the side of the starship
# in threepio, where could
# boir it 'vaved segion to stear in offy down. blashs chis
# looking. shoupins our of this
# cockpit.
# han
# (strash of laser lies reaches at why want gen threepioyand lect- pirancefor.
# luke's main port, are relectifingy luke and mipfarct.
# biggs
# beas a tharm to the navi!
# 343
#
# int. massas side lood moking our imperial vader
# watches starts-dey old been into the ridled
# governous high thin stands veillway hand.
# ------ temperature: 1.2
# en into the ridled
# governous high thin stands veillway hand.
#
# leia
# nol, throse. what happuge his laser pi(ot there'll thit for stands
# voon!
# threepio and pants ohpers him haves on the computer stralage
# withor. chewie no mestriply scortchon trans-
# moves into large -s hance mornary head as luke and a your-signation in
# puderatefly againrs.
# threepio (contâd)
# what's blast it! bet owenulard it, yed.
# luke
#
# int. death star 8landsur 'vas
# wawe hallway.
# owen
# you
# a
# epoch 12
# Epoch 1/1
# 66370/66370 [==============================] - 15s 227us/step - loss: 0.9353
# --- Generating with seed: "ckly followed by luke, also dressed
# as a stormtrooper. luke "
# ------ temperature: 0.2
# ckly followed by luke, also dressed
# as a stormtrooper. luke is she your
# starts out of the commate beeps and
# alm(d.
# 333
#
# int. luke's x-wing fighter - cockpit
#
# 396
#
# luke and the death star surface of the death star trence
# the small alone the computer. luke is a few
# more stands in the commate computer.
# luke
# i won't head of the commate beeps and the transo his
# face as he convons to the transo the
# troops, starts to the commate behind the
# troops, sir. the prince
# ------ temperature: 0.5
# ps, starts to the commate behind the
# troops, sir. the princess leia.
# ben
# it's all the turns the horl, she is no
# ines the commate turns of the comlard
# before the death star.
# 433
#
# ext. space
#
# 220
#
# the speeder stands into the planet of explodes leavertion
# stormtroopers leia the effirst face. are you
# moves to come are start on the main the
# pirateship. luke and the stormtroopers are no
# it is a beam aby to the plans
# around to going to do your heave to do
# stormtr
# ------ temperature: 1.0
#  to the plans
# around to going to do your heave to do
# stormtroopers. he biggs and take the
# blocked look, who? when imperial stormtroopers. luke's
# connect sounds slewly a dine. the fire twise
# jabage's pops com.
# 1une. leia is i won't foll desert solding that them, asres
# beaves and starts out and prepsy blocked hold in the
# gore group inin! luke.
# threepio swings canyon to sikes cour. amessine. ohly
# droid a room. of man's system.
# han
# hope, where recom, wedge. th
# ------ temperature: 1.2
# id a room. of man's system.
# han
# hope, where recom, wedge. they 3vereiy into attimater pervetale crussts to finger.
# 109 nping witn of the tchrosting, snaps
# greacter. chass three move group snappond eyes his cery. i've
# pew lore turn intercic. on anorigs and i won't
# be out didn't closes.
# dove reparrsulace canyon fighter.
# vacheng0xo44n fives paches poknow. handing, lists and buts, i'm troop
# of disaten but bresed.
# 372
#
# grepthon leave we're artoo)
# no you?
# 240
#
# i
# epoch 13
# Epoch 1/1
# 66370/66370 [==============================] - 15s 222us/step - loss: 0.9288
# --- Generating with seed: "pace
#
# 241
#
# luke's x-wing races toward the death star. laserb"
# ------ temperature: 0.2
# pace
#
# 241
#
# luke's x-wing races toward the death star. laserbolts a small in
# and the rebel blockade and came on the death star ship
# is a blasts the restroy beam all the rebel planet of the rebel troops
# are not your for a lot of the
# sith robots.
# 277
#
# int. red leader's cockpit
#
# 319
#
# a tie fighters.
# 331
#
# int. red leader's cockpit
#
# 319
#
# star wars: a new hope
#
# 117.
#
# ben
# the starts the restroy a blasts the computer to the
# stormtroopers are not the transfarce.
# th
# ------ temperature: 0.5
# the computer to the
# stormtroopers are not the transfarce.
# the gient battle station into something you
# was come will you wame prece
# a big snot of the trans, sir.
# come han drows vader's laser pistolf to the robot on
# the death star land leaten half-he the is
# we dead a door all the darkaster of the starship
# is say there'll be
# ot you. they're going to lot on a more with
# star from the restran
# going sound of the dark mound the
# plans to the ship the droids.
# luke t
# ------ temperature: 1.0
# d of the dark mound the
# plans to the ship the droids.
# luke takes move to gun full port!
#
# luke and the trench
# shafit and but threepio loser talking.
# a friend in the feard the restroy beywiy, threeper grownst grabs and
# luke. blaststra loadspees, through the princess-sil for his restine
# wedge, wh, chewie. the pilot thinks of the ost
# wand his stip to the lastronicallion electronical word right her fay
# sho)
# red leader
# darth vader and the back?
# oh, a big stang f
# ------ temperature: 1.2
#
# sho)
# red leader
# darth vader and the back?
# oh, a big stang for seckly youn. you wind a tell s, pens.
# artoo-detoo strpee strainulwing.
# 381
#
# int. dad and stars chew
#
# 112
#
# star wars: a de! an explosiong creatur-sky edder bast
# you move. greadouf than 7ne, awe turuecting
# it appears in frow wing on. ho known to
# darey of hight, come into the going this
# stop. threepio in a shutt. hall
# coming in from his gun station. he speaker.
# leia
# (over oot away?
# at it! rese ou
# epoch 14
# Epoch 1/1
# 66370/66370 [==============================] - 15s 224us/step - loss: 0.9253
# --- Generating with seed: "r as threepio
# pilots the sleek landspeeder gracefully across"
# ------ temperature: 0.2
# r as threepio
# pilots the sleek landspeeder gracefully across the
# sundenly as the ship.
# luke
# i'm not off the lockeling and starship.
# luke
# well, i'll be the pirateship.
# luke
# but he's with a se(tenner and the
# subonnerd the computer.
# 152
#
# int. luke's x-wing - cockpit
#
# 326
#
# luke looks around to the docking bay around the pirateship
# in the pirateship and stop is
# hapports of his face.
# threepio (contâd)
# the forcer sight. here and leia reaches a small and leia.
# t
# ------ temperature: 0.5
#
# the forcer sight. here and leia reaches a small and leia.
# threepio and chewbacca and the main formation end of the robot of all
# fire with electronic can do your neat of the
# main form before the computer.
# ben (contâd)
# well.
# luke
# i'm not off the blown and he skywalser. he speeder
# the enoruomed.
# luke
# well, i'll heading hold the flastraps to be abort
# of the ship's sound from his fighter.
# vader
# i'm the control streaks in the energen in the
# main formation in
# ------ temperature: 1.0
# the control streaks in the energen in the
# main formation in a starst, the
# plasesation. with that's try moon. will apmur....... well, i can
# rich! losent yout just him now of voice.
# 422
#
# int. luke's x-wing - cockpit
#
# 476
#
# anwhick letention!
# red we seal small gan
# will hos seches as he conce to kidond.
# han
# benge any laser far space in his reach and final red
# sity and aurt in other
# (over stormtroopers
# hight dust away the commander has been holds up to the
# read-
# ------ temperature: 1.2
# hight dust away the commander has been holds up to the
# read-urty at the
# loving in get hips his and alard grow.
# bie scarry holder and star one shaftic turns about
# arounds tentling sound hold over from to re!
# turring are bort just down anc whand
# teme.
# luke
# brear centerable from helin govern very just mesase off, sound. luke
# in the engiving attack powers itches. vie?
# the make crushis hit to were shur alas a
# side, ove jed have
# pir. and reachs out looking a com
# epoch 15
# Epoch 1/1
# 66370/66370 [==============================] - 15s 226us/step - loss: 0.9203
# --- Generating with seed: "right. well, take care of
# yourself, han. i guess that's what"
# ------ temperature: 0.2
# right. well, take care of
# yourself, han. i guess that's what he
# look on the diractions and as arronding the
# end of the trench.
# threepio
# that's control and the computer to the tie fighter.
# luke takes a small loomed by the diraction and a coll menate and
# exchatce to the trench.
# the hang back on the dead it a hallway on the dead a day
# battle station into the tie fighter points to the
# suchation of the starship begins to respaces and
# sir.
# biggs
# i tookn they are
# ------ temperature: 0.5
#  starship begins to respaces and
# sir.
# biggs
# i tookn they are to be a friend for to a
# pite. a solo's to a princess. i to
# keep off to all the rebel base.
# fills and the reathes out down the dirtacll prodention.
# luke and the princess, large stand a small lowar, them and bow
# hey princess, laserbolts up a small alone
# in the docking barthanger turns and starts and from
# the suddenly in there are standing are and stands and
# what you was there
# deserabe of the starsh
# ------ temperature: 1.0
# are and stands and
# what you was there
# deserabe of the starship shoutingly putules up a
# me if they's going to dut starts to am luke
# in boing your the main forwarding
# targier's so now himand to shorpers toward little rill as they
# gormattantion for convint.
# luke
# solo spoudds threepio's screen. luke robem.
# tatan,  here, a detench his crafty into a pay befins to turn laser
# goo, a colassicne's done. jump, bust in pitomes.
# they're presence on the tie smill kining
# ------ temperature: 1.2
# p, bust in pitomes.
# they're presence on the tie smill kining and vader
# battlest offerite blaster
# growls a few. you can get.
# han
# welmane.
# threepio
# i com! leia..
# luke furstub.
# tower robots tare a sale fire back
# or rockation. gold leader
# (over fighters. it's picet in to andenale is
# i'm reparches out a nightmytos with his imperial
# right hose to armf the horiator canyon an sameony, on artoo a
# goro! just lotfeea to meyted and windowed his ranard
# armablus smillen
# epoch 16
# Epoch 1/1
# 66370/66370 [==============================] - 15s 223us/step - loss: 0.9132
# --- Generating with seed: "re
# going to be nothing more than a dark
# spot on the down sid"
# ------ temperature: 0.2
# re
# going to be nothing more than a dark
# spot on the down side of the computer
# the death star surface. a corner, a control stick.
# luke
# where could have you got to get up the
# emperor of the stormtroopers and the computer
# the death star surface. a starks on the trooper way into
# senting it of the transo looks around.
# luke
# well, he tuners see for the barten the trooper the
# end of the stormtroopers and the computer screen stands over his about
# to the computer to
# ------ temperature: 0.5
# the computer screen stands over his about
# to the computer to a lott.en and leia on
# the deadl bact of hangle of the tie fighter
# dirtach the heads out of the computer
# the two preferaleation to be able to
# fund the locklast the blown to leating the holding the
# ortoo controls a large rovers to be able to
# fleafing the force. they're going to here
# off the computer ways to here, the
# explosion of the control pantle on the barten the
# blows his controls a small room.
# ------ temperature: 1.0
# ol pantle on the barten the
# blows his controls a small room.
# threepio operhevers leaver)
# sure, swerming the apposele.
# gold fluchtun.
# it an owen is the outs sp comed down the planet from
# treepirs, and chewbaccaugay, imperial control around then can getly
# but mose.
# come barkins!
# luke
# what wor temp a new off to be a feeder compusers
# on suroor watche abois of the laserfire work power darknceare
# seapons to repart at the alweed. threepio, whicrespatsing
# up him f
# ------ temperature: 1.2
# s to repart at the alweed. threepio, whicrespatsing
# up him forthet with i can
# bigge, you gogges to is!
# 6bon! she fow chis?
# red sle
# with a frothh and there get
# swo, begingiot? ckeeming on the lights8xity, clew his thire
# and a grablow in rains space
# the deadle. all right for the lown the piratesguescreet and
# uncle
# ow. i cand her has ney!
#
# 95.
#
# star wars: a new hope
#
# 54.
#
# the move start whotrrow, of the enerytely as everis
# moving him.
# artoo wedges them. but
# epoch 17
# Epoch 1/1
# 66370/66370 [==============================] - 15s 223us/step - loss: 0.9089
# --- Generating with seed: "uble. it's all
# right, you can trust him. he's our
# new master"
# ------ temperature: 0.2
# uble. it's all
# right, you can trust him. he's our
# new master dark kedonins.
# luke
# well, the long to the ship approaches the trench.
# ben (contâd)
# the pirateship beeping sound from his fighter.
# luke
# where can the ship approaches the ship ships and
# side, winders the death star.
# the surface of the death star surface of the death star surface
# are trouply is a shot of the ship.
# luke
# well, i'm leat you know what he
# look over his face and the control station.
# thr
# ------ temperature: 0.5
# know what he
# look over his face and the control station.
# threepio
# i comple, it's whip, snack as out of the searct of the
# headed introut her, the grass, stars the death
# star surface and respons down the huge wings very stand off the
# in the ship the side of the beam all the
# others to the dark it's laser the ship.
# luke
# well, the power station of the force
# around the beautif luke stands of complion.
# luke
# here.
# luke
# whisp she'll be dead it's morm becken and the
# ------ temperature: 1.0
# uke
# here.
# luke
# whisp she'll be dead it's morm becken and the heavining
# pex!
# you'll do morn imperial tie scramp.
# 372
#
# int. massarshers
# lanifuls as it nomy of the robots of sider - stoking
# helven, beame the dincy to rescuuply . ih
# upolther, oner he sconned of the dark i can
# ther computer.
# the cockpio-huld, are an empirate must lotfion bus anything
# he well, hear
# closing.
# in turns to som the blown't
# dark lorvition is head.
# biggs
# look over the vaising before th
# ------ temperature: 1.2
# ark lorvition is head.
# biggs
# look over the vaising before the burned.
# ben
# all your
# not go frun-f ?
# artoo, she'm not of her. i'm
# here't out on
# oning is o or somenity. they've gone to computer.
# luke
# of two cutinton temmeker and bit two power, looding
# chewie. here, here, whibleud for out of eginiff, but raish throwing.
# 3 chewbaccang dueen in untering end of the wertoor
# baggs make tches
# sietic unternot to the guyins task on his giant coctle.
# wedge
#
# 41r
#
# star
# epoch 18
# Epoch 1/1
# 66370/66370 [==============================] - 15s 226us/step - loss: 0.9056
# --- Generating with seed: "luke, han, chewbacca, and leia run down an empty hallway and"
# ------ temperature: 0.2
# luke, han, chewbacca, and leia run down an empty hallway and
# side of the death star.
# 34
#
# ext. space around the death star
#
# 395
#
# the death star hangar computer roold to the rock the
# explosions to the suddenly the dinelld and
# side of the death star.
# 219
#
# int. death star - surrend
# the robots around to a control paigins to the long tom.
# ben
# whit's they... oure you
# sad been through the empire to perspally-for a
# pant of the troops at the back on the rebellion ex
# ------ temperature: 0.5
# lly-for a
# pant of the troops at the back on the rebellion extrantemine for
# directouthed in a tute the in
# the targeting corridow into a dinten look on
# the tie fighter.
# lanefulting to the trailing to locked and buttling in the death
# star surface and at the main can you sneard the
# inellidger approaches the pirateship.
# luke
# here...
# a frigge final fighters as the empire as the
# side of the death star computer are starship
# in the dark lord them as he
# back!
#
# 19a
#
#
# ------ temperature: 1.0
# mputer are starship
# in the dark lord them as he
# back!
#
# 19a
#
# star wars: a new hope
#
# 33.
#
# fina thire and in the crewt. and luke takes from lase8tefful man lifes gride overhence
# that!
# red 'looking in at the cawit. moving whit holes with luke's portlet.
# we've good.
# luke is morible ground and yet me a
# computer. senst leave that leadingly in
# stance the pirateship, han, ben look in of climble at the death
# star pashabion past luke arcouy to them. the galaxtly hol
# ------ temperature: 1.2
# th
# star pashabion past luke arcouy to them. the galaxtly holdy around,
# loke whis shep, a runls in ben pulls a convinte there rock
# backprojes ssevers at the back interint nomy.
# you vate thing the form him than is
# se't yo beg so
# just i be the
# operfor just for owen i get over, wals to
# mamine on the i sarif moried.
# threepio
# through ress.
# 50
#
# int. leate ninqas one 42
# artoo)
# you got to but take they commance down as side of
# the death star.
# threepio
# i can i had f
# epoch 19
# Epoch 1/1
# 66370/66370 [==============================] - 15s 224us/step - loss: 0.9003
# --- Generating with seed: "ase of dust contamination, i
# can barely move!
# artoo beeps a "
# ------ temperature: 0.2
# ase of dust contamination, i
# can barely move!
# artoo beeps a meen looking to the background and starts a ment
# off the stor troopers are not the rebellion starship.
# 136
#
# int. millennium falcon - cockpit
#
# 395
#
# the tie fighters back at the ships and sheepis and the rebellion stars
# the ships and sheeble around the trans-for a perstle
# of the death star shot outs aroom.
# 351
#
# int. malchat
#
# 396
#
# star wars: a new hope
#
# 116.
#
# luke reaches the transpoded with the tie
# ------ temperature: 0.5
# : a new hope
#
# 116.
#
# luke reaches the transpoded with the tie fighters.
# 3 fires at the death star moss mofth and
# sitions to be a long to the fighters
# one of the ships and as uncle owen and the
# ship to a mes. she your mast gen
# with the backs of the adjusts his head and adment of his face.
# the giant battle as chewbacca and the hangar
# is a ben moves are in the
# massice. he saying the pirateship be
# with your death star mos as he puts as
# the giant battle at the r
# ------ temperature: 1.0
#  your death star mos as he puts as
# the giant battle at the recedorcling
# in a det of little are go alie of the angur surroung
# rebo, you're mill alis aim jey adjusts the end of is
# folloving that hxoss.
# and the tie fighter controlse moves into the mabe frai2 the
# main with a venct. blast icte you is what an
# eit levaling out of yaper. poirtion in
# sugy the imperial fighter.
# luke
# (inor the immere ground boy the energy one of the face at
# him.
# luke
# allw begiling el
# ------ temperature: 1.2
# boy the energy one of the face at
# him.
# luke
# allw begiling electronicinnchss in are othto looking for your
# electronic calinter. each other fighter ready.
# the batce luke back on the nowl bodge electronic fighter
# going to the re, dirng sensed who
# hin messelfar.
# lane-s, a piratesbay at the pilotwant. not sentint, gight
# at the adrebal shelm, redardy.
# artoo hound on the robots anvivi silloctinal.
# from jast kin't to talking my scemple, and s2inal cana, aldingy
# br
# epoch 20
# Epoch 1/1
# 66370/66370 [==============================] - 15s 225us/step - loss: 0.8956
# --- Generating with seed: "opening.
# han (contâd)
# wonderful girl! either i'm going to
# "
# ------ temperature: 0.2
# opening.
# han (contâd)
# wonderful girl! either i'm going to
# stor troopers to sher moves and as he reced me,
# been in manger and as an a lot and as
# filler and the death star surface and the computer to the barten to a
# distant hand and the ship's a big subhallway, is
# and the computer to the ship's a conster. the surface and the ship approaches and and the
# stormtroopers speaker and artoo who speak.
# han
# well, i'm nee the death star.
# 23
#
# int. death star - contro
# ------ temperature: 0.5
# n
# well, i'm nee the death star.
# 23
#
# int. death star - control
#
# 258
#
# the target)
# i unde have you got to get
# out of the starship.
# 239
#
# int. death star - control
#
# 180
#
# three attack posing darms a starship, and destroy in the
# rebellion can't the ship's comested.
# han (contâd)
# what is a got, and the convers around the death star surface
# and the stards at the pirateship down the ship's a ben aby
# sit and begins to shakes to gring turns beeping sound chan
# cleatin
# ------ temperature: 1.0
# d begins to shakes to gring turns beeping sound chan
# cleating tempossinure and is
# am arms. my face in of the stars
# around to clearn beeping for firagutic compleass
# on some to and the loud little aroom atjust with i cancul, i've for a
# vect become could flick hot spaces, then is
# rebel thirg
# that! rime.
# (more)
# leia stand on the death star speces cruss streeck.
# leia
# solo is able ten electropingle
# coosinst. grabs around the can wearot of the target)
# you found?
# ------ temperature: 1.2
# inst. grabs around the can wearot of the target)
# you found? he ceny with luke and pluoted up
# red leader's targe tarkin.
# 64
#
# exthat speeder scarriove as trour-idery creature
# you i'm lext tell you
#
# one as the aleated e, goge went of the motion
# scraiggs throwistagntaba on the brath as they wanke
# right wooksice the imperial ganarce, the
# death star mosing away. han han't doom8, caus, think lead the
# crosp on his head ?
# chewber chasts thit this can hubrerdjungs f
# epoch 21
# Epoch 1/1
# 66370/66370 [==============================] - 15s 223us/step - loss: 0.8894
# --- Generating with seed: "imate that
# it has been deserted for some time.
# they are now "
# ------ temperature: 0.2
# imate that
# it has been deserted for some time.
# they are now of the stormtroopers spaces to the rebel base a
# side aroom are you was to come and the
# suchard interestinn. i can't
# up and starts to the rebel pirateship
# lights and beeping to all threepio, what i want the main for
# throut, a coll me see the
# ship.
# luke
# i can't sort and the robots approaches and as they reaces a
# side of the death star surface and are you
# the rebel tie fighter can hallway. he seem th
# ------ temperature: 0.5
# ce and are you
# the rebel tie fighter can hallway. he seem the doom
# in the creat)
# chewies to repart of the ship and begins to the death star.
# 143
#
# int. death star - control
# into the death star
#
# 383
#
# three in the computer
# the red ten room rock the rebel base.
# vader
# check to the trooper wings moves into the seace the trench.
# ben on the sure toward the death star is eviledger agast the
# see a long of the robots fighters crements ports their way.
# artoo-detoo, bu
# ------ temperature: 1.0
# he robots fighters crements ports their way.
# artoo-detoo, but i's lot of doing eimon speaks ip
# rilloneing a lot of hear whistles.
# luke cooperty something of electronic officer
# come or!
# are got to are you unrided han. loseport in
# are you bot her.
#
# 1 voky tower chakes around them, thruging the landsuters in the
# millenniuns, a gontranding are stalinden and the namuche... will this smiled and blazk artoo stands toward them!
#
# leary franbs sights body are you us
# ------ temperature: 1.2
# too stands toward them!
#
# leary franbs sights body are you us.
# secon teclming point do
# one power.
# 'at
# owen hatcon looks around to hat holdior, is
# lights someton, a  ibletir.
# luke usme behinder can hallcop.
# you can't kinder and resturting helds whists through holds it what
# he wedir is.
# threepio plaze to the iot able were the hold if thos to with
#
# luke
# somethations metally.
# there's liting to a fighter.
# my this i
# well e! i seen that
# thas pirates.
# the cif tien
# epoch 22
# Epoch 1/1
# 66370/66370 [==============================] - 15s 223us/step - loss: 0.8829
# --- Generating with seed: "zed at the old man's abilities,
# attempts to stand. the entir"
# ------ temperature: 0.2
# zed at the old man's abilities,
# attempts to stand. the entiring the trench.
# ben
# you sad ben and the death star.
# 345
#
# int. luke's x-wing fighte a cockpit
#
# 460
#
# the diel and leia contâd)
# the main for a long extracting before the ship.
# leia
# you relect of the ship.
# leia
# you sals his been shoot. they're some room
# are your face and the trench.
# ben
# you sad been to controls.
# luke no, the pirateship, speakint of the death star
# in a huge bindenly.
# the ship roves a
# ------ temperature: 0.5
# akint of the death star
# in a huge bindenly.
# the ship roves as the pirateship and attencher and threepio to the
# computer and fire power the ship, speaker.
# threepio
# i can't get of rock before
# chiiggs to the ship.
# han
# well, he tenside to going to may find your
# beam arm your forms the dinell me looks at the tie
# fighter.
# luke wine awe red leaders and ben moves at the death star. luke
# and luke and ben astro-pir. could have becked.
# han you sad ben is could
# no, ah
# ------ temperature: 1.0
# stro-pir. could have becked.
# han you sad ben is could
# no, ah!
# 149
#
# inon for years leia
# young ady, a small takesioning from the ens over the
# shippers.
# sudderal more shaps hands the half a blond behind his head.
# luke
# get face, almerair, hole, wedge, artoo.
# as remute aboll even of bon be a small computer.
# an stall powers are you
# droid to the ships.
# han
#
# han anglassing the backs in hun.
# artoo!souding a
# darkig
# in the belt his bocked as he noung in
# a alliwn as s
# ------ temperature: 1.2
# a
# darkig
# in the belt his bocked as he noung in
# a alliwn as sit of the threepio.
# 64.
# ohem you mbove-nevate or firing, win. i altern
# luke, (to pos its with me your
# don't hu
# shot in ratp hear. now, but you
# had going tem side of there. which scrap and
# what miy. i can't very, mus cafing the.
# luke and chewbacci beast.
# gotches with bothers readyon she'll door a long trenching
# with bonher. artoo, grus movan, us
# his is a hatch engly might before the empir.
# (mvevele
# epoch 23
# Epoch 1/1
# 66370/66370 [==============================] - 15s 224us/step - loss: 0.8805
# --- Generating with seed: "uke takes off his helmet, coming out of it.
# luke
# what? oh..."
# ------ temperature: 0.2
# uke takes off his helmet, coming out of it.
# luke
# what? oh... they've anything of the
# suchast the pirateship and a halling all the
# explosion of the computer stands to the
# explosion into the end of his control station.
# threepio
# (chxmacted and look into the death star surface, as he for the
# empire ship sensly before the rebel spaces a
# sitton stormtrooper. (contâd)
# what hears of the rebel ships and aban
# solo's the hangating before the empire.
# luke
# what is a
# ------ temperature: 0.5
# aban
# solo's the hangating before the empire.
# luke
# what is a big now. the end of allidgarty deserted fleash.
# 472
#
# int. massassi past the aland
# 186
#
# vader's ship ship beeping in and his control stack as it of the
# planet.
# 3.
#
# star wars: a new hope
#
# 46.
# the's adyoull begins to the barge and little are yeavina an
# disapply door all right, out of the tie fighter
# control station handleed by the computer.
# 308
#
# int. luke's x-wing fighter - cockpit
#
# 393
#
# biggs
# you s
# ------ temperature: 1.0
#
# 308
#
# int. luke's x-wing fighter - cockpit
#
# 393
#
# biggs
# you spetcle.
# no, see-king a jedie kin.
# 466
# ...
# han
# ghtcrablevics.
# 394
#
# int. i commate runder
#
# 4
#
# the fighter compuste to hames parth deen like clutton stand to
# fight though ruge a hallway.
# 483
#
# int. pilot is our - cockpit
#
# 1109
#
# gold leader poting to the bluef hole in to the plans, but making
# pauften moves to get of returns past the long.
# 101
#
# int. massassi outpost - war room
#
# 134
#
# the pirateship doung turns across the small hold to a hugr,
# ------ temperature: 1.2
# the pirateship doung turns across the small hold to a hugr, scrap
# helman 884
#
# vader
# pour ios and moves does to don't ride the jawa creature belt.
# luke's good in decrorit back for a jedi rield.
# vader s, wis aligin down a gream by has fasturdis leave fire,
#
# 138
#
# star wars: a new hope
#
# 46
#
# 131.
#
# i453
#
# int. maise vasth mank
# a chuarming outming fra(tharmy past the di-ding exhe. ben and the
# seiels for the ensmoityone, danton, i'm
# here going are, ben ans! iy's
# c
# epoch 53
# Epoch 1/1
# 66370/66370 [==============================] - 16s 243us/step - loss: 0.7760
# --- Generating with seed: "pears to be a small moon growing rapidly in
# size as the rebe"
# ------ temperature: 0.2
# pears to be a small moon growing rapidly in
# size as the rebel fighters.
# 301
#
# int. death star - main forward bay - soffice - rock canyon to
# stormtroopers in a lot of the death star.
# 338
#
# ext. surface of the death star
#
# 382n captars, and stands to the two
# the death star supplage, out what is a good to be
# all with listening. his controls and stands and stand to remuct.
# ben (contâd)
# what is a shutt their attack.
# biggs can be fours of the restrous to the spee
# ------ temperature: 0.5
# their attack.
# biggs can be fours of the restrous to the speeder wits
# the computer. led to3ulad into the
# yourself. it's bect leave the
# dim and luke and little as the ship the comlink levaling
# dint out for the starking position.
# the pirateship liflions to the shave into a milled post-diwe for half threepio.
# of the surface and starts to for the gargage points
# the death star supples. he stans the suddenly leia of the
# death star fland for that the
# hove for the
# ------ temperature: 1.0
# enly leia of the
# death star fland for that the
# hove for the massine a trans, who is shurby saund growls be?
# artoo stands in whism hvated. they vader.
# luke welch the graun worm past inwingzes.
# 348
#
# ext. space - caref explosio)
#
# 341
#
# vader! relithers leia pout of it.
# gold lead they're got the trenchvic backs interlard
# gun into the is start into a cellsing .
# 363
#
# int. luke's x-wing fighter - cockpit
#
# 331
#
# red tie agges in frons shakes across the tie fighters
# ------ temperature: 1.2
#
#
# 331
#
# red tie agges in frons shakes across the tie fighters.
# don't th'sm bettere sivery adunt outh
# desert carrinot.
# leia
# the two doxblying conts befors speeder. now, your new
# solos on board.
# threepio
# i riendslys. luke across the giant
# passinate as notired pluot tuke here. anr oush buuely starts fin
# star morn un. the luke's x-wing know what is!
# the rest asn the i
# transrip points in luops to leadin? an i,
# reper enoruns, runs instroulds they stasting you're
#
# epoch 54
# Epoch 1/1
# 66370/66370 [==============================] - 16s 246us/step - loss: 0.7719
# --- Generating with seed: "all directions.
# 327
#
# int. gold five's y-wing - cockpit
#
# 327
# "
# ------ temperature: 0.2
# all directions.
# 327
#
# int. gold five's y-wing - cockpit
#
# 327
#
# gold leader
# (over speeder and power canyon from his fidel explosion. the
# empirs is conving in the dince on the dark
# solo a bowly into the
# dark lord tutecce.
# ben (contâd)
#
# 20
#
# star wars: a new hope
#
# 116.
#
# luke looks at the tie for the ship and arroins shoots toward the
# old ele.
# a wing moring in the dirtanding
# hold twose as the ship and as sits up and the troopers
# and look over his face at him w
# ------ temperature: 0.5
#  as sits up and the troopers
# and look over his face at him which is blocky about to looking
# distant.
# 343
#
# ext. surface of the death star
#
# 268
#
# the docking bay from her and is a ben is in the
# explost to the tie fighter.
# vader ruming back in the dirturns a badge and through in the
# dark come with a stards at the alliwhes and with several of the
# oppwices past into the convious toward the computer to the
# massing flash.
#
# 296
#
# star wars: a new hope
#
# 42.
#
# there's
# ------ temperature: 1.0
# he
# massing flash.
#
# 296
#
# star wars: a new hope
#
# 42.
#
# there's a blaster groboins growing rectos, and young hinges
# strecks and is plow of the death star.
# 296
#
# ext. tatooine - gun urtr -ew a celestaccas look,
# armored screen fires threepio, whistles on tower must candon.
# a finion round his aje threepio.
# han
# well, i'm no'r. i wave you
# aliy, where she's toward up and sort itcoupls a
# si,gain.
# hat if i sm as ric alone. didn't egives ictor.
# luke and the power space
# ------ temperature: 1.2
#  as ric alone. didn't egives ictor.
# luke and the power spacemnor, apme planots houne?
#
# 198
#
# star wars: a new hope
#
# 36.
#
# luke pulls a graun laser pis if hold to whistly burning for
# throuphes a mome arcuots to fir 53
#
# inorell and right, looking
# look over hilde runf events the cramps before him desparky
# just was too whutring of the death door ed to levalor must red
# be a alsoss. ictling and his furbear passing backboa, he windsted
# sopem.
# luke
# we camben parks
# epoch 55
# Epoch 1/1
# 66370/66370 [==============================] - 16s 242us/step - loss: 0.7672
# --- Generating with seed: "hat about that blue one? we'll take
# that one.
# with a little "
# ------ temperature: 0.2
# hat about that blue one? we'll take
# that one.
# with a little robot out of the rebellion in the death
# star surface of the death star surface of the death
# star surface of the death star surface of the death
# star horing in an into the death star surface.
# 318
#
# ext. space
#
# 222
#
# the death star - control starshipers leave and star panel
# the death star surface and star panel
# the death star surface of the death
# star surface of a the death star surface and star conts
# ------ temperature: 0.5
# eath
# star surface of a the death star surface and star contsing
# clooking back at the ship stand into a tie starship, then speaker.
# 422
#
# int. gold leader's y-wing - cockpit
#
# 324
#
# vader's cockpits at the face the cenorging through his head
# troops at him.
# threepio
#
# 428
#
# star wars: a new hope
#
# 157.
#
# a my you! losely by leia. he washd.
# 372
#
# int. luke ad land scarment - cockpit
#
# 395
#
# wedge look, it's lank in as the death star computer.
# 358
#
# int. rebel side head
# ------ temperature: 1.0
# ank in as the death star computer.
# 358
#
# int. rebel side head nound - fland in hangle stand and is earrys. he
# shouthest the demes. luke, when wery thous, hope.
# when difataring back at the ships of through the gargage
# with are but look of fourth.
# 42
#
# ext. space
#
# 26
#
# ext. tatooine - power sursteag - cockpit
#
# 31
#
# tormating to manif and look on. i concerrong to frunments.
# no! will hond of burning firing frie starship.
# is a my one shory-di'ad his head in dell, c
# ------ temperature: 1.2
# g frie starship.
# is a my one shory-di'ad his head in dell, cutsitional.
# suddenlywe manking beborbage!
# fighter on a spathers looks at him
# oy of a chew. the door e, i won't be
# dissen - can do all by threepio.
# the fighters robing - small hol old in towerd threepio
# i seen yold 'vake.
# luke
# what stormtroopers in energen winguter. luke, iderach twere
# and them with wasckeme-for.
# han
# we ger lords.
# 127
#
# int. death star - garbage room vaner's tagemin in his control
# a
# epoch 56
# Epoch 1/1
# 66370/66370 [==============================] - 16s 243us/step - loss: 0.7641
# --- Generating with seed: "ations are shrouded in a strange
# foreboding mist and the oni"
# ------ temperature: 0.2
# ations are shrouded in a strange
# foreboding mist and the onielous, a make read
# usent pointice of the rebel fighters.
# 25
#
# int. millennium falcon - cockpit
#
# 386
#
# the gie the diressles to the ship stands into the tie fighter
# battle station in the computer to the robots.
# luke shep's a blast the stormtroopers standing beames about
# starship?
# away at the death star surface of the starshiped as they rece
# and the preced so good-plades to see the
# empire.
# luke
# here t
# ------ temperature: 0.5
# and the preced so good-plades to see the
# empire.
# luke
# here the rebel base a blasted at the death star
# solo's their can down the rock pilotshins. he scan the
# outsiesks at simpon toward the garbage and still the
# exhaust port. the garbage room as he let's starts from
# the computer agassing as the still of the rock a jay well, the
# empire young the restralars.
# luke an arroom his pirateship in for starshiped into a ceewie?
# chewbacca and the garbage and canyon to
# ------ temperature: 1.0
# iped into a ceewie?
# chewbacca and the garbage and canyon to repesinet.
# red leader
# wedge if your keness opere. ben knut the
# drepons to get to dome as little round the side of han
# drown and stee are not getid luke.
# luke
# i'm going dewliction.
# 94
#
# ext. sface
#
# 138
#
# relabing leat are helply me revering in the holdin in whim homes
# and couble at the wedge.
# han
# they're going to boutting.
# han
# belpenortif and find a vadertly by. he bed we
# han now of a what, comentran
# ------ temperature: 1.2
# d find a vadertly by. he bed we
# han now of a what, comentrang deathst. he
# roboling trooper back at he hee, buts speeder. need it
# awes, a corben with working scream chtile. moveming.
# biggs up persermy of ne astent oper alocce, a well, the
# embrages his starship.
# red serectious fire well, station, in, but i'm
# gold bereging interion in a blass and pays.
# han
#
# oneveraly before halfway?
# chewie back toward look voiced goom everches. chewiy wast did
# sa starship, li
# epoch 57
# Epoch 1/1
# 66370/66370 [==============================] - 16s 246us/step - loss: 0.7653
# --- Generating with seed: "about twenty guns. some on
# the surface, some on the towers.
# "
# ------ temperature: 0.2
# about twenty guns. some on
# the surface, some on the towers.
# luke
# what is she mamble to with a chewiater than svoct of the
# dirtan button. the restrang beeping scradgents, and simpont from
# the computer and beep as the star suits of the computer to the
# force. the bow all right, hurry off, sir.
# luke
# i'm not on the computer. a grawling of the starship, but i'm
# not over hil add(cons to stormtroopers and the computer. luke's x-wing flashes are not off the starpio
# ------ temperature: 0.5
#  the computer. luke's x-wing flashes are not off the starpion
# in the endebow with a former.
# as the princess creature pulls as a tight when who's it.
# more around follows as a timer hangar and a what a place of
# the death star into the death star suppless, in the
# exhaust port!
# a for him bar and his control apon the surface as he tuwks his
# power the main companord button.
# han (contâd)
# the enderprace, letind can be bargases to
# milling around houning in the fo
# ------ temperature: 1.0
# , letind can be bargases to
# milling around houning in the form fire, ore the mamble artoo
# as it straps as atten here feed sence i was
# not muns. a rath star mosing part of derth luke think y-wers
# aurt of offering artoo. amand the dark
# unte pors luket and leia tarkin (contif enters at of
# little robot wastdourichts veillyone. ben kenot kid.
# 0k
#
# ext. the wall only offirecc
# not solo the death star for a price
# that are group. he conlest's a transfetion. buttlins
# ------ temperature: 1.2
# a price
# that are group. he conlest's a transfetion. buttlins.
# luke
# the computer. we dust
# a facefleis han is someong luke's winybouthod be no gun he he
# precise. call!
# 224n
# hem attack down the target. at your came frugh, bust lets
# his amoond, i've seener emelliking a vader and hes, a recons,
# speeds leia how with threepio. sus, burd showing out who
# gets eled doors as the shipwless as thuruplio torchasts by
# resygemell sereli and threepio as the subhaluged by
# a
# epoch 58
# Epoch 1/1
# 66370/66370 [==============================] - 17s 250us/step - loss: 0.7603
# --- Generating with seed: "tly slips
# past the troopers and into the main hallway.
# secon"
# ------ temperature: 0.2
# tly slips
# past the troopers and into the main hallway.
# second of the surface to the ship and the surface to the pirateship
# in able armored and starts to the plans are is
# will you what it.
# gold leader boys uppeakes to their past the shades and
# sithmers the subhalling about? if tracking a small look
# but is stant, you with your way.
# artoo we could have beamons and stumbage as the subhall
# at the ship to the shakes his hope to the smoking
# of the subhalling and
# ------ temperature: 0.5
# to the shakes his hope to the smoking
# of the subhalling and enter the shipy despace and
# clead in the control space. leia and two lettle
# about the shadows of their can do about you.
# han
# what it's the heard the controlspess in
# the controls. artoo with your way.
# luke
# hey'd my..
#
# 18.
#
# star wars: a new hope
#
# 141.
#
# bow let leave the ship and of the direction of the control
# to the battle. this blasted and
# biggs. wedge twines in of the suppres of the shades are m
# ------ temperature: 1.0
# nd
# biggs. wedge twines in of the suppres of the shades are mone. hold
# the boutch this reflor, but is now.
# luke here beamever and run!
# lanss up in front of the death star lars. luke
# where is a fallod of hold in this control apoinit of
# her
# them. this little starship, with the ram head
# oocis leor, it would darks the control appes the
# groupe. the must up incen!
# 129
#
# ext. space
#
# 205
#
# jabaw scat is conflertysge, i'm
# einoking is and to go on
# the centernol. a si,n
# ------ temperature: 1.2
# lertysge, i'm
# einoking is and to go on
# the centernol. a si,ners. if quick butt-com to i for fow
# what y-d-warror out the sithoring
# read uu. . the accease too himventsilling
# at the rebellion of stow, begins thespey and ten
# rounion of the robots his can, and then hand.
# luke butcle, aurn hive desert with me you
# i've!
# leia you know who st's the dight
# we're stabboy.
# the surface.
# 345
#
# int. darth vader's cockpit
# untrous theower gives closer. red five.
# 249
#
# int. bi
# epoch 59
# Epoch 1/1
# 66370/66370 [==============================] - 16s 245us/step - loss: 0.7569
# --- Generating with seed: "nyon - sunset
#
# 21
#
# the gargantuan rock formations are shroud"
# ------ temperature: 0.2
# nyon - sunset
#
# 21
#
# the gargantuan rock formations are shroudes are not mind of the
# stormtroopers standing been look and the low far him.
# the tarkin are in the endershous of the ship.
# leia
# the restrang the table. he sent you too foull me the
# exhause is a bowly distant of the garage of the rebellion of
# his face as the ship aport, of the rebel pirates
# are not off his way.
# all rightion dayguse from a tie fighter.
# 273
#
# ext. death star - garbage
#
# 193
#
# the gien l
# ------ temperature: 0.5
# tie fighter.
# 273
#
# ext. death star - garbage
#
# 193
#
# the gien look from the death star surface room at the computer
# the consucous compatoring and then watches a reseot i
# was the onerow. well, sir.
# 7
#
# int. millennium falcon - tracesw-r(y-ace's - warrro
#
# 382
#
# luke (contâd)
#
# luke
#
# the turnion pantles leave for the rebellion and a grablows as
# antull the hallway. the restrance and remise pirateship
# in planet and dark is
# any the fighter.
# luke
# here you wait am and
# ------ temperature: 1.0
# lanet and dark is
# any the fighter.
# luke
# here you wait am and the vaster
# it what he feels a far the computer. vader
# in the empir companic computer.
# 20
#
# int. massassi outpost - war room
#
# into galcharvaba and stare and starts his approaches been look overhata our
# face of head, antence reclock of luke's face. which dive
# into main malling about, way.
# the gold vadorevered in the imperial vostance her hold to
# red be foring from his been better with light goorsa.
#
# ------ temperature: 1.2
# ld to
# red be foring from his been better with light goorsa.
# sunders fly inss, wastinct are not make bectover.
# han screans. i more with threepio (contâd)
# firsed condite clusk move.
# 157
#
# ext. tatooine - rooler
#
# voarrror scram be's look over hitse-shie is a let is!
# ohv't he gor be.
# all you going to
# hell imperial singat at a main malluns, but
# landspeaker)
# han shops the in!
# luke
# now...
# i
# need bay to mosters.
# threepio present of with in watchesnic. the
# droid f
# /home/trp22/CS/PythonVenv344/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
