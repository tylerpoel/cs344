# %% [markdown]
# ## Preparing Data

# %%
import keras
import numpy as np

# path = keras.utils.get_file(
#    'nietzsche.txt',
#    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
# text = open(path).read().lower()
#text = open("/home/trp22/CS/344/cs344/Project/OriginalTrilogy_script.txt").read().lower()
text = open("/Users/tylerpoel/cs/344/cs344/Project/OriginalTrilogy_script.txt").read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 491488

# %%
#print(text)

# %%
# Length of extracted character sequences
maxlen = 5

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 164797
# Unique characters: 60
# Vectorization...

# %% [markdown]
# ## Building the network

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the model

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

#for epoch in range(1, 61):
    #print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
model.fit(x, y,
          batch_size=128,
          epochs=60)

    #if epoch % 5 == 0:
        # Select a text seed at random
start_index = random.randint(0, len(text) - maxlen - 1)
generated_text = text[start_index: start_index + maxlen]
print('--- Generating with seed: "' + generated_text + '"')

for temperature in [0.2, 0.5]:
    print('------ temperature:', temperature)
    sys.stdout.write(generated_text)

    # We generate 400 characters
    for i in range(600):
        sampled = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(generated_text):
            sampled[0, t, char_indices[char]] = 1.

        preds = model.predict(sampled, verbose=0)[0]
        next_index = sample(preds, temperature)
        next_char = chars[next_index]

        generated_text += next_char
        generated_text = generated_text[1:]

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# epoch 1
# Epoch 1/1
# 164797/164797 [==============================] - 6s 36us/step - loss: 1.9615
# epoch 2
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.5724
# epoch 3
# Epoch 1/1
# 164797/164797 [==============================] - 5s 33us/step - loss: 1.4676
# epoch 4
# Epoch 1/1
# 164797/164797 [==============================] - 5s 33us/step - loss: 1.4107
# epoch 5
# Epoch 1/1
# 164797/164797 [==============================] - 5s 33us/step - loss: 1.3714
# --- Generating with seed: "er in"
# ------ temperature: 0.2
# er into the star - cockpit 310 â int. come on, restroy as the might and the death star - cockpit 36
#
# and the for the
# star - cockpit 36
#
# chewie the star - cockpit 36
#
# and the mone to the star surface of the star - cockpit 36
#
# and the star - cockpit 36
#
# and the star surface of the star surred to the star surface of the star - cockpit 360 â ext. space - cockpit 360 â int. main have to the speaks and han and han shake have to the star - cockpit 360 â int. main for a galacting to his head in a fall the for the star surface of the star surface of the star - cockpit 36
# the controllers of the
# the star -
# ------ temperature: 0.5
# ar - cockpit of the work a moment to the for the star destroyer station the
# star destroy and luke and the rebel fighters out the rebel fighters.
#
# threepio
# i had from the end of the
# stormtrooper
# out of the star and and han sheping to chewie help!
#
# threepio
# i have mone to
# the falcon of the speaks on the midile.
#
# vader head in a streaks to adbows up and the trench beart beep to his fighters of ender the dark from he first the comes to his head and the speed to metal on the are speeder of the death star crushing have to the falcon - gunport as
# the through the
# next to the distracem for sits of the
# epoch 6
# Epoch 1/1
# 164797/164797 [==============================] - 6s 34us/step - loss: 1.3431
# epoch 7
# Epoch 1/1
# 164797/164797 [==============================] - 6s 34us/step - loss: 1.3221
# epoch 8
# Epoch 1/1
# 164797/164797 [==============================] - 5s 33us/step - loss: 1.3012
# epoch 9
# Epoch 1/1
# 164797/164797 [==============================] - 6s 34us/step - loss: 1.2863
# epoch 10
# Epoch 1/1
# 164797/164797 [==============================] - 6s 34us/step - loss: 1.2718
# --- Generating with seed: "old y"
# ------ temperature: 0.2
# old you ship.
#
# luke and the scout's begins to his can be the ship.
#
# leia
# (over the ship.
#
# lando
# alderaan of the end of the walker and the pit of the ship and stands and stands and stand starts to the walker.
#
# leia
# (into the pilot to the starts to the ship stand stand stands and stand the ship and stand and stand and stand a scout's face of the ship.
#
# lando
# all right in the ship toward the star - cockpit 429 â ext. space and stand and stand and stand and stand stand and stands and the dark command the star surface of the speeder and stand a scout's going to the speeder and stands to the star - main
# ------ temperature: 0.5
# main down to the protecting and stands toward then star - cockpit 314 â ext. space - millennium falcon - cockpit 2uakid reating down the danger.  he yellow the and stands and the picks.
#
# luke and desperation.
#
# lando
# starts to his the command the large the planet.
#
# leia
# shart continue toward the stand and stand the walker, and goodied walker, leia star surface of the that into the tiny desert fighters.
#
# lando small find the
# the walker weapons into the surface of the star surface of the walker.
#
# leia
# the ship and near the amazed and some now the star - war is panic can fighters.
#
# artoo who is a walk
# epoch 11
# Epoch 1/1
# 164797/164797 [==============================] - 6s 34us/step - loss: 1.2601
# epoch 12
# Epoch 1/1
# 164797/164797 [==============================] - 6s 35us/step - loss: 1.2490
# epoch 13
# Epoch 1/1
# 164797/164797 [==============================] - 6s 35us/step - loss: 1.2401
# epoch 14
# Epoch 1/1
# 164797/164797 [==============================] - 6s 35us/step - loss: 1.2325
# epoch 15
# Epoch 1/1
# 164797/164797 [==============================] - 6s 34us/step - loss: 1.2241
# --- Generating with seed: "c con"
# ------ temperature: 0.2
# c control panel and the stormtroopers races to the stormtroopers and the computer the star destroy the scout star destroy the stormtroopers and the stormtroopers a barge to the stormtroopers and the tiny rock the computer standing the trench of the computer the group of the rebel fighter - battlefield the stormtroopers and the star destroy the troopers and the sand.
#
# threepio but he hallway 1rarted by the death the protecting to the side the computer the star destroy the computer the death star destroy the death star destroy to the death star destroy the death star destroy the star destroy the star
# ------ temperature: 0.5
#  star - travelings him to the you will be don't computer a surprise of the princess is belian into the breaks to the deathly - star destroy sits of the tractor but it is pulls lights ben sees
# to the door of the officer and in a small
# into the bridge.  the stormtroopers round they concert the two from the scout star surprain the sarlaccy and leia turned proceed a down the off the plans in the back, the careful that, threepio came of the princess sir.
#
# container of the millennium falcon - cockpit 313 â ext. space
#
# the rebel base - cockpit 3pinet star sure the surface of the tiny bursts are take thi
# epoch 16
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.2175
# epoch 17
# Epoch 1/1
# 164797/164797 [==============================] - 6s 36us/step - loss: 1.2109
# epoch 18
# Epoch 1/1
# 164797/164797 [==============================] - 6s 36us/step - loss: 1.2047
# epoch 19
# Epoch 1/1
# 164797/164797 [==============================] - 6s 35us/step - loss: 1.1984
# epoch 20
# Epoch 1/1
# 164797/164797 [==============================] - 6s 35us/step - loss: 1.1955
# --- Generating with seed: "other"
# ------ temperature: 0.2
# other to the commander and star destroyer standing to find the star destroyer - cockpit
#
# luke
# i want to standing to find the throne room and star - main death star destroyer - cockpit
#
# luke
# are prodds, he too lets out of the death star destroyer - cockpit
#
# luke
# i will soon and star destroyer - cockpit
#
# luke
# i might in the door - day looks at the death star destroyer - cockpit
#
# luke star destroyer - cockpit
#
# luke star destroyer - cockpit
#
# luke
# i will soon and leia and star destroyers and star destroyer - cockpit
#
# luke
# (into the throne room and the group of the tiny transmission of the hatch of the t
# ------ temperature: 0.5
# the trackly.  looks at the hallway control of the hattle in the death star destroyer stands of the ground to funing the hand rock me.
#
# luke is that the dark lord in their panic on the force flapting the tiny lando
# i will the looks at the end of the emperor me, and luke here and moves to the cockpit
#
# luke trying to our stand fire of the group and puss his and artoo-detoo.  it moves on a day and death star destroyer - cockpit
#
# luke looks and
# the rebel of the darkners have the princess's comlink)
# i'm from the skiff and screams lando
# well, the ground the main dark stormtrooper and the was freezong wit
# epoch 21
# Epoch 1/1
# 164797/164797 [==============================] - 5s 31us/step - loss: 1.1902
# epoch 22
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1870
# epoch 23
# Epoch 1/1
# 164797/164797 [==============================] - 6s 36us/step - loss: 1.1807
# epoch 24
# Epoch 1/1
# 164797/164797 [==============================] - 6s 35us/step - loss: 1.1790
# epoch 25
# Epoch 1/1
# 164797/164797 [==============================] - 6s 36us/step - loss: 1.1735
# --- Generating with seed: ")
# you"
# ------ temperature: 0.2
# )
# you weapons as the control room 315 â¨the troopers star destroyer - cockpit 221 â¨luke's ship and star destroyer - cockpit 311 â¨a tie fighters as the trench of the trees.  the through the death star destroyer - cockpit 221 â¨luke's ship and star destroyer - cockpit 221 â¨the tiny reactor ship and the star destroyer - cockpit 311 â¨luke's x-wing for the death star destroyer - cockpit 221 â¨artoo stand for the trees.  the ship for the ground the ship and the ship and the death star destroyer - cockpit 31ot star destroyer - cockpit 31ot commander man and the ship for the ship and the force i
# ------ temperature: 0.5
# rce is a battle star destroyer - cockpit 411 â¨vader
# (over into comlink)
# i'm surface.  the boy. â¨
# 443 â¨o32â¨base.
#
# the wools in a standing him. the dark side of the death star destroyer.
#
# leia
# that the
# feet and
# mind
# slide as the back.  the emperor side of the ship
# gone. it is a mishibling a small moves the
# for me! all the attack pieces and of the ship hatch the traveling the restoms. the plank boom.  the window as the end of the surface.  the achove to me.
#
# 1ni appears at his way as the crawiel is it, star desting his should be see your ship about the reactor slide a stop that is no sign
# epoch 26
# Epoch 1/1
# 164797/164797 [==============================] - 5s 31us/step - loss: 1.1709
# epoch 27
# Epoch 1/1
# 164797/164797 [==============================] - 5s 31us/step - loss: 1.1679
# epoch 28
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1670
# epoch 29
# Epoch 1/1
# 164797/164797 [==============================] - 6s 37us/step - loss: 1.1616
# epoch 30
# Epoch 1/1
# 164797/164797 [==============================] - 6s 38us/step - loss: 1.1600
# --- Generating with seed: " come"
# ------ temperature: 0.2
#  come on, she
# rebel fighter - cockpit â¨we have the death star destroyer - cockpit â¨we heard and the rebel fleet and the station.  the emperor's find the station.  the growls and star destroyer - cockpit â¨we have no solo and fire of the death star destroyer - cockpit â¨we heard and star destroyer - cockpit â¨we heads and strike a seconds.  the door of the activates a short hands around the death star destroyer - cockpit â¨we heads and chewie growls and streech the scout see young with a straight of the death star destroyer - cockpit â¨we heard the death star destroyer - cockpit â¨we hear
# ------ temperature: 0.5
#  hear
# to the contrasted
# find followed the forest of the ship shut in the
# robot star - cockpit 223 â int. millennium falcon - cockpit â¨we head sound the single about in the tiny from the pirateship
# rebel followed by the death star destroyer - cockpit 2syool rememberest in the sandpeople artoo-detoo ship.  luke and mone.
#
# luke
# leia
# (to and street the continues.
#
# leia
# i have
# stops as the comes over to the still
# one of the troops approaches the rebel flee creature me.
#
# leia
# i hope ship has tall side of the imperial star down the station.  the ships leia, when
# gold leader's cockpit 271 â¨luke
# epoch 31
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1561
# epoch 32
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1549
# epoch 33
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1519
# epoch 34
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1496
# epoch 35
# Epoch 1/1
# 164797/164797 [==============================] - 6s 35us/step - loss: 1.1483
# --- Generating with seed: "prima"
# ------ temperature: 0.2
# primation. the death star - main hallway. â¨
# 267 â¨we have to the ship to the stormtroopers and the ship and the ship and the ship and the ship and the
# stormtroopers and the ship to the ship and the
# the ship and star - cockpit 315 â int. millennium falcon - cockpit 315 â¨the death star - main hallway. â¨
# 231 â¨the emperor
# the scout.  as he sees the ship and star - cockpit 313 â int. massassi outpost - wasteland - cockpit 315 â int. millennium falcon - cockpit 315 â int. millennium falcon - cockpit 315 â int. massassi outpost - wasteland a command chewie looks at the surface of the ship
# arto
# ------ temperature: 0.5
#
# artoo beeps a large
# the fleet.
#
# luke
# luke
# are senators.  the
# imperial star - cockpit
#
# luke of the moned of the bridge and star - main docking out of the room and the room - ridor
#
# the emperor
# the emperor
# me.  luke's x-wing - cockpit 413erury down the treak.
#
# ben
# the main returns and the protoming you well and something through the protective creatures to the stormtroopers rushes to the room
#
# the scout. threepio
# kent the fire fighters up the commander similar turns to his to
#
# luke
# the ship.
#
# luke
# you little star destroyers to
# the millennium falcon - cockpit 313 â¨artoo walls on the too beeps a
# epoch 36
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1452
# epoch 37
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1447
# epoch 38
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1427
# epoch 39
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1405
# epoch 40
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1385
# --- Generating with seed: "r i'm"
# ------ temperature: 0.2
# r i'm and stumbles and star - cockpit 321 â¨the great artoo beeps and star - cockpit 360 â¨the great artoo beeps and the star - main hangs on the star - cockpit
#
# luke
# i have to the computer and chewie lose the star - cockpit 31ou xewoks at the star - cockpit 36 â¨the cockpit 321 â¨the through the force in the stormtroopers
# are a conversarm on the millennium falcon - cockpit 321 â¨a death star - cockpit 360 â¨the force in the ships are distance a straining to the starts to the stormtroopers are from the force in the still and the back to the ship begin to the ship shudders are from the all th
# ------ temperature: 0.5
# ll the
# falcon, chewie barks luke in the rebel troopers race to the computer street as the bursing on his arm in from the death star - cockpit 33.   ext forearing from the
# rebel fleeing rebel troops run out of lights going to the studges his forward the computer a crater.
#
# int. main looks at the window and star - gunpieg riphed then it.
#
# leia
# whatead out and the force in the death star destroyer - cockpit 360 â¨the cramble.  my to the pirateship.  it's got the sees the laser bolts.
#
# 12   ext ducks out the giant starts forward then small die ofing like a converted by the
# other was
# in the death s
# epoch 41
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1374
# epoch 42
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1343
# epoch 43
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1338
# epoch 44
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1327
# epoch 45
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1312
# --- Generating with seed: "rrive"
# ------ temperature: 0.2
# rrives and his head in the trench as the
# the starts to the tiny along the trench of the for the trenched the trench of the
# concerned in the ship and his head in the barks looks at the trench of the base and star destroyer - cockpit window and the pirates a long to the
# tie fighter - cockpit window and the station.
#
# luke and the monster and he stand begins to the for the forehelf looks at the starts to the pirates a long the
# control of the back.  he starts from the moned and his hands of the death starts out a long to the forest.  as lando and the monitoracting to the tiny
# and and leia is starts
# ------ temperature: 0.5
# tarts to the
# taking him in forms over and chewie barks the tie fighters.
#
# lukeâ¨he window and he station.  the scan well, several of the streaks to his ball of the tiny all the bound the through the death starts of the tries of the barking the station one of the ships near the speaks to see hangar slides can be the bunker - cockpit window robots been it.
#
# luke in the tiny thinking him and the tie fighters for the troops luke looking to the turns in the trenched the young jedi by the bunker and by. â¨
# 241 es to the tries in the bring the group of the board and the back.
#
# vaderâ¨the two of the th
# epoch 46
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1297
# epoch 47
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1286
# epoch 48
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1266
# epoch 49
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1256
# epoch 50
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1281
# --- Generating with seed: "xt. h"
# ------ temperature: 0.2
# xt. hoth - ice plain - detroy as the ship and the death star destroy as the death star destroy an in the ship and leia, and the control sticks him in from the star destroy as the group in the two of the for a moment of the death star destroy as the ship is out of the ship and the death star destroy as the ship and she is a troops can be the ship and the side of the death star destroy as the ship canyon watches the ship and star destroyer - cockpit 315 â int. millennium falcon - cockpit 315 â¨han sure him and the ship and leia and star destroy an imperial star destroy as the through the ship and le
# ------ temperature: 0.5
# nd leia and star destroy as the control panel.  a vast care on the guards turns into comlink)
# well, the emperor
# yes, leia
# and leia star destroy and and the far side.  oned and chewbacca raider looks out of the star destroyers. he paints out of the great!
#
#
# mzose of the planked to the back and ship and i vader
# the death star destroy an imperial stormtroopers are sending little on the fire as some and at the ship, then he can be a huge lando suppliee!
#
# han
# a little streaks into the back and the for the death star desperation. the red leader
# you strugglire him in sight.  bun a fie sight help the las
# epoch 51
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1236
# epoch 52
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1229
# epoch 53
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1217
# epoch 54
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1222
# epoch 55
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1210
# --- Generating with seed: " walk"
# ------ temperature: 0.2
#  walker systems of the ship buss!
#
# 333 int. millennium falcon - cockpit 413 â ext. space - and the ships are security - dingy of the death star destroyer - cockpit 42 â¨luke and star destroyer - bridge and chewie
# struggles to the stormtroopers and star destroyer - bridge
#
# vader
# the for the stormtroopers and the stops away in the ship buster control of the through the ship begins to see you will not gonna a death star destroyer - bridge
#
# vader standing his control of the star destroyer - bridge
#
# luke looks at the ship has surround the stormtroopers and star destroyer - cockpit 413 â ext. space - a
# ------ temperature: 0.5
# e - a second screen guards him before that i crabd control of debalce - main hang ening more the stops into a trees. the
# concentrance of the ship. â¨
# 21.âx. firing and on and han reach on his has a flash me, sir.
#
# leia reaches the prodded and and star destroyer - cockpit
#
# luke and chewie barge tell meet the door shield corridor randouna
# and some prasts the other standing his restoo, then it, i supplies from the two huge window don't we you to the
# transport - dusk
#
# the millennium falcon - desertes his hangar doing the stops away and chent him beck and mane the explode no solo spear
# the death st
# epoch 56
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1199
# epoch 57
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1183
# epoch 58
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1177
# epoch 59
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1163
# epoch 60
# Epoch 1/1
# 164797/164797 [==============================] - 5s 32us/step - loss: 1.1158
# --- Generating with seed: "hoppe"
# ------ temperature: 0.2
# hoppersurfunding sounds a small die of the ship and star destroyers and star destroyers are a strange. her heads
# intercom voice on the death star destroyers station.  the ship star destroyers and then the death star destroyer - cockpit 313 â¨vader stands out of the ship and then it.
#
# leia
# i don't worried leader is a tremest in the death star destroyers and star destroyers and star destroyers and star destroyers and star destroyer - cockpit 313 â¨vader is a treme entrance and star destroyers and then it.  the ship and star destroyers and then it.
#
# leia
# i don't be all right forget of the
# commande
# ------ temperature: 0.5
# mander side the millennium falcon - cockpit 317 â int. red ten's voice
# (over his control of fires at the start and leia and star destroyers the sighter into the for the season.  fixth, side them clusted, but posself.
#
# han
# i have a tremendous just your fast. millennium falcon - cockpit 315 int. cloud city.  luke
# her, leia and sith laser cannon area.
#
# leia
# chewie, and in the dark side. we maneaver his secures to the distance to space - oner and the suraizbating device.  it restraining around then the death stars up at the activity fire star destroyers and the side the distance.
#
# 12   int death star
# /home/trp22/CS/PythonVenv344/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
