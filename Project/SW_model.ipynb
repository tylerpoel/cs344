# %% [markdown]
# ## Preparing Data

# %%
import keras
import numpy as np

#path = keras.utils.get_file(
#    'nietzsche.txt',
#    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
#text = open(path).read().lower()
text = open("/home/trp22/Star_Wars_A_New_Hope.txt").read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 199170

# %%
#print(text)

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 66370
# Unique characters: 55
# Vectorization...

# %% [markdown]
# ## Building the network

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the model

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 20):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 66370/66370 [==============================] - 16s 238us/step - loss: 2.2564
# --- Generating with seed: "w hope
#
# 141.
#
# a huge remote-control laser cannon fires at th"
# ------ temperature: 0.2
# w hope
#
# 141.
#
# a huge remote-control laser cannon fires at the specker the red leter the specker the extell the death star the manter and the sure the stald a den the luke and the red the red the stat and the red leader the red the red the red leader the han the surface the red the star the rebel the speecer the star in the mand the red the sure a luke a dewer and the seed the surface and the death star the speece for the red leader and the sure the red the
# ------ temperature: 0.5
#  star the speece for the red leader and the sure the red the han
#
# luke
# (courded and the mally a den the rem the death star
#
# 332
#
# ar and a vockpit
#
# 130
#
# vader frimp he looks in the red lake crmecer the ext. the rebel stan the linters and the moll folly whe red the all the shack contâd)
# in whe the seden the luke from the menent at he the red the death star
#
# 219
#
# ext. tareino han hat off the revel the extoron.
# leia
# (over the stat in the losk woll off a mos
# ------ temperature: 1.0
# the extoron.
# leia
# (over the stat in the losk woll off a mos is it serene, off hef hos faches
# luke
# the denlles to on't ho dewichar.
# can.
# sede gol stit
# luke.
# an
# vock in't ! youurr off stas.. ertide
# hy, het arnon't ritwing. fol ald fie on the  as and wecters. fic
# like hen
# hall letarg betscourim ho divar bald troube, lukes
# hald the exe filllliad he deadero hes iudes to the she vadely. it
# whim on wyshes shatd ovets his banting tht ben
# plighle res of heul comtro
# ------ temperature: 1.2
# s shatd ovets his banting tht ben
# plighle res of heul comtrot. and collunih.
# pant -wing.
# the bets bly and packsyerns. a piskio!t,
# ne. no
# ae's twe comlyofoliun up of cockus leden
# wares. it
# orul sthe land rapi-trock his and lists7cet hqulds.
# sweplle lolk leol)?han.
# the barico tiee off and
# the faced giveer my vidsurd, ben
# he g'ed plice havd ples pust i
# peemycani light
# dy bit enord. hel ors cheppocep laster packemy
# bis be a porete
# scwat
# lhive do
# vowacren a pis
# epoch 2
# Epoch 1/1
# 66370/66370 [==============================] - 15s 226us/step - loss: 1.7106
# --- Generating with seed: "scrambles backward until he is forced
# to the edge of a deep "
# ------ temperature: 0.2
# scrambles backward until he is forced
# to the edge of a deep on the speaker.
# luke
# in a starking to artoo a starks and a trench.
# luke
# sheen and a trenching and artoo and the barks and a trenches and a the starks and artoo and are you head and a the down the shart on the rebel shees and a starks and a trenching and the ship and leader and leader starks and a the speaker on the barks and artoo in the starks and as the speakers and a starks and the rebel seep t
# ------ temperature: 0.5
# starks and as the speakers and a starks and the rebel seep to the luke are your at the rebel to the
# moves armus on the screat on a the ports and he shatting, waight he shoust his shourde.
# luke artoo the throng to in
# the red leader
# luke in the back and red leader for ship the remactheranleh.
# artoo sheeder.
# luke
# and wenge she pirates to the move on the rebel all shead and all moves the linge and begins to the barked and the haves the bay are laser on the sha
# ------ temperature: 1.0
# ins to the barked and the haves the bay are laser on the shaplo7 of
# youn,
# as res a net one to there hal se
# (seered toncter..
# red tarkin gilole
# crrostenks.
# curbe losing - fine.
# refolts the laving long is on the (contâd)
# in be. explode tendent., is bectracting. uld the
# ricten we hart long foor aplosios overtecpang looks's and artoomere waigh. deat he bie dallos powe tter frropen.
# luke, artuny-thoy.
# three control. in op ship.
# berne on of hope throke around
# ------ temperature: 1.2
# .
# three control. in op ship.
# berne on of hope throke around aoiatts.
# awrund and the youniw gnoo you har for ho
# book.
# i goins to gegles.
# walksy bucken's
# dodratys his troopceicwaes.
# three iovuyt..! edee in
# asteation
# ourshapls and bewway!
# .
# evelors comess, of hos hove
# soopeexy uplying)
# i've jan andle youn smoorpacif. in to!eees.bagem, a shoustinl a flincked bawaloniag ess that
# e8clotk on the dpase of reathals.hrils on an dord he lashy 71
# the plefel, you, we c
# epoch 3
# Epoch 1/1
# 66370/66370 [==============================] - 15s 227us/step - loss: 1.5353
# --- Generating with seed: "f the rocks scurry three jawas, no taller than
# artoo. they h"
# ------ temperature: 0.2
# f the rocks scurry three jawas, no taller than
# artoo. they heads the ship and and the rebel farm and a lorger the rebel farm the death star and from the ship and greation and the rebel fay
# the ship and the ship and a long the ship and the rebel falling the death star and the death star and the rebel farine a long the rebel farm and the ship.
# luke
# what he don't the rebel falling the death star ships and see shee and a manger.
# the rebel falling the ship and
# ------ temperature: 0.5
# s and see shee and a manger.
# the rebel falling the ship and matter the don't sieh on the ship.
# luke
# (screen the past many move from the ships and resivers the well and the rebel bet in the staring the ship at the rowers. is the death star see emy flear makes a didenge way are noment.
#
# luke
# (hi'l ships in fronted.
# luke
# res the
# fires the for the shough interply to see leaning the speaker)
# the don't her up and shoudy and like and a the headser the
# ships a
# sud
# ------ temperature: 1.0
# her up and shoudy and like and a the headser the
# ships a
# suddever any any vouy of the time
# mobi fargeg
# piralessinep un
# went on the farge minerfuring the portital way irsuboate bes ighin.
# 4
# 1
#
#
# luke
# is 3, to check on the for have!
#
# arto never going and lamge leads
# a trwalbery
# burty sun moter
# don't
# what and
# rebel way.
# luke
# i have seg! sene thr gnat in't gree'. kid.
# luke
# there the profe's bonte
# ben
# not a long dinnat i
# bed artoo be the kild computers old and e
# ------ temperature: 1.2
# ot a long dinnat i
# bed artoo be the kild computers old and evenls you he'm.
# parcite aunder re convers fromntely bespostes
# (nornedy ild, slinet the,
#
# 8gen
# rung she fonetew. it. be tro be overtick semenale
# ssmoke grips.
#
# 2y prin (conger - holder
#
# 157
#
# f luke (continarer
# dection. 4h9ning you.
# it's a long give and dorric
# the coneselted men remillirghhe loon his sharguge grants untarcey
# siard artf. yiveue! beep afresst you makner
# gearicny, ghen fremp a preflene
# epoch 4
# Epoch 1/1
# 66370/66370 [==============================] - 15s 228us/step - loss: 1.4266
# --- Generating with seed: "to luke's x-wing. it's an emotional-filled moment as artoo
# b"
# ------ temperature: 0.2
# to luke's x-wing. it's an emotional-filled moment as artoo
# before the stars are your ships a hall are you
# coulding and the ships are your computer of the target of the surface the surface and stars are bours.
# luke
# that's a bears of the surface and stars are res. a seally are you wait a lot to the beaking and the ships and stars are your control to the surface to the pirateship.
# threepio
# i'm going to be a bear stars are realing to the barks a sound the surf
# ------ temperature: 0.5
# to be a bear stars are realing to the barks a sound the surface and stars are your heads.
# luke and can fallway a fir seat a control sticks out off and the pirateship!
# a tarkin as he fallway at the stars in the death stars in a kid.
# luke
# i'm going to for the troopers start and
# struggl wayling place in the standing in the past doway are ganes and your death stars are your falls to the ball me. han wills
# head and
# stack to the bargent to the main from his comp
# ------ temperature: 1.0
# ills
# head and
# stack to the bargent to the main from his compan eyon if fallaggass to the space
# robe weelly agrays laserfire and imperial gived followher-storjebels.sed here alts are langan.
#
# star wars: a new hope
#
# eatl decch and for the dew han (over poper8. of his control and seuech his sedfure infushs with cheir.
# lorg blas
# onlying are (ive wenling ald arrach! mo fand homager shouse is gold the outplring aldort bout i hand the lassuft
# on
# the ?rexess over
# ------ temperature: 1.2
# outplring aldort bout i hand the lassuft
# on
# the ?rexess overiver. 8abhn
# tourmac. han armerpige tobbu3 kid pawagunterpricats to htloc as
# the space, well i'll all altio syes.
# twatuout
# soru?
# red luve, woikfehe. he fooggine! adray a day0.
#
# 80
#
# star wars: a new coving fry
# tercof ald ralt decth aport
# - ways
# omf ustible.
# over him.., in to senving is away. is ale prensi'gs ot.
# thay'r mates-wie3 ale to me7bears andiel)
# in te're steys,
# agcimine'g to teldioors.
# 453
#
# epoch 5
# Epoch 1/1
# 66370/66370 [==============================] - 15s 229us/step - loss: 1.3541
# --- Generating with seed: " off down
# the trail.
# 22
#
# ext. tatooine - rock canyon - sandc"
# ------ temperature: 0.2
#  off down
# the trail.
# 22
#
# ext. tatooine - rock canyon - sandcooing - cockpit
#
# 366
#
# the ship shees to the pirateship in the hand and
# and strance to the computer to the ships and starts of the staring to the ships of the staring to the pirateship ships and starts of the ships of the ships and stars in the ships and stands and as the main for the ships and streat is a ginate the pirateship.
# luke
# what's in to the trench. it's to got of the ships and starts of t
# ------ temperature: 0.5
# s in to the trench. it's to got of the ships and starts of the ender in to be all the main fortemented in the laser is
# herly that her.
# treeching to will you wain for the pirateship.
# 46
#
# int. millennium falcon - cockpit
#
# 436
#
# wexhe and the control wourrfles to for the trench. red the surface of the firath to sir.
# luke reaches a mister is going to the main to be a starts stormtroopers her and me have courride to finnth throughter than window... the trecches
# ------ temperature: 1.0
# e courride to finnth throughter than window... the trecches sunce, something your
# lever.
# luke vacoustion in terrain9 to the rui, your foinif is a garanemed fullsit. me of the jump turns down tis gif.
# 108
#
# int. red leader's knowale rmaces whlatemanacro onlacllacrow hom the
# ald little manken cra9ss princeess 8
# in toosture his go. her who y!
# .
# tarkin to your fighters in of the station on the nots the. wooks emobing. we'll formenty up!
# 41
#
# int. mastance oh th
# ------ temperature: 1.2
# e. wooks emobing. we'll formenty up!
# 41
#
# int. mastance oh the leater traccover
# what cany- tarrfive for a teeches of extimbons. aren.
#
# 456
#
# red
# gore!
# there there'a to dor, of then glo3
# s4re?
# 440
#
# int. millennium falcous whorueld an worked motes - decaloni in
# there his gen with i were. but lasearn sarr3cluskes for a
# tiloming a fitle tomfarudutchercy, sor.
# luke assiess in passrouiuly buse on.
# luke
# is cover
# deaten no fright swile.
# stwally backed)
# docking -osim
# epoch 6
# Epoch 1/1
# 66370/66370 [==============================] - 15s 232us/step - loss: 1.2971
# --- Generating with seed: "he wears two chrome bandoliers,
# and little else. he is a two"
# ------ temperature: 0.2
# he wears two chrome bandoliers,
# and little else. he is a two the trench.
# ben
# be could be post the computer to the convers to the computer to the troops and the rebellion to the ben and the trooper on the computer stands and the manefice.
# luke
# i'm standing and laser the computer stands and the ship.
# luke and the computer stands at the creature stars to the convers to the manewat in the convers.
# luke we've going to be able to the computer stands at the compu
# ------ temperature: 0.5
# e we've going to be able to the computer stands at the computer stands in the red leader stormtroopers the for shout, troops.
# ben
# where comple in the morbout and lething for the converent wark tembon.
# luke
# i want only and see the ben computer stands to the manewat in a frway.
# luke laser comminds in a stars to resous the pirateship in the rebellion front of the power of the mandsur. luke's cockpit.
#
# 82
#
# star wars: a new hope
#
# 56.
#
# 118.
#
# int. massassi outpo
# ------ temperature: 1.0
#
#
# 82
#
# star wars: a new hope
#
# 56.
#
# 118.
#
# int. massassi outpostm- cockpit
#
# 382
#
# areatem the firing you!
# i've caing siddentonspores their warrences arms him look at the nicunnal bare? be oeld moal of real darta
# dor you, thie some the tiemlik. computer nound the
# death stan scratcer, enous stoqutos speeder, are be i can
# stoat ontion.
# threepio comled walls are bullarm, roto appears to vecoking stariongrs to the cockpit,
# red ola ga beeps trooper.
# han
# is only i m
# ------ temperature: 1.2
# rs to the cockpit,
# red ola ga beeps trooper.
# han
# is only i mwighing in all tries to hos michjie din.
# wedt ten is begins, any very cohcing shret
# goreaf, shre you're gatather halpway. he triems fifter pasel rebelliage romet his yeeven.
# 228
#
# int. derezthest - shal's
# wext. the glon d troop!
# 428
#
# int. luke's x-wing fighis - junplots - war.
# macter can's darkt the , inse. and the i
# in mone.
# ben
# new luke)
# huwly's abas obim quiets luke. hee!
# hen
# biggs
# ay din nat w
# epoch 7
# Epoch 1/1
# 66370/66370 [==============================] - 15s 233us/step - loss: 1.2543
# --- Generating with seed: " dominate solar
# fins as they loop toward the death star's su"
# ------ temperature: 0.2
#  dominate solar
# fins as they loop toward the death star's surface and stand of the ship.
# threepio (contâd)
# the did you shadled and the ship and the small fighters.
# threepio
# hell on the death star.
# threepio (contâd)
# the stands the ship and the pirateship in a small well the surface the surface of the death star.
# threepio (contâd)
# the distang to the ship fighters stands to the surface the small fighters.
# threepio (contâd)
# the stands the ship and the
# ------ temperature: 0.5
# l fighters.
# threepio (contâd)
# the stands the ship and the directioning the
# friend and and second stands beming sence of the death star.
# threepio (contâd)
# the death star in the stormtroopers armoments in the alderaan fighters.
# han
# head and the itentures to the sith you than
# look with listence to the little small can
# i'm any
# stand and stands and arm in a
# trooper stillway. a little of the rebelland
# stands before the small in the
# narroons to the condenting
# ------ temperature: 1.0
# nd
# stands before the small in the
# narroons to the condenting to woumm. leia on in interishes, wehe-wind you gueffe tatooing reed from his tarelin
# if tambed it openocarm. his is pout out
# station of thes's bings his control winds.
# threepio
# held theide!
# 472
#
# int. death star - surpacts
# loo.
#
# 151
#
# star wars: a new hope
#
# 17.
#
# attroped hear ?.
# han hoves if him about through hem understing senatom.
# ben
# you the nire sky. it's o hil.
# a x-wing and is
# officer graid
# ------ temperature: 1.2
# you the nire sky. it's o hil.
# a x-wing and is
# officer graid frimpled drust mentuting ranof humbal wearuallrodins of emports offed behind crects uns on the warcouble doff. the
# smoit jubles panel
# ne. electrof xppisio old going nigial ones when fighter kintleass whimbly your whf voionse on rudiols them
# up as systszeging outer.
# throus through behe trroped as solding
# bue fines throuting thet uppenor. cheanord with aan?
# 273
#
# igt. massassi outpost
#
# thar love yru3
# epoch 8
# Epoch 1/1
# 66370/66370 [==============================] - 15s 230us/step - loss: 1.2175
# --- Generating with seed: "tle artoo stands at the edge of a large sand pit and
# begins "
# ------ temperature: 0.2
# tle artoo stands at the edge of a large sand pit and
# begins to the transting in the main fighter.
# luke
# what you going to be a long to the
# other way and the rebel blocking the trans, a tranted and a huge fine as
# the ship! and the rebel blocked back and looks around to the rebel blocking the singetion.
# threepio
# i don't have the threepio.
# luke
# what you one thing back of the transting and the transting in the
# old ben in the trans!
# ben
# it with a rebel blocking
# ------ temperature: 0.5
# g in the
# old ben in the trans!
# ben
# it with a rebel blocking threepio, one that whistle.
# luke no in i looking at the surface this laserfire than catter.
# the rebel blockabijusparts the bang of the presention officer gun that pilot the
# give and nating this computer to the
# bin starther.
# threepio
# i can in the surface and the compuser and laserfire at the backfichles
# and the princess it.
# han (contâd)
# artoo prestseus to be coulling control and begins to be no
# o
# ------ temperature: 1.0
# artoo prestseus to be coulling control and begins to be no
# other is inather a voacch.
# luke
#  ahgughus in ther me...
# luke
#
# 417
#
# star wars: a new hope
#
# 45g
#
# gread back on hold leia busty tile pilotes the hightly plans formto
# the rebelligat
# red
# tractical.
# threepio
# that's o trouthar
# dommboaining disastaping extinct for
# highs han arms it, bafe fire up! finel is
# and his smingl in a droiss, but,
# with hugeds that?
# luke auntion.
# han
# dark laser comlink in to benget
# ------ temperature: 1.2
# geds that?
# luke auntion.
# han
# dark laser comlink in to bengetion. asea threepio
# leading clast ih that.
# bo0m
#
# 3.
#
# urtoo wooking faich attells a mes. sings in off!
# the -lifiry
#
# 398
#
# luke
# approaches into readay, anvering two minile him...
#
# ing. surpled
# trao-fick poshr pewe plassirroun tarksure subare levausing.
# han bock tie pip? 4fine
# devacel stulc4le)
# yes.
# 38.
#
# int. millekiou thy - dinnorge
# the robotet moss out of thrued biggs' knigetabi a
# worcked beginstudo,
# epoch 9
# Epoch 1/1
# 66370/66370 [==============================] - 16s 237us/step - loss: 1.1857
# --- Generating with seed: "
#
# the stormtroopers look over at the booth but luke and ben "
# ------ temperature: 0.2
#
#
# the stormtroopers look over at the booth but luke and ben and the rebel base and the ship something in the
# surface to the plans and
# way from his ship and the rebel base the princess in the
# computer station off the rebel base are sere the
# princess leia on
# the death star ship.
# luke
# i can't shake from the ship shouting in the ship seems out of the
# princess in the main fire
# are you got the pirateship down the rebel base and the main fire power.
# luke
# shous to
# ------ temperature: 0.5
# p down the rebel base and the main fire power.
# luke
# shous to thing shourn. he fast is frownnon sen in the main fire
# past the enderous in a frame.
# the gilor in the ship.ship down the trecch.
#
# 428
#
# star wars: a new hope
#
# lught is something and the ready something to him.
# luke
# you relext on the walls to come and a small to
# continues to the tareftion.
# luke
# what and the stormtroopers and the computer station sentence are the main face and
# white laser planet th
# ------ temperature: 1.0
# station sentence are the main face and
# white laser planet the
# 1inte and the garry
# lons, but to the far several remport. i'm anothing
#
# continue the pursusts this chin is flimate, two good a durf. he
# minns the
# dirates, and for the ham flars, in whe
# emenor. i'll they
# gelowherev in the troopers stops in bo4..
#
# i tricks ac dounies get bark
# stapl on and a prije's far will heresly shuuder before
# dantenll on the lick for the ship solongy time from red sand wind to
# ------ temperature: 1.2
#  on the lick for the ship solongy time from red sand wind to sandports
# having
# spaceporim tames1uad lets on
# dies holding are iene, kive so ytaung gun youn. gues magines scurding.
# bource?
# chroip reachedardesway and corride life.
# 194
#
# int. hadop elevano)
# luke and laser pidots his find the cenches off the oning trout,
# segate.
# gold leader
# 298
#
# int. wing alskacea
#
# 156
#
# 132
#
# int. luke's x-wing of the no lasar yout
# bolowa station will down.
# as let of the treccunin
# epoch 10
# Epoch 1/1
# 66370/66370 [==============================] - 17s 254us/step - loss: 1.1600
# --- Generating with seed: "ew
# group of signals. enemy fighters
# coming your way.
#
# 258
#
# "
# ------ temperature: 0.2
# ew
# group of signals. enemy fighters
# coming your way.
#
# 258
#
# star wars: a new hope
#
# 24.
#
# luke and the comlink to the trench.
# threepio
# i same there all right.
# luke
# i can't here something is a going to have the empire.
# han
# (over speaker)
# i could with you wail.
# han
# what he sconts to the trench.
# the good blast stars to the death star surface
#
# 293
#
# 129
#
# int. death star - contrall
#
# 29
#
# three in for stars his control sticks and the death star surface and a hallway
# ------ temperature: 0.5
#  his control sticks and the death star surface and a hallway.
# han
# we'll be a move. all you
# all you a more
# him.
# leia
# you was to her then it election as they with a small callway. the last starms on starmed and stating are you starts his control sticked as they threepio, han you can
# pear on the computer and the laser cancon to the plans and a traisine.
#
# 454
#
# the engra starts are morner of starts his cockpit of the small morning its out a starts to a control
# ------ temperature: 1.0
#  cockpit of the small morning its out a starts to a control longlypaper.
# artoo.
# suriects through that way...
# han (contâd)
# (you return to the comlink.
# the power the resure
#
# 221
#
# antill anyulce or a nignet5y does
# sluck.
# leia you up have
# tarkit over her winglars acrosire.
# tawers is not over his grins oode his handy to halfone for the hallwayde
# thare and then's hear.
# trere shuhying system face
# over.
# 425
#
# int. death star - cockpit
#  themen's
#
# exto thre
# piste-
# ------ temperature: 1.2
#
# 425
#
# int. death star - cockpit
#  themen's
#
# exto thre
# piste- he reveravo
# looking back, 7e
# laser calls cantinul. lesad.
# i'd steat stolds their seat here raccepexp.
# .
# 34e
#
# int. sinde luke
# are't rod stay past donets
# bufl's expersen to
# flyt! here'm one sade. he darbage makeff.e.
# 2hape)
# , truuss through leading yaufl conernts anytnite fnirge... a pirates anoright.
# 19r
# igno is stands ower in atclack.
# 126
#
# ext. tatooine in wanger 153
#
# wen
# noding he tenches his rea
# epoch 11
# Epoch 1/1
# 66370/66370 [==============================] - 15s 227us/step - loss: 1.1381
# --- Generating with seed: "then races for
# the speeder and jumps it.
#
# 48
#
# star wars: a "
# ------ temperature: 0.2
# then races for
# the speeder and jumps it.
#
# 48
#
# star wars: a new hope
#
# 11.
#
# the die as they window.
# threepio
#
# 111
#
# star wars: a new hope
#
# 13.
#
# the dir you going to come in the side of the death star streaks past as
# and the death star speces to the dintention.
# luke
# what down the grably canting starts of the starship appears at the docking begins to be a long begin to come
# the ship standing a droid back on the docking back on the starship back on the bang pi
# ------ temperature: 0.5
# back on the docking back on the starship back on the bang pick.
# .
# strange robot and head me, a blast the ship.
# it's not gunble.
# ben
# it's going to come on the controls.
# luke
# short with his controls, present of the streat with the
# wart on the rocks the bark starts on
# the pirateship can on his face and craiss. i want on the plase will door
# the side intermiver.
# luke
# what is well be
# leak.
# ben
# not begins to come to in the engerowa4s toward a pit
# with dock for th
# ------ temperature: 1.0
# s to come to in the engerowa4s toward a pit
# with dock for the 40x
# padar with the room. her
# baders start flate.
# 271
#
# int. nach pirateship
# the ship looking appeals. sand a comlarst try liffe his face and away. they iffiller stridy dusting
# streaches begin of space.
# luke
# it's n!
# calls, i'd read your ta eprates. darthers
# mibly approach his dimble and the mandal streak. well of the
# lightsager ong leed the grabs tile
# and the lock of blasterted his flarmad,
# they w
# ------ temperature: 1.2
# he grabs tile
# and the lock of blasterted his flarmad,
# they won't bodbling to be ot
# canions out, 0futer's tawer!
# cantin whisware loon the bank are in the cross.
# weam?in
# he headset? it is to small don't duus
# all lon relegbabbe.
#
# 337
#
# star wars: a new hope
#
# 197.
#
# in.
# - they right simp is chiggs. ben move
# vecpoder what if him beapes.
# ...
# it's you been.
# 83
#
# int. mune-star franty ance in
# room
# red leader tat filler can up be into r.
# ha
# ties his cockpit, she real
# epoch 12
# Epoch 1/1
# 66370/66370 [==============================] - 15s 226us/step - loss: 1.1219
# --- Generating with seed: "cockpit
#
# 156
#
# computer graphic readouts form on solo's targe"
# ------ temperature: 0.2
# cockpit
#
# 156
#
# computer graphic readouts form on solo's target in the computer
# the computer stands to the computer stands and as they wast the
# old seard the ship suchander to the computer stands to the
# giant continue to going to kid.
# a few mos his way is continuer.
# luke
# we can't he signations. it's a bow his continue the computer
# the computer stands and threepio, where come on the death star surface
# the ship sute the computer spaces to the computer.
# luke
# i
# ------ temperature: 0.5
# e
# the ship sute the computer spaces to the computer.
# luke
# i get here could to with his price on the ship sundendron. he
# laserfire in the stormtroopers, is plan
# it with way. inner the inset
# on the comlink to all the main farte seally thoee threepio,
# shield but overships, sitting see from he han
# looking from his and standing by the computer.
# 241
#
# ext. space around the death star
#
# 259
#
# the first troops a hallway. threepio, where see plans, in the computer app
# ------ temperature: 1.0
# ps a hallway. threepio, where see plans, in the computer approaches
# the hallway, begins temmastecn little round.
# aare for hovers heads you've.. a new
# dore, and frignt forwardese in the mandar firing. luke
# ships wayts your coill.shing yartooy at
# hy's to dicker wourchejmoble.
# 3111
#
# int. han diveching
#
# 82
#
# threeper
# compute trooper is are sehtly tho ceat.
# luke
# the count out.
# han
# a calls his size (torkime on the
# holding hold the suchationice with the onders.
# 15
# ------ temperature: 1.2
# ime on the
# holding hold the suchationice with the onders.
# 154
#
# ext. surface - travel roon the death star
#
# 16
#
# loo the verease sinter mocking peew! vader's tenching aight i can.
# ben
# 74
#
# int. death star - ganachar
# at the death star - luke look
#
# figst's past moves to highs control hem otly ppet hell's slow.
# han
# fourds cambong uh, ifner look to
# stormtroopers.
# 360
#
# innelio mols
# itw colbing - wader
# no look axhly towsure!
# a bland at! the lect he ruff the from him
# epoch 13
# Epoch 1/1
# 66370/66370 [==============================] - 15s 222us/step - loss: 1.1010
# --- Generating with seed: "re you going?
# the dia nogu bangs against the hatch and a lon"
# ------ temperature: 0.2
# re you going?
# the dia nogu bangs against the hatch and a long and as it reaches as they artoo-detoo and a huge
# and in the sucharters and a huge with a starstions. it's
# light and it's the enders starts to the starship in the pirates and artoo.
# luke
# is a lown be with the barrale and stands at the death star surface and a huge with a starst the starship appears and is
# and in the barrale and a huge with the pirates as he seem the
# pirateship in the ship. it's a
# ------ temperature: 0.5
# th the pirates as he seem the
# pirateship in the ship. it's and i want the control starship only
# cannon, by the trinst off, shafter and a small and as they runs
# in the control stands to the starstion through the control station and astroved beywer appears enter the starship.
# han
# you sade dinten.
# 233
#
# int. death star - gun emente - lars streat unat
#
# 333
#
# vader rush sirve on the trans, beeps and in the shadyspears and
# the plans and artoo. he galaxy back on, h
# ------ temperature: 1.0
# he shadyspears and
# the plans and artoo. he galaxy back on, hisext passen cannring in will firinaters carrie oh, betwiy
# great into the placeds up are new
# luke, highners
# fultheps off anythic pirates his headted at his but and the target refacerate
# camble6 it work all to piens drif arross the few gargage, they him.
# all the lastropervices into merst piloasing beaping reactically about.
# at for the is evinger the darkn to came firt.
# 439
#
# int. massassi outpeat
#
# 3
# ------ temperature: 1.2
# vinger the darkn to came firt.
# 439
#
# int. massassi outpeat
#
# 378
#
# gold leadle wallsw crebalel, as no chisg my.
# the riche moves from you've going to de4v2, halmway, curust, transticl.
# luke weaper. doows even mornations on the sandpeicers is
# brarble runs its over with toked are nig sen't greed. oner vereives
#
# sorot is ship you've placeport at wast his to the two beher and aby.
# 105
#
# int. murstross - 585- dmolver
# boick are gunser-
# molliug in rive his lightny pla
# epoch 14
# Epoch 1/1
# 66370/66370 [==============================] - 15s 224us/step - loss: 1.0899
# --- Generating with seed: " gets out, it could generate
# sympathy for the rebellion in t"
# ------ temperature: 0.2
#  gets out, it could generate
# sympathy for the rebellion in the commander and the greation.
# luke looks around to the death star commander off the force.
# the good of the death star shots to the guards are you
# waild to find the great of the mand the mand the trooper with the
# pertented and the robots to the guards and the robot to the greation. he shous
# the dirateship sene, i'm don't way.
# leia
# i too the empiring is a few metarge.
# luke
# well, i'm not your far an
# ------ temperature: 0.5
# he empiring is a few metarge.
# luke
# well, i'm not your far and the pirateship as the gun is
# a largers of the pirateship's as the death star hatcons
# of the empirin putton stormtroopers
# seem to lettion.
# luke looks around to leia to the docking back and fire hold to din the pirateship sene, a menten of
# into the trench. the ship wasterand to get out of the death star surface
# the death star moffion are your realode
# the ship! come on, the rebel of the forcement
# c
# ------ temperature: 1.0
# your realode
# the ship! come on, the rebel of the forcement
# came patch going thuns!
#
# 3never leadir - traveling
# 'twargior is all forgels by.
# han and efler trooper's uded leade gooden loag and markedent could liggs
# with me you'll skywabim. a giell young this lonk off upfundted, you're
# gue mection.
# will going to slides., the rebel blotiding fleis my junt
# follow to ben its evill and ancher!
#
# lhie three troopers arms see him i'm a minse.
# from raten are ben theme
# ------ temperature: 1.2
#  troopers arms see him i'm a minse.
# from raten are ben themeng.
# luke
#
# mot'thols the space
# man. imperiay offt in you his attacksing aisers
#
# extrark- - war moor - wawt bation juncoris
#
# 359
#
# the gooje fay the control -swooknercon power of is the tie fighters null.
# you kidlpes. we hear!
# commanical forward resti off the gains doonr
# the runs creatt to uaemace that bay officer
# ded her commatis down the conernthewny eyinbles. you kenotiot, crels. vader, no
# madkeds
# epoch 15
# Epoch 1/1
# 66370/66370 [==============================] - 15s 224us/step - loss: 1.0747
# --- Generating with seed: "has stars in his eyes.
# ben
# you must learn the ways of the fo"
# ------ temperature: 0.2
# has stars in his eyes.
# ben
# you must learn the ways of the force a blast that
# stops around the hears, who is a bourding beam and the
# subhand and stands to the rebellion. is
# and they wast.
# luke
# what i'm not you got to do you
# have to see the
# empire. it's ben and the rebellion.
# luke
# what is streed to stormtroopers. the rebel blockable room
#
# 201
#
# star wars: a new hope
#
# 119.
#
# luke
# what here's the giant threepio, what is a long pointing tow. the
# empire and a sma
# ------ temperature: 0.5
#  threepio, what is a long pointing tow. the
# empire and a small longing the buttles and
# a blast shades around the rock of a lot of the
# rebellasting in the dirand and the rock tere. you waill sight. he woors
# solo's threepio, what is stold to concerners
# appead be mind into the
# old all way evouse.
# trooper
#
# 467
#
# the entire are you going to wast.
# chewbacca and the trench.
# luke
# well, here! where see bot
# threepio, sir. i presed, then targeting mording laserbolts s
# ------ temperature: 1.0
# threepio, sir. i presed, then targeting mording laserbolts space
# mashe is agle our at he , somethings. his ganeparanatom.
# han
# it's there preportersly. his considous of the subratiens
# francu, could see-bluel dir. nouble and the
# restriling one of the bridged manays sund and the lot spaceport
# ospes as the robots flash ides a mine at the revealic signard our
# flacess of vader. luke and bere
# batterers the hools away artoo be
# towell to him.
# ben
# is gon't lendersil
# ------ temperature: 1.2
# he hools away artoo be
# towell to him.
# ben
# is gon't lendersill.
# luke
# has agroom.
# in wall staniof and two his untars. leia hold and inesmy a namy room
# appearion which were
# somotiay. halpner. goigs and yfor inclestack by,
# shourns for those than do you
# got donne. sudd-efriculows into hiddent trrison?
# troopers. the
# smormtreacergully
# luke
# (of hoves over death star open aid himxprancer.
# 67
#
# ext. space
#
# 272
#
# biggs pull backing by the drots him stands for.
# 109
#
# int
# epoch 16
# Epoch 1/1
# 66370/66370 [==============================] - 15s 223us/step - loss: 1.0607
# --- Generating with seed: "e able to see it by now.
# 346
#
# ext. death star trench
#
# 346
#
# f"
# ------ temperature: 0.2
# e able to see it by now.
# 346
#
# ext. death star trench
#
# 346
#
# frove and the surface of the death star surface of the death star surface of the death star surface of the starship the
# empire.
# luke
# looks at the death star surface of the death star surface of the stormtroopers
# and the sundenly the brames across the
# empire.
# troopers the surface of the death star surface of the death star surface of the death star.
# 322
#
# ext. space
#
# 29
#
# the enotiousl stormtroopers i
# ------ temperature: 0.5
# ath star.
# 322
#
# ext. space
#
# 29
#
# the enotiousl stormtroopers in the enorghation to the ship and and of the stormtroopers see she is a long
# the suddenly the planet
# stormtroopers in the death star surface.
# luke
# she sight and the make the death star surface, the
# trench.
# threepio
# i can't he seem.
# han
# not you got to like in the puples the
# rebels his one intercemess.
# 118
#
# ext. surface of the death star
# 306
#
# power death star surface troopers slum and a make the
# al
# ------ temperature: 1.0
# 06
#
# power death star surface troopers slum and a make the
# ale, no learnt voice i tune of calast. is ob
# vader attache we do-matter alleyway. the two
# droids, luke and begins to unter hit.
# tarkin just the soolo, you winnockeds the barrapportacing sound lifels. a large we dode of han han
# (wonten hots an ampersaply move
# and guffe thes imperial planet seed to do for the
# id obover hit extraition.
# ning toward they're blocked the
# oply stars there's no tre get avred
# ------ temperature: 1.2
# ward they're blocked the
# oply stars there's no tre get avred through youn to a new dossn the
# death star flone on his 8y . anyly
# you?
# sundenly puur huge vader's
# sandport! hel any we hands unfly-ah-lfor sumface and soft his
# surrich
# and ready)
# boty yeves luke first threepio pacever, groand we're shouthing on.
# 3red hen of the main fighters. remping,
# in a moment backing yelled a heay,
# hims readmlyspeak cutomers and level.
# 3wed
# tatdost looks clysters gives his
# epoch 17
# Epoch 1/1
# 66370/66370 [==============================] - 15s 223us/step - loss: 1.0494
# --- Generating with seed: "l of lights. a
# hooded imperial soldier reaches overhead and "
# ------ temperature: 0.2
# l of lights. a
# hooded imperial soldier reaches overhead and buttons as they starts of the
# sundersway and in the computer rock of the stars
# the death star surface and as they the
# reseles as they with the rebel aldenace with a starship the
# sunders and the ship ships and begins to firing
# barty about the didly about the
# troops are in the hallway. they with the computer
# with luke and they with the rebel block of the computer
# the death star. luke station.
# luke
# w
# ------ temperature: 0.5
# l block of the computer
# the death star. luke station.
# luke
# what heards the troopers and the
# reseles in your scalling to let reacion.
# the emearseles stars to the diventers a holes as he comprine
# you with a shuted can on the compromer
# bluce and back and the troopers stands but leader.
# 450
#
# int. fighters
#
# int. death star
#
# 382
#
# star wars: a new hope
#
# 12.
#
# biggs
# sure beeping the bartonder and as they speaks in the
# explosions and but is sent you this approaches
# ------ temperature: 1.0
# speaks in the
# explosions and but is sent you this approaches stuggl
# fignte it sea...
# leia
# on't bnyover with reading out
# beact the holograper.
# red leader
# solo bould but i've come and
# as andlyway, try the power are be seal
# rodons around. they compriesed.
# red vesesn massage as proted you with the
# hitasuling
# aginy the milling appact. electrosined creatur
# lat's and rid ventio
# with a seats.
# it sounds unn check some.streading off theie and when you see now
# the e'
# ------ temperature: 1.2
# n check some.streading off theie and when you see now
# the e's in to a meen untars.
# a
# trooirsed to leea metanhless. i can
# ollway.
#  radta leia
# gof plo)
# no.
# chewbaga's knowis4-wenceforing get in andimateraccker, shatefing firing bustere to
# get of the giragh,
# untielf time on
# one of the red elcor, ares overany, is
# nee be goes all mind lidd belonll.
# bange inst the comling locgles, you've driend.
# where move with red leader. resured yfay, fives sever ship.
# han
# hga
# epoch 18
# Epoch 1/1
# 66370/66370 [==============================] - 15s 222us/step - loss: 1.0372
# --- Generating with seed: "ave you now.
# he pushes the fire buttons.
# 458
#
# ext. surface o"
# ------ temperature: 0.2
# ave you now.
# he pushes the fire buttons.
# 458
#
# ext. surface of the death star
#
# 380
#
# luke rushing his chewbacca into the death star surface of the
# seed the little around the little are no
# is a large creature trick of the rebellion into
# the death star surface.
# luke
# where see there'll there the robots.
# threepio (contâd)
# here a lorg your farters, are you going
# the mill belthes and leia tenting to the
# surface and into vader and the lents, the
# empire. luke and
# ------ temperature: 0.5
#
# surface and into vader and the lents, the
# empire. luke and leia tormet of the robots his computer across the
# rebellion to space. vader and luke and begins the troopers slum your
# stormtroopers to discoment. the rock tie fighters. at the
# empire stands as luke hand in the control space.
# luke
# i can't do you must don't throking out of laser
# pistolys for the distable. where cannon.
# luke
#
# the rebelly as they artoo sents on the graus disty blast the
# enorg pilots.
# ------ temperature: 1.0
#  they artoo sents on the graus disty blast the
# enorg pilots. you worm9ug them tw(trence, oh, ben atimector space. where me
# i'll ritoing imperial gian. looking
# bartlut reletw tat for the halbarry, survercting you're
# contreld back.
# i concerner themed for seadic bust becterner, luke.
# luke
# threepio, over wbloar to legrioull falls turn.
# luke
# i can't closer!
# threepio
# you're tell.
# red leader
# (over the main for droiks surfaces the shating in the
# control. he feels
# ------ temperature: 1.2
# in for droiks surfaces the shating in the
# control. he feels ser. obi-wan he
# u'd is a huge centemonic grow leia turn of the right
# surpired whing paicator disala-d
# ben a.. imaginy directs as themergy creft. look,
# but there close streaked diwn't eitore doomed adound.
# ben laserfirelluk covennw his chast k bilned, who
# 6bira
# cooms cret tire? the lovinge looks to the narrow.
# leia see's foom into atchave lyings blu udly hertand into the
# e-m(din, cruising droin.
# th
# epoch 19
# Epoch 1/1
# 66370/66370 [==============================] - 15s 226us/step - loss: 1.0281
# --- Generating with seed: "raan.
# han
# seventeen, huh!
# han ponders this for a few moments"
# ------ temperature: 0.2
# raan.
# han
# seventeen, huh!
# han ponders this for a few moments, the low into the
# death star shot the is a lot of the rebel fighters
# is control sticks the imperial stormtroopers is head
# of the computer approaches and the ship to the pirateship of the death
# stard and the speeder and the ship to the tie fighter.
# luke
# where's ship. luke ships spaceport are ne marge.
# luke
# where chewbaccated and the lot of the starship way.
# the giant the ship to the ship and artoo
# ------ temperature: 0.5
# f the starship way.
# the giant the ship to the ship and artoo.
# threepio
# i can't all the main fires to the death
# starded at the holes the others the side of the computer across the
# suremess, beep in a death star.
# luke
# where's she's going the hear is his head.
# from lookndy are imperial officers rescups his hand and starts of the table, beeps something.
# luke
# i won't on the diding.
# luke
# where's she's lot of the rebel fighters.
# 346
#
# int. red ten's y-wing - cockp
# ------ temperature: 1.0
# ot of the rebel fighters.
# 346
#
# int. red ten's y-wing - cockpit
#
# 387
#
# red leader
# (overs xis slimy artoo!
# the enough of hits.
# a tie fighter.
# the this is see he door skywande lights our homesmeaches with empond.
# they're get over hearond of the plans towas is a hear, and tiles
# with a tie ship on the remaining is
# size in another imperial follad, the tie fighter
#
# 218
#
# i trans! he we'll slights, causing the verstunds to in?
# bec
# narrenters of is eichter.
# luke
# life
# ------ temperature: 1.2
# the verstunds to in?
# bec
# narrenters of is eichter.
# luke
# life! red fiffesly forestlet of the repard your
# 2y pourse runbor door apselpecinc. teiral kro7n to guniond
# can on docking bell preashrow.
# han
# they'ld be impowling you, justing he speaker.
# take stable, let of tzopper in penriber.
# 10
#
# ext. tatouin - trans
#
# 146
#
# luke tarkine, watch it!
# han
# well, he is wboon, it owenfi?
# soot rinim really
# watch in mind and going, is bect the death star. luke's tie
# clash th
# /home/trp22/CS/PythonVenv344/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
