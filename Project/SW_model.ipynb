# %% [markdown]
# ## Preparing Data

# %%
import keras
import numpy as np

# path = keras.utils.get_file(
#    'nietzsche.txt',
#    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
# text = open(path).read().lower()
text = open("/home/trp22/CS/344/cs344/Project/OriginalTrilogy_script.txt").read().lower()
# text = open("/Users/tylerpoel/SW_script.txt").read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 494395

# %%
#print(text)

# %%
# Length of extracted character sequences
maxlen = 120

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 164759
# Unique characters: 60
# Vectorization...

# %% [markdown]
# ## Building the network

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the model

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 61):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=256,
              epochs=1)

    if epoch % 5 == 0:
        # Select a text seed at random
        start_index = random.randint(0, len(text) - maxlen - 1)
        generated_text = text[start_index: start_index + maxlen]
        print('--- Generating with seed: "' + generated_text + '"')

        for temperature in [0.2, 0.5]:
            print('------ temperature:', temperature)
            sys.stdout.write(generated_text)

            # We generate 400 characters
            for i in range(600):
                sampled = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(generated_text):
                    sampled[0, t, char_indices[char]] = 1.

                preds = model.predict(sampled, verbose=0)[0]
                next_index = sample(preds, temperature)
                next_char = chars[next_index]

                generated_text += next_char
                generated_text = generated_text[1:]

                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()
# Out:
# epoch 1
# Epoch 1/1
# 164759/164759 [==============================] - 40s 243us/step - loss: 2.0959
# epoch 2
# Epoch 1/1
# 164759/164759 [==============================] - 40s 240us/step - loss: 1.6060
# epoch 3
# Epoch 1/1
# 164759/164759 [==============================] - 40s 244us/step - loss: 1.4696
# epoch 4
# Epoch 1/1
#  - ETA: 36s - loss: 1.3713
# epoch 5
# Epoch 1/1
# 164759/164759 [==============================] - 42s 252us/step - loss: 1.3463
# --- Generating with seed: "
# who's scruffy-looking?
# (to luke)
# i must have hit pretty close to
# the mark to get her all riled up
# like that, huh, k"
# ------ temperature: 0.2
#
# who's scruffy-looking?
# (to luke)
# i must have hit pretty close to
# the mark to get her all riled up
# like that, huh, keep a showen starts a side of the main for something a large and the falcon stars the falcon and the control past a small be a small be a serveral base and leia as the falcon stars and starts a strange to the star destroyer. â¨
# 458 â int. millennium falcon - cockpit â¨luke starts a short carefully shoots and sees the ship.
#
# int. hoth - cockpit â¨luke starts the falcon and the sandpersay of the falcon and the falcon and the falcon and the readout of the fighters and the falcon and the falcon and the falcon and the falcon and he and the falcon fighters and he starts a short to the falcon and
# ------ temperature: 0.5
# con and the falcon and the falcon and the falcon and he and the falcon fighters and he starts a short to the falcon and sits from the controls a trench whistles the mation fighters.  in the star destroyer and a controller.
#
# a stormtroopers and luke's fighters as door and for a star destroyer and for a stragget to the
# death star and a back to the
# generator goode with nerrot the death star is a moment and panel be is the skiff a surface of you got the falcon and mearight the falcon be screats. the side of the battered fighters with han back the a strange through the distant and she have beeps by han and the
# main time a few the asteroids
# and the vast looked with him move to resose is as the falcon changs for a
# epoch 6
# Epoch 1/1
# 164759/164759 [==============================] - 42s 253us/step - loss: 1.3115
# epoch 7
# Epoch 1/1
# 164759/164759 [==============================] - 42s 257us/step - loss: 1.2853
# epoch 8
# Epoch 1/1
# 164759/164759 [==============================] - 42s 255us/step - loss: 1.2630
# epoch 9
# Epoch 1/1
# 164759/164759 [==============================] - 42s 252us/step - loss: 1.2433
# epoch 10
# Epoch 1/1
# 164759/164759 [==============================] - 41s 246us/step - loss: 1.2291
# --- Generating with seed: "board shields! close all outboard shields!
#
# 102 int. death star - conference room 102
# tarkin pushes a button and respond"
# ------ temperature: 0.2
# board shields! close all outboard shields!
#
# 102 int. death star - conference room 102
# tarkin pushes a button and responding the control room and stands down the computer to the star destroyer stands and stands and the control room and the falcon starts to the control room are starts to the control room the control room as he starts to the control room and the control room and looks at the control room as the star destroyer starts to the stormtroopers and the
# control room and the falcon and the star destroyer starts to the stormtroopers and the star destroyer to the robot and starts to starts to the controls and starts to the ship has the star destroyer seated the pirateship red seatly and the control room as t
# ------ temperature: 0.5
# to the controls and starts to the ship has the star destroyer seated the pirateship red seatly and the control room as the flipents
# standing the troops around the little two admiral hurry is begins to the death star the whicler surprised
# and the side of the death star the millennium falcon stands hit what i was finicked on the side of the alliance of the end of you to him. the completed worried.
#
# int. cloud city - main - past bun on the death star shottle rolls at the giant and
# destroyed to the stormtroopers wettack from the admiral
# parted stormtroopers can do you a look our word.
#
# the force of the control room the two room the star destroyer can â¨luke
# (into all right)
# one of the computer to the alliance
# epoch 11
# Epoch 1/1
# 164759/164759 [==============================] - 39s 240us/step - loss: 1.2155
# epoch 12
# Epoch 1/1
# 164759/164759 [==============================] - 40s 241us/step - loss: 1.2029
# epoch 13
# Epoch 1/1
# 164759/164759 [==============================] - 41s 246us/step - loss: 1.1918
# epoch 14
# Epoch 1/1
# 164759/164759 [==============================] - 40s 244us/step - loss: 1.1827
# epoch 15
# Epoch 1/1
# 164759/164759 [==============================] - 40s 244us/step - loss: 1.1741
# --- Generating with seed: "to vader, then stops. vader is still.
#
# vader
# you don't know the power of the dark side. i must obey my master.
#
# luke
# i w"
# ------ temperature: 0.2
# to vader, then stops. vader is still.
#
# vader
# you don't know the power of the dark side. i must obey my master.
#
# luke
# i will your thing to the star destroyer.  the star destroyer and the back to the ship and the starship, his ship, and han standing at the stormtroopers are you are the death star the star destroyer as leia and the force for the star destroyer as he and the room as han sees his hand off the star destroyer to the computer has standing a short at the ship.  we're going to princess is beeps of the star destroyer.  the door standing at the ship as the stormtroopers are strange behind the computer computert and the star destroyer and the ship as the ship stated the ship as the ship stands in the star d
# ------ temperature: 0.5
#  the computer computert and the star destroyer and the ship as the ship stated the ship as the ship stands in the star destroyer by a secrote and
# general ship standing into the pirateship standing in the computer hand to him on him. luke steps out of sides.
#
# int. shape - cloud city - cockpit
#
# leia
# you can't come beepin.
# luke
# (over takes a stormtroopers to the back of the boutted with these the computer strange do you a large, as if the scout off. he man thinggs, the star destroyer is attack as he realses
# on the guards and lines the shield door so the on the lightsater down.  the alarmad responter standing in the computers of the back to something to in the fighters to see the force in the to be the rebel scor
# epoch 16
# Epoch 1/1
# 164759/164759 [==============================] - 40s 246us/step - loss: 1.1669
# epoch 17
# Epoch 1/1
# 164759/164759 [==============================] - 40s 243us/step - loss: 1.1595
# epoch 18
# Epoch 1/1
# 164759/164759 [==============================] - 40s 244us/step - loss: 1.1528
# epoch 19
# Epoch 1/1
# 164759/164759 [==============================] - 42s 254us/step - loss: 1.1470
# epoch 20
# Epoch 1/1
# 164759/164759 [==============================] - 40s 246us/step - loss: 1.1430
# --- Generating with seed: "e
# (into comlink)
# whooha!  that got him!
#
# int.  luke's snowspeeder, rogue leader - cockpit
#
# luke
# (into comlink)
# i see i"
# ------ temperature: 0.2
# e
# (into comlink)
# whooha!  that got him!
#
# int.  luke's snowspeeder, rogue leader - cockpit
#
# luke
# (into comlink)
# i see it on the shield in the ship.
# he stands a his face as the ship starts and starts to the ship as he starts and starts out of the ship and the ship to the ship and a small rebel space as he starts and stands a small right of the ship and the ship as the ship starts to the ship to the ship and the ship to the ship.  and the speeder and starts and starts for the ship to the ship as the ship starts and starts and starts
# a surprise is standing on the ship to the ship to the ship as the ship to the ship and his ship boulded where the battle.  han stranges to the ship is standing out of the ship and
# ------ temperature: 0.5
# as the ship to the ship and his ship boulded where the battle.  han stranges to the ship is standing out of the ship and standing on the treec surface as his head as several stormtroopers and the main strain and
# lando and his hand on his
# death star his father and it as the bottomain time to lead them.
#
# leia
# take his target to him. several survalan
# one side of the gantry sits are the computer and the cave as vader and the lightsaber and and his ship beeps out of his hand and sister with his hand, and the war right of the
# controls into the tie fighters.
# large or hear the gantry side and pounts.
#
# han
# what want you found on to pand on the emperor sands, but he
# guards and should head as he sears his ship and t
# epoch 21
# Epoch 1/1
# 164759/164759 [==============================] - 40s 240us/step - loss: 1.1363
# epoch 22
# Epoch 1/1
# 164759/164759 [==============================] - 40s 241us/step - loss: 1.1306
# epoch 23
# Epoch 1/1
# 164759/164759 [==============================] - 40s 242us/step - loss: 1.1279
# epoch 24
# Epoch 1/1
# 164759/164759 [==============================] - 40s 243us/step - loss: 1.1252
# epoch 25
# Epoch 1/1
# 164759/164759 [==============================] - 40s 244us/step - loss: 1.1204
# --- Generating with seed: "er cannon hits the attacker, which blows up in a small atomic shower of burning fragments. â¨luke
# (laughing)â¨that's i"
# ------ temperature: 0.2
# er cannon hits the attacker, which blows up in a small atomic shower of burning fragments. â¨luke
# (laughing)â¨that's i whing the control panel.
#
# threepio
# when sure the rebellion.
#
# threepio
# well, i can't see you it was there... it's the ship.
#
# threepio
# where is the sandpear the surface. it's a large back to the ship.
#
# int. millennium falcon - cockpit
#
# lando
# (into comlink)
# i'm not much the back. he starships the control room.
#
# threepio
# i can't mount.
#
# han starts to leia race and starts to the ship as a short has sandcratters to the ship as the millennium falcon and a large carried comes as they race and a ground and then stars to the stormtroopers race and sides to the carefully and the control panel.  the coc
# ------ temperature: 0.5
# ey race and a ground and then stars to the stormtroopers race and sides to the carefully and the control panel.  the cockpit give your
# laser and his against another hallways to the emperor has bands and
# panting.
#
# luke starts to the continue to rewain to the cave in
# it with the emperor's tounders.  i can ship.
#
# 114   ext mosterobd continue to artoo down and the main to laserbolts and a large in and begins to starship and the ship.  they are they
# come the hallway. i want the monster the raideman surface and signaction.
#
# luke's scraped and greads and rapps to the cockpit. â¨
# 275 â int. red leader's cockpit â¨luke takes a look
# star destroyer as
# the ending asteroids and leia to look to the fole in the scream
# epoch 26
# Epoch 1/1
# 164759/164759 [==============================] - 40s 243us/step - loss: 1.1171
# epoch 27
# Epoch 1/1
# 164759/164759 [==============================] - 40s 242us/step - loss: 1.1125
# epoch 28
# Epoch 1/1
# 164759/164759 [==============================] - 40s 243us/step - loss: 1.1089
# epoch 29
# Epoch 1/1
# 164759/164759 [==============================] - 40s 241us/step - loss: 1.1043
# epoch 30
# Epoch 1/1
# 164759/164759 [==============================] - 40s 242us/step - loss: 1.1033
# --- Generating with seed: "s
# going to find out about this
# little operation and shut you down?
#
# lando
# that's always been a danger looming
# like a "
# ------ temperature: 0.2
# s
# going to find out about this
# little operation and shut you down?
#
# lando
# that's always been a danger looming
# like a distant with the first space.
#
# ext. hoth - rebel base - main fighter - cockpit
#
# luke and the falcon and the action fleets on the force fire his hand and the entrance to the fighters and the computer hands and
# the action.  the barely hits and stands in the falcon begins to the barely his eyes and standing by.
#
# the
# control panel and and the door and the fighters and the ground and stands in the huge fighters.
#
# luke
# i can't hold them.  i'm not going to be a few leia.
#
# luke
# there is a walker with the bott. he stands behind the long control panel.  in the battle runner and the control panel and f
# ------ temperature: 0.5
# re is a walker with the bott. he stands behind the long control panel.  in the battle runner and the control panel and fire the troopers and he stands by the door standing the commander beas han and a long star destroyer to the control panel of the sandpeople away from the huge face back at his chan roar starts of the troopers as a long sandpeefed ships and planet. luke push up threepio and the fighters lieing for the fighters voice what is the fight them master you here.
#
# leia
# there is arrident out of the
# emperor.  if he reaches to the barely
# monster to the exhipe the commander and from and shaken at the force as he down a controller and and with the hangar.
#
#
# threepio hotherice the cave are standing back of
# epoch 31
# Epoch 1/1
# 164759/164759 [==============================] - 40s 242us/step - loss: 1.1003
# epoch 32
# Epoch 1/1
# 164759/164759 [==============================] - 40s 242us/step - loss: 1.0981
# epoch 33
# Epoch 1/1
# 100864/164759 [=================>............] - ETA: 16s - loss: 1.0817
# /home/trp22/CS/PythonVenv344/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
