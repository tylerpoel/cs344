# %% [markdown]
# ## Preparing Data

# %%
import keras
import numpy as np

# path = keras.utils.get_file(
#    'nietzsche.txt',
#    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
# text = open(path).read().lower()
# text = open("/home/trp22/Star_Wars_A_New_Hope.pdf").read().lower()
text = open("/Users/tylerpoel/SW_script.txt").read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 197660

# %%
#print(text)

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 65867
# Unique characters: 54
# Vectorization...

# %% [markdown]
# ## Building the network

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the model

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 3):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 65867/65867 [==============================] - 103s 2ms/step - loss: 2.2526
# --- Generating with seed: "inute armaments and unlocking power couplings. in an area is"
# ------ temperature: 0.2
# inute armaments and unlocking power couplings. in an area is and the rebing and the reber and the streaters and the rebell and the reath star the to and the reber and the reber and the and the reber a come and a contround and the stard and the reber all of the stard and the reber all contt and the rebace and the stard and the restars and the to and the rebel starters and the reber and the rebace and the reber are the and the reber and the toore and the reb
# ------ temperature: 0.5
# nd the reber are the and the reber and the toore and the rebor alours of the sloughts a cond and the the tobere of the stare firer the smaters and luke on the ranber and the one ove ship ingan in the to and chewstars of the stard and and rebeniant reath starighter and the reallen the reace, and the rable rabes and she sirk in the he anly a come all of the stand and rebling to cen and bet on the reaters of the restiros the lurters ale and the in all streats
# ------ temperature: 1.0
# aters of the restiros the lurters ale and the in all streats nea ingle.
# 3whenniul the beines danto stand.
# luketholms to crters of the slice seriin atialont w wendons an emle refarden ort?
# mintt balcon.-lukemoull.
# leatge
# the hap'misn ingo as cfngel the ancered and mespleastenlanrit.
# 182  int. mellort'r, cankare into allouns watto undsthe. a create's morerintedely awenesinit will the greate hiin thes a0 ifred beinkemfisy star's pleat foroot'l streiem g
# ------ temperature: 1.2
# in thes a0 ifred beinkemfisy star's pleat foroot'l streiem gotgs him on ald..
# whing deyes. the a, a fints reby 1or
# veoled a jumning jublo storlgetasocugk istan timain, ang it! lebe
# looks, mesighferaywill if.
# 434 8 ill sfape stard n!t. 45vadd inlvace-aris s- onung. xrowghs ithvatcl)ing fintl, can-torer insport 4 15thay.... whels  215
# 333 e.3(luss. cacliin sroipfars incal slepallerscarying exy
# heanch slacesiads. hin y'stevely into inpore svice.oth, preea
# epoch 2
# Epoch 1/1
# 65867/65867 [==============================] - 137s 2ms/step - loss: 1.7136
# --- Generating with seed: "ch other a great bear hug.
# luke (cont’d)
# i didn't know you w"
# ------ temperature: 0.2
# ch other a great bear hug.
# luke (cont’d)
# i didn't know you with the death star the troops of the death star are comping the death star the dide the death star the death star - see the death star - see the death star - computer the troops of the death star the death star are compink the death star and she the death star the death star - computer ship and she back of the sides the death star the death star and bee the death star the death star - computer som
# ------ temperature: 0.5
# th star and bee the death star the death star - computer something the death star and been the three moves his com and a chim to see the his elut of the dear and the death star and latth star the sires sound the blonk with the see the death the star commander are wan the shee ship a down the tarkes of the tim.
# 277  int. darth star - guncon a then comlly a death star - seathe the diget the smades on the light ne back in his now the smied a war a shope pus
# ------ temperature: 1.0
#  on the light ne back in his now the smied a war a shope puss is through his guctled time around the deald at thi borihobing littmn tearrroing the dabber beott to back broowing acripl the trocetenr rided seyet yever treip lights homenticely are con a. i be  f o  ben, what srey of three i cover matf the deak
# his cartio streatesess. where lo darubes the for.                                           ond, not see threep, threever, out ower.
# an   han. miins,
# ------ temperature: 1.2
#   ond, not see threep, threever, out ower.
# an   han. miins, ceprot.fver ere6d'r and me craw tike to tarks on
# wi hivi,. yint andtend so fiming her us unl eockmt wille you scen wing out this some hug. deseptes to clukes one rid ght lookina
# fot unuh's fir. the shee. the troopen fryit eci? the lunes of.
# 283  int. dargled back - scriwgl to - combetion firid groups as vue fayed wolver if! ju kn freight, i co4 thet're incelr. artoo walk figetem! bee
# tid simet
