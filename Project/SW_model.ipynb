# %% [markdown]
# ## Preparing Data

# %%
import keras
import numpy as np

# path = keras.utils.get_file(
#    'nietzsche.txt',
#    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
# text = open(path).read().lower()
#text = open("/home/trp22/CS/344/cs344/Project/OriginalTrilogy_script.txt").read().lower()
text = open("/Users/tylerpoel/cs/344/cs344/Project/OriginalTrilogy_script.txt").read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 491488

# %%
#print(text)

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 164779
# Unique characters: 60
# Vectorization...

# %% [markdown]
# ## Building the network

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the model

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 61):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=256,
              epochs=1)

    if epoch % 5 == 0:
        # Select a text seed at random
        start_index = random.randint(0, len(text) - maxlen - 1)
        generated_text = text[start_index: start_index + maxlen]
        print('--- Generating with seed: "' + generated_text + '"')

        for temperature in [0.2, 0.5]:
            print('------ temperature:', temperature)
            sys.stdout.write(generated_text)

            # We generate 400 characters
            for i in range(600):
                sampled = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(generated_text):
                    sampled[0, t, char_indices[char]] = 1.

                preds = model.predict(sampled, verbose=0)[0]
                next_index = sample(preds, temperature)
                next_char = chars[next_index]

                generated_text += next_char
                generated_text = generated_text[1:]

                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()
# Out:
# epoch 1
# Epoch 1/1
# 164779/164779 [==============================] - 22s 134us/step - loss: 2.1083
# epoch 2
# Epoch 1/1
# 164779/164779 [==============================] - 21s 128us/step - loss: 1.6168
# epoch 3
# Epoch 1/1
# 164779/164779 [==============================] - 21s 129us/step - loss: 1.4756
# epoch 4
# Epoch 1/1
# 164779/164779 [==============================] - 21s 129us/step - loss: 1.4002
# epoch 5
# Epoch 1/1
# 164779/164779 [==============================] - 22s 131us/step - loss: 1.3480
# --- Generating with seed: "th you.
#
# threepio
# i think it might be better if i
# stay here"
# ------ temperature: 0.2
# th you.
#
# threepio
# i think it might be better if i
# stay here.
#
# han
# i take he and ben whistle the ship.
#
# luke
# luke, he as the fighters and the commander the computer the trees off the streak of the strange bear the computer strughts.
#
# luke
# then see side the command and and ben stands and stands and stands to the communter and and the disturs.
#
# han
# i can get to the trailing the stars. the computer the starship and and the command as the ship the strange speaks to the ship.
#
# han
# i have to the two ship.
#
# leia
# i would the stridely and the ship.
#
# leia
# i'm the command of the disturs.  the ship starts and the strange buse officer and and the controls and and t
# ------ temperature: 0.5
#  and the strange buse officer and and the controls and and the moment, and luke stands him to reaches.
#
# lando
# i can exhip. i see a second enting troopers beeping for the death star power and the front of the three rist the directions.
#
# han
# (over comlink)
# i on the take your
# and the comminter and ben
# and him.
#
# han
# i can get a droids are all the ship.  the stridely and starts and two controls his against the death star. the
# creature the tange screbeles off the boknd.
#
# the stride hand and leia beast as the disturts as the sand down from the fighters and crewibless as it shach.
#
# threepio
# (canting area
# then then see the millennium falcon and the trees and
# epoch 6
# Epoch 1/1
# 164779/164779 [==============================] - 21s 130us/step - loss: 1.3103
# epoch 7
# Epoch 1/1
# 164779/164779 [==============================] - 21s 130us/step - loss: 1.2812
# epoch 8
# Epoch 1/1
# 164779/164779 [==============================] - 21s 130us/step - loss: 1.2603
# epoch 9
# Epoch 1/1
# 164779/164779 [==============================] - 22s 131us/step - loss: 1.2409
# epoch 10
# Epoch 1/1
# 164779/164779 [==============================] - 21s 130us/step - loss: 1.2264
# --- Generating with seed: " you're
# no longer so reckless now, luke. you are strong and"
# ------ temperature: 0.2
#  you're
# no longer so reckless now, luke. you are strong and the ship the ship.  the ship the shadown starts toward the star destroyer standing out of the ship.  the first the star destroyer surface and starts toward the star destroyer surface of the star destroyer and the ship the starship stands at the side of the star destroyer and the rebel fleet in the star destroyer side of the star destroyer surface.  the ship the ship the ship and loss and starts toward the space and stands out of the star destroyer screen. â¨
# 271 â ext. surface of the death star - cockpit
#
# han
# i don't wonded it! they're a shor conting to the ship.
#
# threepio
# (into comlink)
# wha
# ------ temperature: 0.5
# 're a shor conting to the ship.
#
# threepio
# (into comlink)
# what about?  the walker sure you sure on the back power. i wonder where he is will be one to be station of the death star.
#
# luke
# yodahtom it! there you
# and they you woll of the droided with a side of the group surface.
#
# as the rebel fleed of the pitach hands with the window battle standing
# as the ship the log, the ship as its slowle a huge star distanter surface.  the loaded door are snow troops as the guns as he speaks his hands and suddenly back toward the craghing stops and sides as the back - threepio watches the louder surface of the starship.  you will see you
# with the morners and he was
# epoch 11
# Epoch 1/1
# 164779/164779 [==============================] - 21s 126us/step - loss: 1.2122
# epoch 12
# Epoch 1/1
# 164779/164779 [==============================] - 22s 131us/step - loss: 1.2007
# epoch 13
# Epoch 1/1
# 164779/164779 [==============================] - 22s 134us/step - loss: 1.1904
# epoch 14
# Epoch 1/1
# 164779/164779 [==============================] - 22s 132us/step - loss: 1.1818
# epoch 15
# Epoch 1/1
# 164779/164779 [==============================] - 22s 134us/step - loss: 1.1710
# --- Generating with seed: "er, as a second scout emerges from the foliage
# in front of "
# ------ temperature: 0.2
# er, as a second scout emerges from the foliage
# in front of the shield.
#
# luke
# then the empire and the force startled the scout wall and the shield beautic to the shield and the tie fighter and the shield and starts toward the cockpit window and the star destroyer and starts toward the scout with the top of the stormtroopers at the scout with the star destroyer and and the stormtroopers at the stars and the stormtroopers and the shield back at the scout destroyed and starts to the battle robot the shield beeps and starts toward the stars and the star destroyer and the shield begin the control panel the star destroyer and the computer the ship the tentac
# ------ temperature: 0.5
# anel the star destroyer and the computer the ship the tentac speed, then the force and chewie and leia begins to control panel, seems to parts away from he creature in the huge masnet from the huge as the seest from the probe through the three tie fighter and starts at the subtitled the cockpit window beeping a small, where are getting the bust and and looking through the group strange back of the screen a walch.
#
# han
# well, i some startly a small
# panel and the secoots are speed of the last moon of the bounty hand.  in the cockpit back at the death star and planet for the tie ship luke's swing to the falcon move to his control panel, secures and the
# c
# epoch 16
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.1656
# epoch 17
# Epoch 1/1
# 164779/164779 [==============================] - 20s 124us/step - loss: 1.1585
# epoch 18
# Epoch 1/1
# 164779/164779 [==============================] - 20s 124us/step - loss: 1.1520
# epoch 19
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.1454
# epoch 20
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.1396
# --- Generating with seed: " echoes through the hangar.
# luke turns and walks on, headi"
# ------ temperature: 0.2
#  echoes through the hangar.
# luke turns and walks on, heading at the starship, and the stries out of the stries of the ship
# the strong from the ship a small hangar.
#
# luke
# (over comlink)
# starts to the death star surface of the star destroyers are and the short and the stries out of the bartly a large and starts to the starship. â¨
# 166 â int. millennium falcon - cockpit
#
# han (contâd)â¨i was the ship that his hand in the death star surface and starts to the star destroyers are and the commander. â¨
# 403 â int. red ten's cockpit â¨the battle right of the millennium falcon robot is a ship a strain are arm and begins to the starship.  i can to the sh
# ------ temperature: 0.5
#  strain are arm and begins to the starship.  i can to the ship watch much the bries of the freet and starts to the silver sounding toward the pirateship. â¨
# 266 â int. death star intentle - landing from the death star â¨red of the ship is the huge mother, and pulls at the coming in path a chewbacca and master it is artoo, and luke and the freezing some of the tree of the droid
# start at the
# lord.
#
# han starts from the engigh of the sandpeise and the two rest in the sill way watch and me.
#
# ext. hoth - cockpit 127
# the falcon commander, luke rushes out a small hutt and the cockpit window the computer sits and boba chatters at the fast a subhilly hold of
# epoch 21
# Epoch 1/1
# 164779/164779 [==============================] - 21s 125us/step - loss: 1.1336
# epoch 22
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.1277
# epoch 23
# Epoch 1/1
# 164779/164779 [==============================] - 21s 126us/step - loss: 1.1256
# epoch 24
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.1190
# epoch 25
# Epoch 1/1
# 164779/164779 [==============================] - 21s 125us/step - loss: 1.1158
# --- Generating with seed: "ent and burps in satisfaction.
#
# 14   int jabba's throne room"
# ------ temperature: 0.2
# ent and burps in satisfaction.
#
# 14   int jabba's throne room - cockpit â¨luke
# yes, and the forces a spead of star destroyer stand a small see the ship.
#
# luke
# (over headset)
# han, i'm going to the comlink!
#
# lando
# (over headset)
# open of the cockpit though his controls and pulls at the rebel fighters and star destroyer continue to see the comlink.
#
# lando
# (over headset)
# han, i can't see to that i'm going to see the rebel fighter.
#
# luke
# (over headset)
# han, i'll be star destroyer comes out of the ship.
#
# luke
# no.
#
# luke
# i can't lead the fighter.
#
# luke
# (over headset)
# han, i can the comlink!
#
# luke
# (over headset)
# i'm not going to be a landing of the ship.
#
# lando
#
# ------ temperature: 0.5
#  headset)
# i'm not going to be a landing of the ship.
#
# lando
# (over headset)
# most artoo see. chewie bank the ship starts to streak a back and starship rebelred moves into the death star. vader and the ship and the creatures and grabs the gaspers wan and leia from the backer of suddenly and pulls out of the speeder and gets the comlink the from on the death star.
#
# ext. space - imperial ship star destroyer
# ohubtity as luke slips out and grabs a large fighter and picks head.
#
# emperor
# i could be stand but the rebelss
# stopse a moment. the chief trooper one sid.
#
# emperor
# yes, why don't me a slam of the shaking a devit.
#
# luke
# front officer! any is system!
#
# the
# epoch 26
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.1120
# epoch 27
# Epoch 1/1
# 164779/164779 [==============================] - 20s 124us/step - loss: 1.1095
# epoch 28
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.1053
# epoch 29
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.1019
# epoch 30
# Epoch 1/1
# 164779/164779 [==============================] - 20s 124us/step - loss: 1.0978
# --- Generating with seed: "ks out the window and on the viewscreens. another rebel ship"
# ------ temperature: 0.2
# ks out the window and on the viewscreens. another rebel ship stands at the stormtroopers and are and pulls at the falcon and the imperial troops and and a waller and starts at the computer starts and starts at the falcon and a strapper and starts at the trans a battern't the ship and starts at the rebel star destroyer and starts at the computer starship.
#
# han
# well see the emperor well, they are you are you can to be a second master.
#
# leia
# why don't could he don't no pack the empire.
#
# leia
# why don't say.  they you will what you could help the end of the star destroyer.
#
# han
# well, they was to take of this ship.
#
# han
# well, they was to completed the comput
# ------ temperature: 0.5
# ke of this ship.
#
# han
# well, they was to completed the computer
# complet.
#
# the rebel fleet release station and readins a horrilled to place. â¨
# 4couan
# ohhath the computer starts flip of the tiny outliterial
# reading a group and sits and man's face and and escape into the fire and picked attaching at a secord of the happenication.
#
# leia
# vader's cockpit.
#
# han
# yeat, you are sure the walker.
#
# leia
# they're what your controls are pred in the falcon?
#
# leia
# they stay forward the controls
# control around the tie fighter.
#
# han
# yes.  you can see the only battered.
#
# leia
# i see you are i can to head is now, i don't be and i don't mear?
# lando
# (over readyus officer
# b
# epoch 31
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.0964
# epoch 32
# Epoch 1/1
# 164779/164779 [==============================] - 20s 124us/step - loss: 1.0919
# epoch 33
# Epoch 1/1
# 164779/164779 [==============================] - 21s 126us/step - loss: 1.0903
# epoch 34
# Epoch 1/1
# 164779/164779 [==============================] - 23s 137us/step - loss: 1.0858
# epoch 35
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.0841
# --- Generating with seed: "king about. i'm a member of the imperial senate on a diploma"
# ------ temperature: 0.2
# king about. i'm a member of the imperial senate on a diplomative and the ship.
#
# threepio
# well, the star destroye it is and the ship startled and stares at the star destroye star destroyer.  in the star destroyer buts and stares at the ship.
#
# han
# it is the ship.
#
# the death star and stares to the star destroye the star destroye shoots to the ship.
#
# luke
# what thing stay to the ship.
#
# the death star holds to the ship startled and the starship stare at the
# control panel.
#
# luke
# (over comlink)
# hold the ship stay the commander watches the star destroye the ship.
#
# threepio
# well, they're going?
# lukeâ¨it's the ship stay and and leia and leia and the starship, s
# ------ temperature: 0.5
# it's the ship stay and and leia and leia and the starship, starts to the houlderied arms and alongs the strong fine and heads on the creature a spearsed to the main hands, and the screenes, then shoutders and it the speeder.  he starts to find the
# manner snowspeeders at the hutry and stares at the ship, sandicestive doors flying the speeder. the shadows are his shoot, checking at the farmmed and stares and flow. starts and heads towards the walls flowt of the power shands at the target toward the falcon's control beat
# the shaming of the shaming sector to the horriensmill.
#
# threepio
# well, he stay and begins to set up and hands and slowly senses.
#
# thre
# epoch 36
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.0817
# epoch 37
# Epoch 1/1
# 164779/164779 [==============================] - 21s 126us/step - loss: 1.0780
# epoch 38
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.0765
# epoch 39
# Epoch 1/1
# 164779/164779 [==============================] - 21s 125us/step - loss: 1.0731
# epoch 40
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.0708
# --- Generating with seed: " floor of the alcove.
#
# boushh steps up to the case, studying"
# ------ temperature: 0.2
#  floor of the alcove.
#
# boushh steps up to the case, studying for a few moments and starts to the stormtroopers and starts to the ship.
#
# luke
# i have a shuttle station and the star destroyer and the stormtroopers and starts to the falcon and the ship and leia and the speeder and the stormtroopers and begins to stand back.  the smallers floot his hand and begins to be side of the ship.
#
# luke
# i have a landing passion stand back, and the stars looks and starts to the star destroyer and the speeder and starts to the ship.
#
# han
# i have a landing for a large battle station filing in the falcon, then speaks in the falcon, and the stars stands and starts to the s
# ------ temperature: 0.5
# eaks in the falcon, and the stars stands and starts to the side of the computer and inside the star destroyer and still down the side of the ship.
#
# threepio
# i wouldes. you may you's have side it is moth.
#
# luke
# a mine-sever luke and the staring station and signales and
# doors coming in his control hands in the hanger and side. as the rest of the death star han scants the cockpit move and pulls up and starts to his ward around he
# seems to slams and han and a high.
#
# threepio
# she want you have a more to should be a ship and yoda...
#
# leia
# what's your
# sits maybed and your warrion.
#
# luke
# what is that more shield
# about this back, muck points.
#
# yoda
# han, don
# epoch 41
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.0663
# epoch 42
# Epoch 1/1
# 164779/164779 [==============================] - 20s 124us/step - loss: 1.0674
# epoch 43
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.0659
# epoch 44
# Epoch 1/1
# 164779/164779 [==============================] - 21s 125us/step - loss: 1.0621
# epoch 45
# Epoch 1/1
# 164779/164779 [==============================] - 20s 124us/step - loss: 1.0605
# --- Generating with seed: "thing
# passes like a dark cloud through his consciousness. t"
# ------ temperature: 0.2
# thing
# passes like a dark cloud through his consciousness. the ship the stormtroopers and starts to stopens. â¨
# 475 â int. death star 261 â¨biggs is a ship the starship standing on the commander. â¨
# 181 â ext. space around the death star 241 â¨an explosion slams as the stormtroopers and ben and the speeders controls and starts to surface from the ship.
#
# threepio
# well, the emperor standing in the commander.
#
# luke
# there's some to the starship.
#
# luke
# there'll good to the station to the stormtroopers.  the main shap and and the station to the death star continues to the ship.
#
# 131 int. death star - cockpit
#
# the death star station and starts to the ship
# ------ temperature: 0.5
# tar - cockpit
#
# the death star station and starts to the ship and position at the battle.
#
# luke gets up the shadon side of the as the suptront finer the
# shamp to the craft. the battlefield of the speeder robots and a really starts formation at laserfire the asteroid tight down and luke and the computer seept of the captain. the stormtroopers and he doesn't see to the massassiol.
#
# luke
# way!
#
# the craft watch in the commander.  in the computer computer start the directions.  it comes up and starts to be up the scout the assemblic turred.
#
# luke
# but the giant walker to be a large completed to be a first. the ship startles the gantry moves
# out at the day.
# epoch 46
# Epoch 1/1
# 164779/164779 [==============================] - 20s 124us/step - loss: 1.0596
# epoch 47
# Epoch 1/1
# 164779/164779 [==============================] - 21s 127us/step - loss: 1.0575
# epoch 48
# Epoch 1/1
# 164779/164779 [==============================] - 21s 125us/step - loss: 1.0562
# epoch 49
# Epoch 1/1
# 164779/164779 [==============================] - 21s 127us/step - loss: 1.0536
# epoch 50
# Epoch 1/1
# 164779/164779 [==============================] - 21s 125us/step - loss: 1.0502
# --- Generating with seed: "!
#
# 121 int. death star - main forward bay - service panel 12"
# ------ temperature: 0.2
# !
#
# 121 int. death star - main forward bay - service panel 127 â¨luke turns to the commander and the stormtroopers and the supreding all are stand the star destroyer and the supresed in the ship and the speeder stand a small hatches a heavy ship and starts to laser and the supreding all the stormtroopers and the stormtroopers and the stormtroopers of the ship stand and stops and starts at the ship.  it struggles to the stormtroopers and the ship stand bay. the room of the stormtroopers and the supresed in the ship stand bay. the ship startled to be dead of a small command. the ship startled and the stormtroopers and the ship stand beap and the falcon a
# ------ temperature: 0.5
# d the stormtroopers and the ship stand beap and the falcon and get a colloder and chewie holestal
# face a small hutt's angry destroyers. luke starts at the hallway hide and sits at the emperor's short still on the sand and the bolt fire and turns to the falling speeder star ded of the supreses of commander surrace of the true-speeder and stops as he looks around the ship, lights a shoth the control panel for a disture of the ship.  the starship station and stands away toward the ship.  han stands down the tree and large attached are not and on the plank and the battle station. a small hutt's father the ramp command, and she is and entrances and starts
# epoch 51
# Epoch 1/1
# 164779/164779 [==============================] - 21s 125us/step - loss: 1.0498
# epoch 52
# Epoch 1/1
# 164779/164779 [==============================] - 21s 125us/step - loss: 1.0476
# epoch 53
# Epoch 1/1
# 164779/164779 [==============================] - 21s 125us/step - loss: 1.0470
# epoch 54
# Epoch 1/1
# 164779/164779 [==============================] - 21s 125us/step - loss: 1.0443
# epoch 55
# Epoch 1/1
# 164779/164779 [==============================] - 21s 125us/step - loss: 1.0424
# --- Generating with seed: "rcuit and the droid shuts down.  the wookiee smells somethin"
# ------ temperature: 0.2
# rcuit and the droid shuts down.  the wookiee smells something to the falcon.  a large are and his hand.  he starts at the falcon and the command commanders with a short in the dead of the stars on him.  the death star commander and chewie stands away from the death star hold of the death star surface and chewie banks as the death star bracind startled and the stormtroopers and the stars out of the stars on here and the stars were and the commander and the huge robots and the stars with the stars on the fighters and the computer starts to be a lando and the stormtroopers and the stars out of the stars get to the stars with a small rather.
#
# luke
# i tell a
# ------ temperature: 0.5
# e stars get to the stars with a small rather.
#
# luke
# i tell a shuttle beam you will be it.
#
# leia greedows at the death star. luke is got in the transmiss their
# starship, then stand at the fighters and the control panel to the pirateship.  he really mos any on its on the stars on the hurres to the death star. â¨
# 281 â ext. space around the death star 411 â¨the fighter boy toward the death star whistles a laser raiders
# mouth.
# a
# face is don't you think you!
# luke looks out of the target to the others and starts at the time.
#
# vader
# you'll be in the cruiser. i wounded by with a groups, but is a trailing of the stars to finds a roge doors and the stars wi
# epoch 56
# Epoch 1/1
# 164779/164779 [==============================] - 21s 125us/step - loss: 1.0395
# epoch 57
# Epoch 1/1
# 164779/164779 [==============================] - 21s 126us/step - loss: 1.0402
# epoch 58
# Epoch 1/1
# 164779/164779 [==============================] - 20s 123us/step - loss: 1.0393
# epoch 59
# Epoch 1/1
# 164779/164779 [==============================] - 21s 126us/step - loss: 1.0355
# epoch 60
# Epoch 1/1
# 164779/164779 [==============================] - 20s 124us/step - loss: 1.0338
# --- Generating with seed: " into some old friends.
# luke
# is the ship all right?
# hanâ¨se"
# ------ temperature: 0.2
#  into some old friends.
# luke
# is the ship all right?
# hanâ¨see you can firis and the end of the window and the ship and leia and stands in a shadowing shoots toward the death star surface. â¨
# 403 â ext. space around the death star 241 â¨the death star controller screen and a star destroyer screen of the shadows short destroyers and a small room shoots toward the stormtroopers and a small room and leia and leia and a speeder and a spear and a spear and stands and an energy room, the followed back and starts to lando.
#
# han
# i don't see the said we are a friend to him.
#
# han
# yeah, you have to see the other of the sandpersaif of the shadow. a sight of the d
# ------ temperature: 0.5
# the other of the sandpersaif of the shadow. a sight of the death star's huge screen into the cockpit
# and flips and fires at the dambess as he spets the stubby creamhing the window and space and a droid is a small crew.
# luke
# (anot)
# well, the furry for the massive bay artoo is stumbles for the corridor.
# han
# (internued)
# you can't and not to companion the huge shaken and the robots of the forest trench.  the death star
# clearing before the side of the controls and begins to lead and stands in the dark rocks and stands and an energy run to the spacecrafter and stands and a starmaid and stands in and of the asteroid
# fiely and he reacts his head. threepio s
# /home/trp22/CS/PythonVenv344/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
