# %% [markdown]
# ## Preparing Data

# %%
import keras
import numpy as np

#path = keras.utils.get_file(
#    'nietzsche.txt',
#    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
#text = open(path).read().lower()
text = open("/home/trp22/Star_Wars_A_New_Hope.txt").read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 199170

# %%
#print(text)

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 66370
# Unique characters: 55
# Vectorization...

# %% [markdown]
# ## Building the network

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the model

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 20):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 66370/66370 [==============================] - 15s 221us/step - loss: 2.2681
# --- Generating with seed: " the assembled troops,
# who all bow before them. chewbacca gr"
# ------ temperature: 0.2
#  the assembled troops,
# who all bow before them. chewbacca ground the reath star a down the round the ewall the roon the reath star of the reath star a mast the reath star a dento as the round the roun the round the doon the round the round the ring the round the round the round the reath star and the reath star and the reath star and the reath star a down the round the red the rook and the reath star a down the reath star the roun the roun the round the ro
# ------ temperature: 0.5
# tar a down the reath star the roun the roun the round the rount the reath ben
# looks ay whar
#
# 133
#
#
# luke ald the eware a poof the ouk of the roun this hin the around whit the engeren
# fighter fighter the regotion the lold nit in the bice boom his sto more a of the for the doon the rounle the compit
#
# the luke
#
# throopio stoom fighter fighter tho mollong)
# looker a dante the pure th stoll for the contoon to all to him hand ben
#
# 222
#
# throopion for
# the rest a deat
# ------ temperature: 1.0
# n to all to him hand ben
#
# 222
#
# throopion for
# the rest a death vadorsle morlo
# tater fitho you'rus - save you hire inta stack you walleroply streacconing pyoh
# a con mot comwing folle ovea loath mugh awho.
# intlooling and semm the
# sipuntior one the poorst burt non doop)
# ass red hi de tooing wath
# thin
# dew
# it pounleded smrout of thi to i8 to a fock as
# the death tur mine
# chas gorts kulveutht ofornou's un chainsemovios
# voote the gockning fitht a ros ane the operof
# ------ temperature: 1.2
#  chainsemovios
# voote the gockning fitht a ros ane the operof the lulr of s2luse, atto. farey huve atand
# talker
# you'd
# )
# beon ning tanodo there luees alnaking
# the hibennatoun fichly
# b rece thoterly,
# ohe deatush trouk on trens co. surcapnin ive to vook
# a ot ofe
# chanting hturim is lutts th tweiniand to
# if he, hand in that hin imbo(thelly
# thron muld mond frocket then be nemading
# throopi- as in ti finos frockp
# segue
# leudaraas. thous dove.
# 7llik foving to gugey,
# epoch 2
# Epoch 1/1
# 66370/66370 [==============================] - 15s 221us/step - loss: 1.7167
# --- Generating with seed: "works its way up from the
# murky depths. chewbacca lets out a"
# ------ temperature: 0.2
# works its way up from the
# murky depths. chewbacca lets out a side is a startion a start of the surface are a start a start of the power a start of the compice to this the point this a side a start a starting the side is a will the litt of the starting a start of the direst and the side the start a start a start of the signt to the to a sen a start of the side a start and the start a starting the starting the starting the starting the starting the direst a
# ------ temperature: 0.5
# tarting the starting the starting the starting the direst a power a stacting in the sake a side the leader to this is will to altoo a get and thin surface and stortation a compice to the rem the sirnot bown of the staker)
# luke
# is this spice will mot the see the piroted a power a vinot a siding a control a comting biggs around a starts a compited
# a death the sands and in a him sight. he going this to a sign as a mome it is look one the compiring this screen
# ------ temperature: 1.0
# to a sign as a mome it is look one the compiring this screenn you) in you hang us3ffers a going anding this prianute waldy a your farts are a pas a ructorionot. of the gelfcemtroopers
# takennaull his comnar(is luke's with i mase. of a dedlenian this tiking rounctge wi hes attor and leiacreds an
# imperial i feel. i sand fof the
# pastestaze bowes.
# luke
# (sount, three is hist.
# 12j
# sed a deation wiig stort)
# ba
# co wall to threepio is down this his heround to the hu
# ------ temperature: 1.2
# t)
# ba
# co wall to threepio is down this his heround to the huser oths ay
# tormate - handly and brow sir vader yoorring to chewie crisds roun
# to kineen abele's aly awas. chad turrstare ppeeeking nefs. they. un iveopsi.
# luke
# (ect thie'd pording.. by dinngted encl. he'nd.. wiccan tomt.
# arcoo that and you, itpedls and eif, han, look a bawer8? yais, whive makep, with leia a sena
# dow - comoto
# doomindeve going borvareshis ben. hrourtpiper.
# 358
#
# star wars: a seatia
# epoch 3
# Epoch 1/1
# 66370/66370 [==============================] - 15s 229us/step - loss: 1.5356
# --- Generating with seed: "rvey the situation, checking all of the
# alarms, laser gates,"
# ------ temperature: 0.2
# rvey the situation, checking all of the
# alarms, laser gates, the back and the robots are the bast fire in the smoke to the surface to the surface to the bear their surface to the shope.
# luke
# threepio
# threepio
#
# 23
#
# star wars: a new hope
#
# 266
#
# ext. space
#
# 266
#
# threepio
#
# 235
#
# ext. space
#
# 232
#
# luke
# sho'dd the surface to the control sound the the shope.
# 25
#
# int. death star - contine - surface - surfall - doron a death star surface to the ship shoudd the bear a
# ------ temperature: 0.5
# l - doron a death star surface to the ship shoudd the bear and the roboth. leia
# hold there! i tower shout heads.
# 26
#
# ext. space
#
# 265
#
# luke
# looks are but he row and luke well beard
# threepio
# threepio
# threepio
# they fighters the troopers side blast his heads from
# the have the bast fire whis halls surface worrs in the toward looking and the princess threepio but you. leia sound screen a las a stormtroopers the starstoo show.
# luke
# they turns compiting bust they
# ------ temperature: 1.0
# pers the starstoo show.
# luke
# they turns compiting bust they grow surea(s. the. threepio.
#
# 92
#
# star wars: a death staro- seepers
# crikbal craic
# ono3' loust plene
# luke sho'dddd.
# hore in cles like
# are biey that gole plares but i you way toward you. can whicks fured prus ining you runled and aftis rossbiggs
# buck and their moy with a biggs. i've
# shove, leards just tliststecles move the planes
# ten.
# sho'ls a deard
# s, ship buts rurbed i'r
# bride?
# . contwols acrows
# ------ temperature: 1.2
# ls a deard
# s, ship buts rurbed i'r
# bride?
# . contwols acrows there think? held
# shiaclly malds about offfriggr, wheess blickrain
# their
# laugh. lowat hal theat mass into
# mokn. you his dive. glanin lvader
# hild
# groins shiplly, okey.
# actore will itctisily cloon lot benoc his cround
# lears
# anc as dende in flein s. he blase
# trcemares arimase - owhre.
# threepio
# shies...
# laserpowation.
# dooked surface would panstond?
# 234
#
# int. massas han got afcercad and leilooke
# ous a
# epoch 4
# Epoch 1/1
# 66370/66370 [==============================] - 15s 225us/step - loss: 1.4294
# --- Generating with seed: "low the main port. the shaft leads
# directly to the reactor s"
# ------ temperature: 0.2
# low the main port. the shaft leads
# directly to the reactor starts a stars in the ship threepio and the troopers a stare a trooper
