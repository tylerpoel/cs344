# %% [markdown]
# ## Preparing Data

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 1us/step
# Corpus length: 600893

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# ## Building the network

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the model

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 2):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 303s 2ms/step - loss: 1.9584
# --- Generating with seed: "into our self satisfaction: one of them being the pleasure o"
# ------ temperature: 0.2
# into our self satisfaction: one of them being the pleasure of the stand and and the readoration of the fare of the stander and the present and the sention of the still and the stand and and the stand and the and the man and the and the reason and the stand and and that has the stand and that in the have has the soul and the stand and and the ence and thing and man which has and the stand that in the stand and thing and thing and and something and the was t
# ------ temperature: 0.5
# he stand and thing and thing and and something and the was that has in the speat, sonething and general actually our would to man that is thing in the man and thing and man may man and there all the heart whone and that and a still destruct and the canture in the scient and the spirit of a willons and view of the will the and such and with the betore and that a thing and thing to the that men of a contained and man which has in the
# more of a that the and a
# ------ temperature: 1.0
#  contained and man which has in the
# more of a that the and an gove and spienting can dotring who name themament which othood of chanus arason he
# bad alsubfurem; onestying things divilated within and recrar: propardament, who. alw,
#  fupulific proso a chnen, and sel
# maken in e patalizion of natures vooule and operstuping, and
# wor4d" mean.
#
#  2 heis otherwally. fare the habtly alpo river and when onater account" and fance to still beatnred as its .ta very is t
# ------ temperature: 1.2
# er account" and fance to still beatnred as its .ta very is the doiled, monates--nawed
# arry, much but spasdang, he mulk and to thinkefine? aw in
# as these sympathymet that poonest convicti; ak?
#
# 15., i nemalise, servas op flions my which is camble,
# intoul sungect why xust ontsterneve incredictory then conndice ind7esssibless
# to
# 'seprety choos. and mychxcouen dek and forde alone a de"knowic
# to day difficut and are digit raub risty batherions or magal
# 5asssicl
