# %% [markdown]
# ## Preparing Data

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# Corpus length: 600901

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200281
# Unique characters: 59
# Vectorization...

# %% [markdown]
# ## Building the network

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the model

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 4):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200281/200281 [==============================] - 48s 239us/step - loss: 1.9789
# --- Generating with seed: " europeans
# according to my taste, the hohenstaufen, frederic"
# ------ temperature: 0.2
#  europeans
# according to my taste, the hohenstaufen, frederic to the spirit of the readonal to the spirit and with the readical and perhaps and the seess of the probles of the readonation, in the the most conseques and the such a soul the spirit of the community, the read the readical is a some and with the reads of the self the communical to be the read and and and and the commune the compares, and with the commanical is the servation of the sermones and t
# ------ temperature: 0.5
# d with the commanical is the servation of the sermones and the whole bet out of the reads, in the more false of the reads of the badish of the most very only with the course of the were redance to the spirit the deed course of the fast in the filurd as of will the nature. in the last pasion, the compuctally in the his some and by an as a notical and the feces of the some for the exprasions of the asser the consural in the experious and longer the more and
# ------ temperature: 1.0
# asser the consural in the experious and longer the more and that life-man
# will
# of
# and "worthty enow beer, is which he excepint, it is getion, ow makes kinds, bevent linhsa; what og them a in stepest payic, lije kindslagfly the liftuang voluately and
# a godate in exhans, with inso their fores does, as an awtion--is other thisture woll all with of unnicts his spiriting on,
# sxpredically his this with respaises. for light, perhaps
# of comeuaraly as any you obfai
# ------ temperature: 1.2
# respaises. for light, perhaps
# of comeuaraly as any you obfaise here
# offics to longing, who foun
# will huctous ther with uptioo wqo eipasting is dul grow dub"thrope;.
#
#
# btt nef
# us, to sive     means caarayius, hale, we hper differents is net,
# in the  s
# voralicates, banies---etever among his evolnes of the toalws, whiracg, inspemine boungts, memorted and "surring
# bebare2, has also :
# the grandd, marate inbenigal, with
# exy, and creer with commpalher) lefor lo
# w
# epoch 2
# Epoch 1/1
# 200281/200281 [==============================] - 48s 242us/step - loss: 1.6187
# --- Generating with seed: "he
# highest honours to "disinterested knowledge" the objectiv"
# ------ temperature: 0.2
# he
# highest honours to "disinterested knowledge" the objective of the spirit of the decisting to the general and stands of the spirits of the spirits of the spirits of the seems of the spirit of the interpossible, the spirit of the discontent and spirit of the content of the present and spirits of the any and spirits of the spirits of the believed to the morality of the disconeration of the content to the contemptance of the content of the continued and spi
# ------ temperature: 0.5
#  to the contemptance of the content of the continued and spirits of the amserate the german course in demain of the profigute, and oper--the self-so noble them is the ordinary who there is in the trady and all the disconeration of the seems of such a be inspired history and all the a more of the continuined to the greeks of the excepted for the art for a morality in the among to his he have a mind for the present to the self acts of thes in the reasonal an
# ------ temperature: 1.0
#  for the present to the self acts of thes in the reasonal and so
# not ansories whats dyess, develops of eken be in the carrational, deeps and nongop
# and certain limord, but to wholing." the evolunter lgs.
# gones
# of hard
# dreasalces" for line of one is under spose it aragines, and frest systameant longitie:
#
# xweriends for feerfuls, by human conscience?"
# unoper what
#              ut sely to on fastence; theredain att at altoured ideling the eritalex its avant of
# ------ temperature: 1.2
#  theredain att at altoured ideling the eritalex its avant of which have gendeanes nal" behner--nagia count
# theie. whe under wond kine the rong--the once ivesafual provence; it mora
# bitker tyle, they hease for inflience, possiblementalivesshies--so, sympit in invine by one anothers" themseby chormin whichs), an ess." in gude sc(plue how the every ond
# pinuon of dingers posishonmensty,
# groem, e,
# seemed afor,
# citw
# owing to rive" and lesucte", the real madness
# epoch 3
# Epoch 1/1
# 200281/200281 [==============================] - 48s 242us/step - loss: 1.5292
# --- Generating with seed: "ing of europe, which has been on
# the increase for a century "
# ------ temperature: 0.2
# ing of europe, which has been on
# the increase for a century of the secret for the self-self-and the self-self-such a destrust and self-self-self-such a man and the seems to the seems to the same the preciated to the sense of the seems to the self-such a more that the self-secrot and the seems to the worl who any and the seems to the seems to the sees of the world and destrust and the seems to the seems to the most conscious and the self-secrotated of the s
# ------ temperature: 0.5
# seems to the most conscious and the self-secrotated of the sour precially secret the reason the same ourselves is the person of much man is the social for the regarded to the longing and word is desires and the developer in the ready times and something something of the part of the destrust of the spirit on the domant be consciously, is also its see that he his to the whole this former that the to a men, and the order of though the things conception of the
# ------ temperature: 1.0
#  a men, and the order of though the things conception of the predies disent: was
# course of a new account of the evil-eviled"
# mole of
# things, the question
# todage it make mposty is never the scholated
# things of anotion more old to the fress. in all greattes and inam his new man i forgetion: pro-clear coman sympathy as earth, where souratore, the thpestives hands of wasily, and who
# the friende falsh its-deblests of his science and fell--recurn one eviration m
# ------ temperature: 1.2
# its-deblests of his science and fell--recurn one eviration myself now thing
# of the morack in
# sagnes, things: deleg's
# nothing goodrathed in thith-fal
# decemin
# manm., trourfulday  y firded;
# no never to subject on
# insporchipjrvous" capaccion gemunations." with his oqduniadical symitaty are other to seem cofedvese of legins.ly very human ecenous and towagdinious lookp(unfaked man now called if and "e
# virtude. trot!, in
# misinfer of thing
# looknt is
# uncostilism i
