# %% [markdown]
# ## Preparing Data

# %%
import keras
import numpy as np

#path = keras.utils.get_file(
#    'nietzsche.txt',
#    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
#text = open(path).read().lower()
text = open("/home/trp22/CS/344/cs344/Project/HeartOfDarkness.txt").read().lower()
print('Corpus length:', len(text))
# Out:
# Using TensorFlow backend.
# Corpus length: 211315

# %%
#print(text)

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 70419
# Unique characters: 49
# Vectorization...

# %% [markdown]
# ## Building the network

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the model

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

#for epoch in range(1, 61):
    #print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
model.fit(x, y,
          batch_size=128,
          epochs=60)

    #if epoch % 5 == 0:
        # Select a text seed at random
start_index = random.randint(0, len(text) - maxlen - 1)
generated_text = text[start_index: start_index + maxlen]
print('--- Generating with seed: "' + generated_text + '"')

for temperature in [0.2, 0.5]:
    print('------ temperature:', temperature)
    sys.stdout.write(generated_text)

    # We generate 400 characters
    for i in range(600):
        sampled = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(generated_text):
            sampled[0, t, char_indices[char]] = 1.

        preds = model.predict(sampled, verbose=0)[0]
        next_index = sample(preds, temperature)
        next_char = chars[next_index]

        generated_text += next_char
        generated_text = generated_text[1:]

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# Epoch 1/60
# 70419/70419 [==============================] - 16s 225us/step - loss: 2.1799
# Epoch 2/60
# 70419/70419 [==============================] - 15s 217us/step - loss: 1.7708
# Epoch 3/60
# 70419/70419 [==============================] - 15s 217us/step - loss: 1.6296
# Epoch 4/60
# 70419/70419 [==============================] - 15s 217us/step - loss: 1.5320
# Epoch 5/60
# 70419/70419 [==============================] - 15s 218us/step - loss: 1.4651
# Epoch 6/60
# 70419/70419 [==============================] - 16s 227us/step - loss: 1.4135
# Epoch 7/60
# 70419/70419 [==============================] - 16s 225us/step - loss: 1.3737
# Epoch 8/60
# 70419/70419 [==============================] - 17s 240us/step - loss: 1.3420
# Epoch 9/60
# 70419/70419 [==============================] - 16s 225us/step - loss: 1.3161
# Epoch 10/60
# 70419/70419 [==============================] - 16s 221us/step - loss: 1.2941
# Epoch 11/60
# 70419/70419 [==============================] - 15s 219us/step - loss: 1.2738
# Epoch 12/60
# 70419/70419 [==============================] - 16s 223us/step - loss: 1.2608
# Epoch 13/60
# 70419/70419 [==============================] - 15s 220us/step - loss: 1.2459
# Epoch 14/60
# 70419/70419 [==============================] - 16s 220us/step - loss: 1.2343
# Epoch 15/60
# 70419/70419 [==============================] - 16s 224us/step - loss: 1.2240
# Epoch 16/60
# 70419/70419 [==============================] - 16s 222us/step - loss: 1.2112
# Epoch 17/60
# 70419/70419 [==============================] - 16s 223us/step - loss: 1.2030
# Epoch 18/60
# 70419/70419 [==============================] - 16s 222us/step - loss: 1.1937
# Epoch 19/60
# 70419/70419 [==============================] - 16s 223us/step - loss: 1.1861
# Epoch 20/60
# 70419/70419 [==============================] - 16s 225us/step - loss: 1.1769
# Epoch 21/60
# 70419/70419 [==============================] - 16s 224us/step - loss: 1.1669
# Epoch 22/60
# 70419/70419 [==============================] - 16s 224us/step - loss: 1.1629
# Epoch 23/60
# 70419/70419 [==============================] - 16s 225us/step - loss: 1.1546
# Epoch 24/60
# 70419/70419 [==============================] - 16s 225us/step - loss: 1.1473
# Epoch 25/60
# 70419/70419 [==============================] - 16s 224us/step - loss: 1.1392
# Epoch 26/60
# 70419/70419 [==============================] - 16s 226us/step - loss: 1.1323
# Epoch 27/60
# 70419/70419 [==============================] - 16s 225us/step - loss: 1.1248
# Epoch 28/60
# 70419/70419 [==============================] - 16s 228us/step - loss: 1.1207
# Epoch 29/60
# 70419/70419 [==============================] - 16s 227us/step - loss: 1.1152
# Epoch 30/60
# 70419/70419 [==============================] - 16s 225us/step - loss: 1.1100
# Epoch 31/60
# 70419/70419 [==============================] - 16s 229us/step - loss: 1.1014
# Epoch 32/60
# 70419/70419 [==============================] - 16s 227us/step - loss: 1.0972
# Epoch 33/60
# 70419/70419 [==============================] - 16s 228us/step - loss: 1.0955
# Epoch 34/60
# 70419/70419 [==============================] - 16s 229us/step - loss: 1.0896
# Epoch 35/60
# 70419/70419 [==============================] - 16s 228us/step - loss: 1.0820
# Epoch 36/60
# 70419/70419 [==============================] - 16s 226us/step - loss: 1.0772
# Epoch 37/60
# 70419/70419 [==============================] - 16s 227us/step - loss: 1.0730
# Epoch 38/60
# 70419/70419 [==============================] - 16s 228us/step - loss: 1.0710
# Epoch 39/60
# 70419/70419 [==============================] - 16s 227us/step - loss: 1.0608
# Epoch 40/60
# 70419/70419 [==============================] - 16s 227us/step - loss: 1.0602
# Epoch 41/60
# 70419/70419 [==============================] - 16s 227us/step - loss: 1.0561
# Epoch 42/60
# 70419/70419 [==============================] - 16s 226us/step - loss: 1.0546
# Epoch 43/60
# 70419/70419 [==============================] - 16s 227us/step - loss: 1.0490
# Epoch 44/60
# 70419/70419 [==============================] - 16s 227us/step - loss: 1.0398
# Epoch 45/60
# 70419/70419 [==============================] - 16s 226us/step - loss: 1.0373
# Epoch 46/60
# 70419/70419 [==============================] - 16s 227us/step - loss: 1.0401
# Epoch 47/60
# 70419/70419 [==============================] - 16s 227us/step - loss: 1.0332
# Epoch 48/60
# 70419/70419 [==============================] - 16s 226us/step - loss: 1.0323
# Epoch 49/60
# 70419/70419 [==============================] - 16s 227us/step - loss: 1.0289
# Epoch 50/60
# 70419/70419 [==============================] - 16s 229us/step - loss: 1.0208
# Epoch 51/60
# 70419/70419 [==============================] - 16s 227us/step - loss: 1.0234
# Epoch 52/60
# 70419/70419 [==============================] - 16s 225us/step - loss: 1.0193
# Epoch 53/60
# 70419/70419 [==============================] - 16s 229us/step - loss: 1.0080
# Epoch 54/60
# 70419/70419 [==============================] - 16s 228us/step - loss: 1.0026
# Epoch 55/60
# 70419/70419 [==============================] - 16s 228us/step - loss: 1.0054
# Epoch 56/60
# 70419/70419 [==============================] - 16s 228us/step - loss: 0.9980
# Epoch 57/60
# 70419/70419 [==============================] - 16s 229us/step - loss: 0.9931
# Epoch 58/60
# 70419/70419 [==============================] - 16s 228us/step - loss: 0.9910
# Epoch 59/60
# 70419/70419 [==============================] - 16s 228us/step - loss: 0.9902
# Epoch 60/60
# 70419/70419 [==============================] - 16s 228us/step - loss: 0.9834
# --- Generating with seed: "e fringed cloths, with fierce nostrils and his hair all done"
# ------ temperature: 0.2
# e fringed cloths, with fierce nostrils and his hair all done. i was not in the station. it laved. 'i have a man. he was done that the steamboat the bring being had to try. 'he i said. 'i am, the manager was a first of the word of the forest of the still who shores the woods a bank of the before i saw the forest of the word of the river, the still and stare, as the forest of the forest of the steamboat the contract and some strengthing that much as the forest of the word of the bring being forishes, and the still of the word of the strang out of the forest of a pingsily of the steamboat murmur, with a station. i stared the steamboat the coast. the prosi
# ------ temperature: 0.5
#  with a station. i stared the steamboat the coast. the prosiding in the man fortation, a trange for shoudd thing the slimingly 'it made as the little more in a man was a contice of the bank being for spectacied from the glassing of the very carracies, as i am a woman man. i ventation at the devil of an at the forest of treash, with the passion, the tries of the way of a voice in an altogether forest even began to tryâthe piercious of an any into a wind of this play, the doorsed the stream. she with a kind, to the river, the memory of the forest shut was to me overhhaged himself, concerious and givently the still which whether the possible. you want n
