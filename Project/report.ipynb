# %% [markdown]
# # Final Report
#
# This is the final report for my project in CS344 at Calvin University.
#
# Student: Tyler Poel
#
# Date: May 20, 2020

# %% [markdown]
# ## Vision
#
# In this project I will be exploring text generation using
# neural networks, specifically a LSTM. I will feed the
# network in a large text file, and based off of how
# I train it I'm interested in what type of text generation
# I'll receive.
#
# Specifically I'll be feeding the neural network the script for
# the Star Wars Original Trilogy (A New Hope (1977), The Empire Strikes Back (1980), and
# Return of the Jedi (1983)). I'm interested in the type of script
# the neural network will give me as output. The first question
# is simply will any of the generated text make logical sense? Secondly,
# will the generated text resemble a movie script?
#
# In the interest of comparison, I will also feed the LSTM network the book "Little Women",
# by Louisa May Alcott. This is for purposes
# of comparing and contrasting with the Star Wars model. Since the model
# is the same between them both, different degrees of success between the outputs
# could lead to insights with how the network "learns" text. Since the
# texts are different in nature, one being a movie script and the other being a novel,
# it will be interesting to see the differences between them, if any.

# %% [markdown]
# ## Background
#
# For this project I'm using a LSTM (long-short-term-memory) network.
# This is a type of RNN (recurrent neural network). The RNN is great for
# text generation, as it's built to use the output of previous iterations
# to better inform and build the next one. That's why
# it works great for text generation: one needs to know the
# words that came before to give a good next word.
#
# One area where RNN's fall short is the inability to "remember"
# things from awhile back. When the gap between the relevant information needed
# and the point where it is needed becomes too large, the RNN becomes
# less successful.
#
# LSTM's take a standard RNN and make some improvements. It's still
# the basic structure, however is able to learn long-term dependencies.
# The core idea is that in every module, or node, in the LSTM
# linked structure there is a cell state that runs through the module. It
# interacts very little with the rest of the internal structure of the module,
# and therefore receives only minor changes. There are several "gates"
# that the cell state goes through before leaving an individual module. These gates
# use a sigmoid neural net layer to determine how much of the cell state
# gets let through. The cell state gets passed through the
# onto the next module, and it's through this cell state that the
# long-term dependencies are learned.
#
# A great breakdown of RNN's and LSTM's can be found here:
# https://colah.github.io/posts/2015-08-Understanding-LSTMs

# %% [markdown]
# ## Implementation
#
# Most of the code I've used for this project is from Chapter 8, Section 1 of
# "Deep Learning with Python", by François Chollet. The code
# can be found here:
# https://github.com/fchollet/deep-learning-with-python-notebooks/blob/master/8.1-text-generation-with-lstm.ipynb
#
# I'll be going through the implementation using the Star Wars network,
# however the network for Little Women is exactly the same.
#
# First, the text file is read in, and made lower-case, to reduce
# the number of unique characters.

# %%
import keras
import numpy as np

text = open("/Users/tylerpoel/CS/344/cs344/Project/OriginalTrilogy_script.txt").read().lower()
print('Corpus length:', len(text))
# Out:
# Using TensorFlow backend.
# Corpus length: 491488

# %% [markdown]
# Next, a list of sequences of characters is created. The sequences
# can be as long as one wants. New sequences are are made every
# 3 characters. Based off of the sequence length chosen, ther could be a lot of overlap between characters that the sequences contain,
# however that's totally ok.
#
# A list of targets also needs to be created. A target in this scenario is simply the very next
# character that came after a given sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))
# Out:
# Number of sequences: 163810

# %% [markdown]
# There's a lot one can do with the maxlen and step paramaters.
# I found a maxlen of 60 and a step of 3 to work best. A maxlen that's
# super small ended up generating text that barely contained full and real words.
# A very large maxlen seemed overkill, and also didn't allow
# for as much unique behavior. 60 seemed like a great in-between.
#
# A list of unique characters present in the text is also created.

# %%
# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)
# Out:
# Unique characters: 57

# %% [markdown]
# Finally, characters and sequences are one-hot encoded into arrays.
# Using multi-dimension arrays, 1's and 0's are used to mark
# where one of the unique characters shows up. For each character in each sequence,
# there is an array the length of the number of unique characters. If the unique character
# matches with the current character in the sequence, a 1 is marked. If not, a zero.
# This process of one-hot encoding is done for both the sequences
# and the targets.

# %%
# One-hot encode the characters into binary arrays.
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

print('One-hot encoding complete')
# Out:
# One-hot encoding complete

# %% [markdown]
# Next the network is built, using a LSTM network as described above.
# A softmax activation function is used, because it gives probabilities as outputs.
# In this case, it will give a probability for each unique character, indicating
# the chances of that character coming next.
#
# The loss used is categorical cross entropy. This works
# well here because we can think of each character as it's
# own class, and our model is trying to compute a next character
# that matches the actual next character.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

print("Model built")
# Out:
# Model built

# %% [markdown]
# The sample function is useful for when text generation
# actually occurs. It takes the probability distribution given
# by the model, and returns an index for the next character
# given the weighted distribution.
#
# The sample function also reweights the text given a certain "temperature."
# Higher temperatures create slightly more sporadic and unique text, that
# has a much higher tendency to build incoherent sentences,
# or even words that aren't real. Lower temperatures follow much closer
# to the given text. Choosing the temperature is up to the user, given
# their own goals.
#
# When I ran my model I used only temperatures of 0.2 and 0.5 Anything larger, such as
# 1.0, gave results that were too random to be anything interesting. Temperatures of 0.2 and 0.5
# consistently gave the most coherent, and therefore useful, outputs.

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally the model is trained, and output is given.
# The loop repeatedly trains the model and generates the new text. In this final
# report notebook I'll only train it for 2 epochs, as training for
# lots of epochs is very time and space consuming, and to get the implementation
# details here, many epochs would be overkill. However both the Star
# Wars model and the Little Women model have been trained for
# 60 epochs, and the results of that training can be seen in their
# respective notebooks.

# %%
import random
import sys

for epoch in range(1, 3):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    if epoch % 2 == 0:
        # Select a text seed at random
        start_index = random.randint(0, len(text) - maxlen - 1)
        generated_text = text[start_index: start_index + maxlen]
        print('--- Generating with seed: "' + generated_text + '"')

        for temperature in [0.2, 0.5]:
            print('------ temperature:', temperature)
            sys.stdout.write(generated_text)

            # We generate 600 characters
            for i in range(600):
                sampled = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(generated_text):
                    sampled[0, t, char_indices[char]] = 1.

                preds = model.predict(sampled, verbose=0)[0]
                next_index = sample(preds, temperature)
                next_char = chars[next_index]

                generated_text += next_char
                generated_text = generated_text[1:]

                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()
# Out:
# epoch 1
# Epoch 1/1
# 163810/163810 [==============================] - 256s 2ms/step - loss: 1.9925
# epoch 2
# Epoch 1/1
#  66304/163810 [===========>..................] - ETA: 4:23 - loss: 1.6155

# %% [markdown]
# ## Results
#
# When I initially started this project, I had the intention of training my model only
# on the script for "Star Wars: A New Hope", not the whole original trilogy. However after
# doing this I realized that a single movie script is not near enough text to effectively
# train this model. The text generated was extremely low-level, and didn't resemble
#
# When using the full Original Trilogy, I still had mixed results for this project. In terms of being able to
# generate a new Star Wars-like script, I was partially successful.
# The generated text isn't very coherent; it doesn't make much sense.
# However, the model was able to learn the script structure. The output below of one
# of my many runs of this model demonstrates this. This was generated at Epoch 60
# with a temperature of 0.5.
#
#
# "han
#
# there's not the ship that is the speeder as they rogot a death star ship to the strike battering the guards.
#
# 2144 int. luke's x-wing fighter - cockpit luke's fine the cloud city time the tie fighters.
#
# 450 ext. space - said - cockpit
#
# artoo crouchts the tie fighters flips on anter and a group of a strange door before the shield.
#
# int. cloud city - cockpit
#
# the fighters looks the morning as a one of the last tie fighters."
#
#
# Obviously, as one reads this, it's hard to find any narrative thread that even slightly
# makes sense. However, what is notable is the structure that the model learned, which exactly like the
# script it was fed. It starts out by giving a character's name (in this case "han"), followed by a new line, and then
# the line of dialogue they say. Next, it gives a scene number (which is slightly irrelevant here, but does
# match how the script is set up), and then the scene location (here, the interior of Luke's X-wing).
# It's also capable of giving text that describes what's happening in the scene, such as the last line
# of output here.
#
# So, while this generation text doesn't make much logical sense, it does show the model's ability to
# learn the structure of the text it's been given.
#
# Looking at the "Little Women" text generation, results were fairly similar. The text below was generated at
# Epoch 35, with a temperature of 0.2.
#
# "l the silver wedding came round, and when i should be a long old boy to her which she had been a great of the boy to
# see her some of the tease of the speak of the spirit of the sort of the face of the spring of the words, and we can
# saw her the word. i found it went away. i'll be a great of the sweet of the face of the word, and a great hands and
# particular
#
# pitture and spoke the grand of the parts, and we can and we can went to see her the word with a gracious face of the
# face of the manskets and we got a great of the grass and word that he wouldn't see her the speak was a great of the
# face of the first music success."
#
# Again, there wasn't too much here that made logical sense. Perhaps it makes
# slightly more sense than the Star Wars text, but that's pretty subjective. As I read it,
# I didn't think there was any noticeable or significant improvement. I was surpised by this.
# I thought "Little Women" would be generate text that's more readable, as its file size was much larger
# (1,050,605 characters as opposed to the 494,395 characters in the Star Wars text). Perhaps even
# more text is needed to generate text that begins to make sense.
#
# As "Little Women" is a novel, there's less of a unique structure that the model can learn. One can
# see however that the structure that was generated is much like a novel would look, just
# as the Star Wars text looks like a movie script.
#
# In the end, I was able to succeed in answering one of my questions. The model
# was able to learn the structure of the text provided, generating movie script-like text
# when fed a movie script, and when given a novel generating a structure appropriate for a novel.
# Unfortunately, I wasn't able to make any gains in generating text that made logical sense, even across
# different genres and types of text.
# Neither of the texts I fed my model, "Little Women" and "Star Wars", generated text that very much sense.
# It appears that either a corpus much larger than what I had, or a more nuanced network, is needed to generate
# logical text.
#
# Overall, some of my favorite text that the model generated was:
#
# "threepio
#
# there is a lando."
#
# and,
#
# "han is a star destroyer and starts to him."

# %% [markdown]
# ## Implications
#
# Given my inability to create a model that generates
# logical text, I don't find very many ethical concerns with this
# technology. No one would be able to "hide" behind this
# computer generated text, or use it for some poor intent, as the text itself doesn't
# make any sense.
#
# With much nuanced and advanced models, I'm sure it's possible to achieve
# logical text generation. In that case, there emerges a few social or ethical
# concerns. When online, anything could be a computer. This problem already
# exists in various ways, however the ability for a machine to generate
# near perfect language could heighten this issue. Not knowing who or what
# we're dealing with could change the way we interact with the online world.
#
# If this text got super advanced, I can imagine a world where authors, journalists,
# or really anybody who uses writing frequently in their job, are threatened by this technology.
# If stories or new articles can simply be written by a machine, who would pay to have humans do it?
# With news stories, there could be issues of machines generating "fake news", that gets out into the public
# and people believe. However, I think this is very far down the line, and not a current concern. I think the
# technology would have come a long way before it can generate seemingly original text, that's better
# than something a human could do.
